# %%
using Statistics
using CSV
using DataFrames
using Measures
using Gadfly

ENV["LINES"] = 9;
# Out:
# ┌ Info: Loading DataFrames support into Gadfly.jl
# └ @ Gadfly C:\Users\Diego\.julia\packages\Gadfly\09PWZ\src\mapping.jl:228

# %%
# parameters
protein = "CAMK2D"
# Out:
# "CAMK2D"

# %%
function path_to_TranscriptAnnotation()
    folders = String[]
    for folder in splitpath(pwd())
        push!(folders, folder)
        if folder == "TranscriptAnnotation"
            break
        end
    end
    joinpath(folders...)
end

results_folder = joinpath(path_to_TranscriptAnnotation(), "benchmark", protein)
table_path = joinpath(results_folder, "thoraxe", "homologous_exon_table.csv")

const table = CSV.read(table_path);

# %% [markdown]
# ## Transcripts per species

# %%
by(table, :Species, :TranscriptIDCluster => length ∘ unique) |> 
    df -> rename!(df, :TranscriptIDCluster_function => :Transcripts) |>
    df -> show(df, allcols=true, allrows=true)
# Out:
# 3×2 DataFrame
# │ Row │ Species         │ Transcripts │
# │     │ String          │ Int64       │
# ├─────┼─────────────────┼─────────────┤
# │ 1   │ danio_rerio     │ 4           │
# │ 2   │ homo_sapiens    │ 5           │
# │ 3   │ gorilla_gorilla │ 5           │

# %% [markdown]
# ## (Sub)exons without (known) homology

# %%
total = sum(startswith(exonid, "0_") for exonid in unique(table[:HomologousExon]))
print("Number of (sub)exons without (known) homology in the gene: ", total)
# Out:
# Number of (sub)exons without (known) homology in the gene: 6

# %%
by(table, :Species) do df
    (ExonsWithoutHomology = sum(startswith(exonid, "0_") for exonid in unique(df[:HomologousExon])), )
end |> df -> show(df, allcols=true, allrows=true)
# Out:
# 3×2 DataFrame
# │ Row │ Species         │ ExonsWithoutHomology │
# │     │ String          │ Int64                │
# ├─────┼─────────────────┼──────────────────────┤
# │ 1   │ danio_rerio     │ 0                    │
# │ 2   │ homo_sapiens    │ 4                    │
# │ 3   │ gorilla_gorilla │ 2                    │

# %% [markdown]
# ### Short exons

# %% [markdown]
# Some subexons doesn't have known homologs because they are too short

# %%
by(table, [:TranscriptIDCluster, :ExonIDCluster], :SubexonProteinSequence => join) |>
    df -> by(df, 
        :ExonIDCluster, 
        :SubexonProteinSequence_join => col -> minimum(map(x -> length(replace(x, "*" => "")), col))) |>
    df -> rename!(df, :SubexonProteinSequence_join_function => :ExonLength) |>
    df -> df[df[:ExonLength] .≤ 4, :] |>
    df -> show(df, allcols=true, allrows=true)
# Out:
# 2×2 DataFrame
# │ Row │ ExonIDCluster      │ ExonLength │
# │     │ String             │ Int64      │
# ├─────┼────────────────────┼────────────┤
# │ 1   │ ENSE00003584478    │ 0          │
# │ 2   │ ENSGGOE00000307398 │ 0          │

# %% [markdown]
# ## Putative orthologous exons

# %%
total = sum(!startswith(exonid, "0_") for exonid in unique(table[:HomologousExon]))
print("Number of putative orthologous exons in the gene: ", total)
# Out:
# Number of putative orthologous exons in the gene: 25

# %%
by(table, :Species) do df
    (ExonsWithoutHomology = sum(!startswith(exonid, "0_") for exonid in unique(df[:HomologousExon])), )
end |> df -> show(df, allcols=true, allrows=true)
# Out:
# 3×2 DataFrame
# │ Row │ Species         │ ExonsWithoutHomology │
# │     │ String          │ Int64                │
# ├─────┼─────────────────┼──────────────────────┤
# │ 1   │ danio_rerio     │ 20                   │
# │ 2   │ homo_sapiens    │ 23                   │
# │ 3   │ gorilla_gorilla │ 23                   │

# %% [markdown]
# ## Exon Lengths

# %% [markdown]
# Distribution of homologous exon lengths

# %%
len(x) = ismissing(x) ? 0 : length(x)

const lengths = by(table, :HomologousExon, :HomologousExonSequence => col -> maximum(len.(col))) |> 
    df -> rename!(df, :HomologousExonSequence_function  => :HomologousExonLength ) |>
    df -> sort!(df, :HomologousExon) 

show(lengths, allrows=true)
# Out:
# 31×2 DataFrame
# │ Row │ HomologousExon │ HomologousExonLength │
# │     │ String         │ Int64                │
# ├─────┼────────────────┼──────────────────────┤
# │ 1   │ 0_1            │ 0                    │
# │ 2   │ 0_2            │ 0                    │
# │ 3   │ 0_3            │ 0                    │
# │ 4   │ 0_4            │ 0                    │
# │ 5   │ 0_5            │ 0                    │
# │ 6   │ 0_6            │ 0                    │
# │ 7   │ 10_0           │ 24                   │
# │ 8   │ 10_1           │ 24                   │
# │ 9   │ 11_0           │ 22                   │
# │ 10  │ 12_0           │ 22                   │
# │ 11  │ 13_0           │ 21                   │
# │ 12  │ 14_0           │ 20                   │
# │ 13  │ 15_0           │ 20                   │
# │ 14  │ 16_0           │ 18                   │
# │ 15  │ 17_0           │ 17                   │
# │ 16  │ 18_0           │ 15                   │
# │ 17  │ 19_0           │ 11                   │
# │ 18  │ 19_1           │ 15                   │
# │ 19  │ 1_0            │ 14                   │
# │ 20  │ 1_1            │ 76                   │
# │ 21  │ 20_0           │ 11                   │
# │ 22  │ 2_0            │ 41                   │
# │ 23  │ 2_1            │ 12                   │
# │ 24  │ 3_0            │ 35                   │
# │ 25  │ 4_0            │ 32                   │
# │ 26  │ 5_0            │ 32                   │
# │ 27  │ 6_0            │ 2                    │
# │ 28  │ 6_1            │ 29                   │
# │ 29  │ 7_0            │ 28                   │
# │ 30  │ 8_0            │ 28                   │
# │ 31  │ 9_0            │ 25                   │

# %%
lengths[:WithHomologous] = [ !startswith(exonid, "0_") for exonid in lengths[:HomologousExon ] ];

# %%
plt = plot(lengths, x="HomologousExonLength", color="WithHomologous", Geom.histogram)
draw(SVG(25cm, 15cm), plt)
# Out:
# SVG(250.0mm, 150.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=21790, maxsize=Inf, ptr=21791, mark=-1), nothing, "img-5ac6aa61", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Property}}(Property{JSIncludePrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{StrokePrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{FontSizePrimitive}=>nothing,Property{SVGAttributePrimitive}=>nothing,Property{StrokeDashPrimitive}=>nothing,Property{SVGClassPrimitive}=>nothing,Property{FontPrimitive}=>nothing,Property{LineWidthPrimitive}=>nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Length{:mm,Float64},Length{:mm,Float64}}[(8.67333mm, 5.0mm), (216.29mm, 5.0mm), (216.29mm, 130.715mm), (8.67333mm, 130.715mm)])=>"img-5ac6aa61-17"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-5ac6aa61-117", false, 117, Set(AbstractString["C:\\Users\\Diego\\.julia\\packages\\Gadfly\\09PWZ\\src\\gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-5ac6aa61-4\")\n   .drag(function() {}, function() {}, function() {});", "fig.select(\"#img-5ac6aa61-5\")\n   .data(\"color_class\", \"color_true\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-10\")\n   .data(\"color_class\", \"color_false\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-18\")\n   .init_gadfly();"], false, :none, (BoundingBox{Tuple{Length{:mm,Float64},Length{:mm,Float64}},Tuple{Length{:mm,Float64},Length{:mm,Float64}}}((8.673333333333346mm, 5.0mm), (207.61666666666667mm, 125.715mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-0.7857902922157649, 8.131454627613687, 81.57158058443153, -8.262909255227376, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %% [markdown]
# ## Alternative spliced homologous exons

# %% [markdown]
# Exons with a `TranscriptFraction` of `1.0` in a gene are constitutive. The plot can help to identify homologous_exons that change their `TranscriptFraction` in different genes.

# %%
constitutive = by(table, :GeneID) do df
    subdf = unique(df[:, [:HomologousExon, :TranscriptsWithSubexon, :TranscriptsInGene]])
    by(subdf, :HomologousExon) do exondf
        (TranscriptFraction = exondf[1, :TranscriptsWithSubexon] / exondf[1, :TranscriptsInGene],
         TranscriptsWithSubexon = exondf[1, :TranscriptsWithSubexon],
         TranscriptsInGene = exondf[1, :TranscriptsInGene])
    end
end;

# %%
plt = plot(constitutive, x="HomologousExon", y="TranscriptFraction", Geom.point)
draw(SVG(25cm, 15cm), plt)
# Out:
# SVG(250.0mm, 150.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=40764, maxsize=Inf, ptr=40765, mark=-1), nothing, "img-490bdd3f", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Property}}(Property{JSIncludePrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{StrokePrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{FontSizePrimitive}=>nothing,Property{SVGAttributePrimitive}=>nothing,Property{StrokeDashPrimitive}=>nothing,Property{SVGClassPrimitive}=>nothing,Property{FontPrimitive}=>nothing,Property{LineWidthPrimitive}=>nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Length{:mm,Float64},Length{:mm,Float64}}[(18.6317mm, 5.0mm), (245.0mm, 5.0mm), (245.0mm, 130.715mm), (18.6317mm, 130.715mm)])=>"img-490bdd3f-4"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-490bdd3f-267", false, 267, Set(AbstractString["C:\\Users\\Diego\\.julia\\packages\\Gadfly\\09PWZ\\src\\gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-490bdd3f-5\")\n   .init_gadfly();"], false, :none, (BoundingBox{Tuple{Length{:mm,Float64},Length{:mm,Float64}},Tuple{Length{:mm,Float64},Length{:mm,Float64}}}((18.63166666666669mm, 5.0mm), (226.36833333333334mm, 125.715mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(0.5, 1.0164318284517109, 31.0, -1.032863656903422, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
show(constitutive, allrows=true, allcols=true)
# Out:
# 72×5 DataFrame
# │ Row │ GeneID             │ HomologousExon │ TranscriptFraction │
# │     │ String             │ String         │ Float64            │
# ├─────┼────────────────────┼────────────────┼────────────────────┤
# │ 1   │ ENSDARG00000043010 │ 11_0           │ 0.75               │
# │ 2   │ ENSDARG00000043010 │ 4_0            │ 0.75               │
# │ 3   │ ENSDARG00000043010 │ 15_0           │ 0.75               │
# │ 4   │ ENSDARG00000043010 │ 16_0           │ 0.75               │
# │ 5   │ ENSDARG00000043010 │ 12_0           │ 0.75               │
# │ 6   │ ENSDARG00000043010 │ 10_0           │ 0.25               │
# │ 7   │ ENSDARG00000043010 │ 3_0            │ 0.75               │
# │ 8   │ ENSDARG00000043010 │ 7_0            │ 0.75               │
# │ 9   │ ENSDARG00000043010 │ 6_0            │ 0.75               │
# │ 10  │ ENSDARG00000043010 │ 6_1            │ 1.0                │
# │ 11  │ ENSDARG00000043010 │ 2_0            │ 1.0                │
# │ 12  │ ENSDARG00000043010 │ 8_0            │ 1.0                │
# │ 13  │ ENSDARG00000043010 │ 18_0           │ 1.0                │
# │ 14  │ ENSDARG00000043010 │ 19_0           │ 1.0                │
# │ 15  │ ENSDARG00000043010 │ 19_1           │ 0.75               │
# │ 16  │ ENSDARG00000043010 │ 17_0           │ 1.0                │
# │ 17  │ ENSDARG00000043010 │ 9_0            │ 1.0                │
# │ 18  │ ENSDARG00000043010 │ 5_0            │ 1.0                │
# │ 19  │ ENSDARG00000043010 │ 1_1            │ 1.0                │
# │ 20  │ ENSDARG00000043010 │ 10_1           │ 0.5                │
# │ 21  │ ENSG00000145349    │ 11_0           │ 1.0                │
# │ 22  │ ENSG00000145349    │ 4_0            │ 1.0                │
# │ 23  │ ENSG00000145349    │ 15_0           │ 1.0                │
# │ 24  │ ENSG00000145349    │ 16_0           │ 1.0                │
# │ 25  │ ENSG00000145349    │ 12_0           │ 1.0                │
# │ 26  │ ENSG00000145349    │ 10_0           │ 0.8                │
# │ 27  │ ENSG00000145349    │ 3_0            │ 1.0                │
# │ 28  │ ENSG00000145349    │ 7_0            │ 1.0                │
# │ 29  │ ENSG00000145349    │ 6_0            │ 1.0                │
# │ 30  │ ENSG00000145349    │ 6_1            │ 1.0                │
# │ 31  │ ENSG00000145349    │ 2_0            │ 1.0                │
# │ 32  │ ENSG00000145349    │ 8_0            │ 1.0                │
# │ 33  │ ENSG00000145349    │ 18_0           │ 1.0                │
# │ 34  │ ENSG00000145349    │ 2_1            │ 1.0                │
# │ 35  │ ENSG00000145349    │ 17_0           │ 1.0                │
# │ 36  │ ENSG00000145349    │ 9_0            │ 1.0                │
# │ 37  │ ENSG00000145349    │ 5_0            │ 1.0                │
# │ 38  │ ENSG00000145349    │ 1_1            │ 1.0                │
# │ 39  │ ENSG00000145349    │ 0_1            │ 0.6                │
# │ 40  │ ENSG00000145349    │ 1_0            │ 0.4                │
# │ 41  │ ENSG00000145349    │ 0_2            │ 0.6                │
# │ 42  │ ENSG00000145349    │ 0_4            │ 0.2                │
# │ 43  │ ENSG00000145349    │ 20_0           │ 0.2                │
# │ 44  │ ENSG00000145349    │ 0_3            │ 0.6                │
# │ 45  │ ENSG00000145349    │ 10_1           │ 0.2                │
# │ 46  │ ENSG00000145349    │ 14_0           │ 0.2                │
# │ 47  │ ENSG00000145349    │ 13_0           │ 0.2                │
# │ 48  │ ENSGGOG00000022729 │ 11_0           │ 1.0                │
# │ 49  │ ENSGGOG00000022729 │ 4_0            │ 1.0                │
# │ 50  │ ENSGGOG00000022729 │ 15_0           │ 1.0                │
# │ 51  │ ENSGGOG00000022729 │ 16_0           │ 1.0                │
# │ 52  │ ENSGGOG00000022729 │ 12_0           │ 1.0                │
# │ 53  │ ENSGGOG00000022729 │ 10_0           │ 0.8                │
# │ 54  │ ENSGGOG00000022729 │ 3_0            │ 1.0                │
# │ 55  │ ENSGGOG00000022729 │ 7_0            │ 1.0                │
# │ 56  │ ENSGGOG00000022729 │ 6_0            │ 1.0                │
# │ 57  │ ENSGGOG00000022729 │ 6_1            │ 1.0                │
# │ 58  │ ENSGGOG00000022729 │ 2_0            │ 1.0                │
# │ 59  │ ENSGGOG00000022729 │ 8_0            │ 1.0                │
# │ 60  │ ENSGGOG00000022729 │ 18_0           │ 1.0                │
# │ 61  │ ENSGGOG00000022729 │ 2_1            │ 1.0                │
# │ 62  │ ENSGGOG00000022729 │ 17_0           │ 1.0                │
# │ 63  │ ENSGGOG00000022729 │ 9_0            │ 1.0                │
# │ 64  │ ENSGGOG00000022729 │ 5_0            │ 1.0                │
# │ 65  │ ENSGGOG00000022729 │ 1_1            │ 1.0                │
# │ 66  │ ENSGGOG00000022729 │ 13_0           │ 0.6                │
# │ 67  │ ENSGGOG00000022729 │ 10_1           │ 0.2                │
# │ 68  │ ENSGGOG00000022729 │ 14_0           │ 0.2                │
# │ 69  │ ENSGGOG00000022729 │ 1_0            │ 0.4                │
# │ 70  │ ENSGGOG00000022729 │ 0_5            │ 0.2                │
# │ 71  │ ENSGGOG00000022729 │ 0_6            │ 0.2                │
# │ 72  │ ENSGGOG00000022729 │ 20_0           │ 0.2                │
#
# │ Row │ TranscriptsWithSubexon │ TranscriptsInGene │
# │     │ Int64                  │ Int64             │
# ├─────┼────────────────────────┼───────────────────┤
# │ 1   │ 3                      │ 4                 │
# │ 2   │ 3                      │ 4                 │
# │ 3   │ 3                      │ 4                 │
# │ 4   │ 3                      │ 4                 │
# │ 5   │ 3                      │ 4                 │
# │ 6   │ 1                      │ 4                 │
# │ 7   │ 3                      │ 4                 │
# │ 8   │ 3                      │ 4                 │
# │ 9   │ 3                      │ 4                 │
# │ 10  │ 4                      │ 4                 │
# │ 11  │ 4                      │ 4                 │
# │ 12  │ 4                      │ 4                 │
# │ 13  │ 4                      │ 4                 │
# │ 14  │ 4                      │ 4                 │
# │ 15  │ 3                      │ 4                 │
# │ 16  │ 4                      │ 4                 │
# │ 17  │ 4                      │ 4                 │
# │ 18  │ 4                      │ 4                 │
# │ 19  │ 4                      │ 4                 │
# │ 20  │ 2                      │ 4                 │
# │ 21  │ 5                      │ 5                 │
# │ 22  │ 5                      │ 5                 │
# │ 23  │ 5                      │ 5                 │
# │ 24  │ 5                      │ 5                 │
# │ 25  │ 5                      │ 5                 │
# │ 26  │ 4                      │ 5                 │
# │ 27  │ 5                      │ 5                 │
# │ 28  │ 5                      │ 5                 │
# │ 29  │ 5                      │ 5                 │
# │ 30  │ 5                      │ 5                 │
# │ 31  │ 5                      │ 5                 │
# │ 32  │ 5                      │ 5                 │
# │ 33  │ 5                      │ 5                 │
# │ 34  │ 5                      │ 5                 │
# │ 35  │ 5                      │ 5                 │
# │ 36  │ 5                      │ 5                 │
# │ 37  │ 5                      │ 5                 │
# │ 38  │ 5                      │ 5                 │
# │ 39  │ 3                      │ 5                 │
# │ 40  │ 2                      │ 5                 │
# │ 41  │ 3                      │ 5                 │
# │ 42  │ 1                      │ 5                 │
# │ 43  │ 1                      │ 5                 │
# │ 44  │ 3                      │ 5                 │
# │ 45  │ 1                      │ 5                 │
# │ 46  │ 1                      │ 5                 │
# │ 47  │ 1                      │ 5                 │
# │ 48  │ 5                      │ 5                 │
# │ 49  │ 5                      │ 5                 │
# │ 50  │ 5                      │ 5                 │
# │ 51  │ 5                      │ 5                 │
# │ 52  │ 5                      │ 5                 │
# │ 53  │ 4                      │ 5                 │
# │ 54  │ 5                      │ 5                 │
# │ 55  │ 5                      │ 5                 │
# │ 56  │ 5                      │ 5                 │
# │ 57  │ 5                      │ 5                 │
# │ 58  │ 5                      │ 5                 │
# │ 59  │ 5                      │ 5                 │
# │ 60  │ 5                      │ 5                 │
# │ 61  │ 5                      │ 5                 │
# │ 62  │ 5                      │ 5                 │
# │ 63  │ 5                      │ 5                 │
# │ 64  │ 5                      │ 5                 │
# │ 65  │ 5                      │ 5                 │
# │ 66  │ 3                      │ 5                 │
# │ 67  │ 1                      │ 5                 │
# │ 68  │ 1                      │ 5                 │
# │ 69  │ 2                      │ 5                 │
# │ 70  │ 1                      │ 5                 │
# │ 71  │ 1                      │ 5                 │
# │ 72  │ 1                      │ 5                 │
