# %%
using Statistics
using CSV
using DataFrames
using Measures
using Gadfly

ENV["LINES"] = 9;
# Out:
# ┌ Info: Loading DataFrames support into Gadfly.jl
# └ @ Gadfly C:\Users\Diego\.julia\packages\Gadfly\09PWZ\src\mapping.jl:228

# %%
# parameters
protein = "GRIN2C"
# Out:
# "GRIN2C"

# %%
function path_to_TranscriptAnnotation()
    folders = String[]
    for folder in splitpath(pwd())
        push!(folders, folder)
        if folder == "TranscriptAnnotation"
            break
        end
    end
    joinpath(folders...)
end

results_folder = joinpath(path_to_TranscriptAnnotation(), "benchmark", protein)
table_path = joinpath(results_folder, "thoraxe", "homologous_exon_table.csv")

const table = CSV.read(table_path);

# %% [markdown]
# ## Transcripts per species

# %%
by(table, :Species, :TranscriptIDCluster => length ∘ unique) |> 
    df -> rename!(df, :TranscriptIDCluster_function => :Transcripts) |>
    df -> show(df, allcols=true, allrows=true)
# Out:
# 5×2 DataFrame
# │ Row │ Species           │ Transcripts │
# │     │ String            │ Int64       │
# ├─────┼───────────────────┼─────────────┤
# │ 1   │ bos_taurus        │ 1           │
# │ 2   │ homo_sapiens      │ 2           │
# │ 3   │ macaca_mulatta    │ 1           │
# │ 4   │ rattus_norvegicus │ 1           │
# │ 5   │ sus_scrofa        │ 1           │

# %% [markdown]
# ## (Sub)exons without (known) homology

# %%
total = sum(startswith(exonid, "0_") for exonid in unique(table[:HomologousExon]))
print("Number of (sub)exons without (known) homology in the gene: ", total)
# Out:
# Number of (sub)exons without (known) homology in the gene: 0

# %%
by(table, :Species) do df
    (ExonsWithoutHomology = sum(startswith(exonid, "0_") for exonid in unique(df[:HomologousExon])), )
end |> df -> show(df, allcols=true, allrows=true)
# Out:
# 5×2 DataFrame
# │ Row │ Species           │ ExonsWithoutHomology │
# │     │ String            │ Int64                │
# ├─────┼───────────────────┼──────────────────────┤
# │ 1   │ bos_taurus        │ 0                    │
# │ 2   │ homo_sapiens      │ 0                    │
# │ 3   │ macaca_mulatta    │ 0                    │
# │ 4   │ rattus_norvegicus │ 0                    │
# │ 5   │ sus_scrofa        │ 0                    │

# %% [markdown]
# ### Short exons

# %% [markdown]
# Some subexons doesn't have known homologs because they are too short

# %%
by(table, [:TranscriptIDCluster, :ExonIDCluster], :SubexonProteinSequence => join) |>
    df -> by(df, 
        :ExonIDCluster, 
        :SubexonProteinSequence_join => col -> minimum(map(x -> length(replace(x, "*" => "")), col))) |>
    df -> rename!(df, :SubexonProteinSequence_join_function => :ExonLength) |>
    df -> df[df[:ExonLength] .≤ 4, :] |>
    df -> show(df, allcols=true, allrows=true)
# Out:
# 0×2 DataFrame

# %% [markdown]
# ## Putative orthologous exons

# %%
total = sum(!startswith(exonid, "0_") for exonid in unique(table[:HomologousExon]))
print("Number of putative orthologous exons in the gene: ", total)
# Out:
# Number of putative orthologous exons in the gene: 19

# %%
by(table, :Species) do df
    (ExonsWithoutHomology = sum(!startswith(exonid, "0_") for exonid in unique(df[:HomologousExon])), )
end |> df -> show(df, allcols=true, allrows=true)
# Out:
# 5×2 DataFrame
# │ Row │ Species           │ ExonsWithoutHomology │
# │     │ String            │ Int64                │
# ├─────┼───────────────────┼──────────────────────┤
# │ 1   │ bos_taurus        │ 17                   │
# │ 2   │ homo_sapiens      │ 18                   │
# │ 3   │ macaca_mulatta    │ 17                   │
# │ 4   │ rattus_norvegicus │ 17                   │
# │ 5   │ sus_scrofa        │ 18                   │

# %% [markdown]
# ## Exon Lengths

# %% [markdown]
# Distribution of homologous exon lengths

# %%
len(x) = ismissing(x) ? 0 : length(x)

const lengths = by(table, :HomologousExon, :HomologousExonSequence => col -> maximum(len.(col))) |> 
    df -> rename!(df, :HomologousExonSequence_function  => :HomologousExonLength ) |>
    df -> sort!(df, :HomologousExon) 

show(lengths, allrows=true)
# Out:
# 19×2 DataFrame
# │ Row │ HomologousExon │ HomologousExonLength │
# │     │ String         │ Int64                │
# ├─────┼────────────────┼──────────────────────┤
# │ 1   │ 10_0           │ 52                   │
# │ 2   │ 11_0           │ 42                   │
# │ 3   │ 12_0           │ 38                   │
# │ 4   │ 1_0            │ 145                  │
# │ 5   │ 1_1            │ 19                   │
# │ 6   │ 1_2            │ 98                   │
# │ 7   │ 1_3            │ 3                    │
# │ 8   │ 1_4            │ 118                  │
# │ 9   │ 2_0            │ 200                  │
# │ 10  │ 3_0            │ 146                  │
# │ 11  │ 3_1            │ 14                   │
# │ 12  │ 4_0            │ 41                   │
# │ 13  │ 4_1            │ 36                   │
# │ 14  │ 4_2            │ 12                   │
# │ 15  │ 5_0            │ 76                   │
# │ 16  │ 6_0            │ 71                   │
# │ 17  │ 7_0            │ 63                   │
# │ 18  │ 8_0            │ 55                   │
# │ 19  │ 9_0            │ 54                   │

# %%
lengths[:WithHomologous] = [ !startswith(exonid, "0_") for exonid in lengths[:HomologousExon ] ];

# %%
plt = plot(lengths, x="HomologousExonLength", color="WithHomologous", Geom.histogram)
draw(SVG(25cm, 15cm), plt)
# Out:
# SVG(250.0mm, 150.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=9798, maxsize=Inf, ptr=9799, mark=-1), nothing, "img-5ac6aa61", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Property}}(Property{JSIncludePrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{StrokePrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{FontSizePrimitive}=>nothing,Property{SVGAttributePrimitive}=>nothing,Property{StrokeDashPrimitive}=>nothing,Property{SVGClassPrimitive}=>nothing,Property{FontPrimitive}=>nothing,Property{LineWidthPrimitive}=>nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Length{:mm,Float64},Length{:mm,Float64}}[(8.67333mm, 5.0mm), (216.29mm, 5.0mm), (216.29mm, 130.715mm), (8.67333mm, 130.715mm)])=>"img-5ac6aa61-12"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-5ac6aa61-51", false, 51, Set(AbstractString["C:\\Users\\Diego\\.julia\\packages\\Gadfly\\09PWZ\\src\\gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-5ac6aa61-4\")\n   .drag(function() {}, function() {}, function() {});", "fig.select(\"#img-5ac6aa61-5\")\n   .data(\"color_class\", \"color_true\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-13\")\n   .init_gadfly();"], false, :none, (BoundingBox{Tuple{Length{:mm,Float64},Length{:mm,Float64}},Tuple{Length{:mm,Float64},Length{:mm,Float64}}}((8.673333333333346mm, 5.0mm), (207.61666666666667mm, 125.715mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-2.4555946631742653, 4.0657273138068435, 254.91118932634853, -4.131454627613688, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %% [markdown]
# ## Alternative spliced homologous exons

# %% [markdown]
# Exons with a `TranscriptFraction` of `1.0` in a gene are constitutive. The plot can help to identify homologous_exons that change their `TranscriptFraction` in different genes.

# %%
constitutive = by(table, :GeneID) do df
    subdf = unique(df[:, [:HomologousExon, :TranscriptsWithSubexon, :TranscriptsInGene]])
    by(subdf, :HomologousExon) do exondf
        (TranscriptFraction = exondf[1, :TranscriptsWithSubexon] / exondf[1, :TranscriptsInGene],
         TranscriptsWithSubexon = exondf[1, :TranscriptsWithSubexon],
         TranscriptsInGene = exondf[1, :TranscriptsInGene])
    end
end;

# %%
plt = plot(constitutive, x="HomologousExon", y="TranscriptFraction", Geom.point)
draw(SVG(25cm, 15cm), plt)
# Out:
# SVG(250.0mm, 150.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=43752, maxsize=Inf, ptr=43753, mark=-1), nothing, "img-490bdd3f", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Property}}(Property{JSIncludePrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{StrokePrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{FontSizePrimitive}=>nothing,Property{SVGAttributePrimitive}=>nothing,Property{StrokeDashPrimitive}=>nothing,Property{SVGClassPrimitive}=>nothing,Property{FontPrimitive}=>nothing,Property{LineWidthPrimitive}=>nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Length{:mm,Float64},Length{:mm,Float64}}[(18.6317mm, 5.0mm), (245.0mm, 5.0mm), (245.0mm, 130.715mm), (18.6317mm, 130.715mm)])=>"img-490bdd3f-4"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-490bdd3f-306", false, 306, Set(AbstractString["C:\\Users\\Diego\\.julia\\packages\\Gadfly\\09PWZ\\src\\gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-490bdd3f-5\")\n   .init_gadfly();"], false, :none, (BoundingBox{Tuple{Length{:mm,Float64},Length{:mm,Float64}},Tuple{Length{:mm,Float64},Length{:mm,Float64}}}((18.63166666666669mm, 5.0mm), (226.36833333333334mm, 125.715mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(0.5, 1.0082159142258555, 19.0, -0.516431828451711, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
show(constitutive, allrows=true, allcols=true)
# Out:
# 87×5 DataFrame
# │ Row │ GeneID             │ HomologousExon │ TranscriptFraction │
# │     │ String             │ String         │ Float64            │
# ├─────┼────────────────────┼────────────────┼────────────────────┤
# │ 1   │ ENSBTAG00000040042 │ 3_0            │ 1.0                │
# │ 2   │ ENSBTAG00000040042 │ 2_0            │ 1.0                │
# │ 3   │ ENSBTAG00000040042 │ 12_0           │ 1.0                │
# │ 4   │ ENSBTAG00000040042 │ 6_0            │ 1.0                │
# │ 5   │ ENSBTAG00000040042 │ 8_0            │ 1.0                │
# │ 6   │ ENSBTAG00000040042 │ 10_0           │ 1.0                │
# │ 7   │ ENSBTAG00000040042 │ 11_0           │ 1.0                │
# │ 8   │ ENSBTAG00000040042 │ 5_0            │ 1.0                │
# │ 9   │ ENSBTAG00000040042 │ 9_0            │ 1.0                │
# │ 10  │ ENSBTAG00000040042 │ 7_0            │ 1.0                │
# │ 11  │ ENSBTAG00000040042 │ 4_0            │ 1.0                │
# │ 12  │ ENSBTAG00000040042 │ 4_1            │ 1.0                │
# │ 13  │ ENSBTAG00000040042 │ 1_0            │ 1.0                │
# │ 14  │ ENSBTAG00000040042 │ 1_1            │ 1.0                │
# │ 15  │ ENSBTAG00000040042 │ 1_2            │ 1.0                │
# │ 16  │ ENSBTAG00000040042 │ 1_3            │ 1.0                │
# │ 17  │ ENSBTAG00000040042 │ 1_4            │ 1.0                │
# │ 18  │ ENSG00000161509    │ 3_0            │ 1.0                │
# │ 19  │ ENSG00000161509    │ 2_0            │ 1.0                │
# │ 20  │ ENSG00000161509    │ 12_0           │ 1.0                │
# │ 21  │ ENSG00000161509    │ 6_0            │ 1.0                │
# │ 22  │ ENSG00000161509    │ 8_0            │ 1.0                │
# │ 23  │ ENSG00000161509    │ 10_0           │ 1.0                │
# │ 24  │ ENSG00000161509    │ 11_0           │ 1.0                │
# │ 25  │ ENSG00000161509    │ 5_0            │ 1.0                │
# │ 26  │ ENSG00000161509    │ 9_0            │ 1.0                │
# │ 27  │ ENSG00000161509    │ 7_0            │ 1.0                │
# │ 28  │ ENSG00000161509    │ 4_0            │ 1.0                │
# │ 29  │ ENSG00000161509    │ 4_1            │ 1.0                │
# │ 30  │ ENSG00000161509    │ 1_0            │ 0.5                │
# │ 31  │ ENSG00000161509    │ 1_1            │ 0.5                │
# │ 32  │ ENSG00000161509    │ 1_2            │ 0.5                │
# │ 33  │ ENSG00000161509    │ 1_3            │ 0.5                │
# │ 34  │ ENSG00000161509    │ 1_4            │ 0.5                │
# │ 35  │ ENSG00000161509    │ 4_2            │ 0.5                │
# │ 36  │ ENSMMUG00000005744 │ 3_0            │ 1.0                │
# │ 37  │ ENSMMUG00000005744 │ 2_0            │ 1.0                │
# │ 38  │ ENSMMUG00000005744 │ 12_0           │ 1.0                │
# │ 39  │ ENSMMUG00000005744 │ 6_0            │ 1.0                │
# │ 40  │ ENSMMUG00000005744 │ 8_0            │ 1.0                │
# │ 41  │ ENSMMUG00000005744 │ 10_0           │ 1.0                │
# │ 42  │ ENSMMUG00000005744 │ 11_0           │ 1.0                │
# │ 43  │ ENSMMUG00000005744 │ 5_0            │ 1.0                │
# │ 44  │ ENSMMUG00000005744 │ 9_0            │ 1.0                │
# │ 45  │ ENSMMUG00000005744 │ 7_0            │ 1.0                │
# │ 46  │ ENSMMUG00000005744 │ 4_0            │ 1.0                │
# │ 47  │ ENSMMUG00000005744 │ 4_1            │ 1.0                │
# │ 48  │ ENSMMUG00000005744 │ 1_0            │ 1.0                │
# │ 49  │ ENSMMUG00000005744 │ 1_1            │ 1.0                │
# │ 50  │ ENSMMUG00000005744 │ 1_2            │ 1.0                │
# │ 51  │ ENSMMUG00000005744 │ 1_3            │ 1.0                │
# │ 52  │ ENSMMUG00000005744 │ 1_4            │ 1.0                │
# │ 53  │ ENSRNOG00000003280 │ 3_0            │ 1.0                │
# │ 54  │ ENSRNOG00000003280 │ 2_0            │ 1.0                │
# │ 55  │ ENSRNOG00000003280 │ 12_0           │ 1.0                │
# │ 56  │ ENSRNOG00000003280 │ 6_0            │ 1.0                │
# │ 57  │ ENSRNOG00000003280 │ 8_0            │ 1.0                │
# │ 58  │ ENSRNOG00000003280 │ 10_0           │ 1.0                │
# │ 59  │ ENSRNOG00000003280 │ 11_0           │ 1.0                │
# │ 60  │ ENSRNOG00000003280 │ 5_0            │ 1.0                │
# │ 61  │ ENSRNOG00000003280 │ 9_0            │ 1.0                │
# │ 62  │ ENSRNOG00000003280 │ 7_0            │ 1.0                │
# │ 63  │ ENSRNOG00000003280 │ 4_0            │ 1.0                │
# │ 64  │ ENSRNOG00000003280 │ 4_1            │ 1.0                │
# │ 65  │ ENSRNOG00000003280 │ 1_0            │ 1.0                │
# │ 66  │ ENSRNOG00000003280 │ 1_1            │ 1.0                │
# │ 67  │ ENSRNOG00000003280 │ 1_2            │ 1.0                │
# │ 68  │ ENSRNOG00000003280 │ 1_3            │ 1.0                │
# │ 69  │ ENSRNOG00000003280 │ 1_4            │ 1.0                │
# │ 70  │ ENSSSCG00000023151 │ 3_0            │ 1.0                │
# │ 71  │ ENSSSCG00000023151 │ 2_0            │ 1.0                │
# │ 72  │ ENSSSCG00000023151 │ 12_0           │ 1.0                │
# │ 73  │ ENSSSCG00000023151 │ 6_0            │ 1.0                │
# │ 74  │ ENSSSCG00000023151 │ 8_0            │ 1.0                │
# │ 75  │ ENSSSCG00000023151 │ 10_0           │ 1.0                │
# │ 76  │ ENSSSCG00000023151 │ 11_0           │ 1.0                │
# │ 77  │ ENSSSCG00000023151 │ 5_0            │ 1.0                │
# │ 78  │ ENSSSCG00000023151 │ 9_0            │ 1.0                │
# │ 79  │ ENSSSCG00000023151 │ 7_0            │ 1.0                │
# │ 80  │ ENSSSCG00000023151 │ 4_0            │ 1.0                │
# │ 81  │ ENSSSCG00000023151 │ 4_1            │ 1.0                │
# │ 82  │ ENSSSCG00000023151 │ 1_0            │ 1.0                │
# │ 83  │ ENSSSCG00000023151 │ 1_1            │ 1.0                │
# │ 84  │ ENSSSCG00000023151 │ 1_2            │ 1.0                │
# │ 85  │ ENSSSCG00000023151 │ 3_1            │ 1.0                │
# │ 86  │ ENSSSCG00000023151 │ 1_3            │ 1.0                │
# │ 87  │ ENSSSCG00000023151 │ 1_4            │ 1.0                │
#
# │ Row │ TranscriptsWithSubexon │ TranscriptsInGene │
# │     │ Int64                  │ Int64             │
# ├─────┼────────────────────────┼───────────────────┤
# │ 1   │ 1                      │ 1                 │
# │ 2   │ 1                      │ 1                 │
# │ 3   │ 1                      │ 1                 │
# │ 4   │ 1                      │ 1                 │
# │ 5   │ 1                      │ 1                 │
# │ 6   │ 1                      │ 1                 │
# │ 7   │ 1                      │ 1                 │
# │ 8   │ 1                      │ 1                 │
# │ 9   │ 1                      │ 1                 │
# │ 10  │ 1                      │ 1                 │
# │ 11  │ 1                      │ 1                 │
# │ 12  │ 1                      │ 1                 │
# │ 13  │ 1                      │ 1                 │
# │ 14  │ 1                      │ 1                 │
# │ 15  │ 1                      │ 1                 │
# │ 16  │ 1                      │ 1                 │
# │ 17  │ 1                      │ 1                 │
# │ 18  │ 2                      │ 2                 │
# │ 19  │ 2                      │ 2                 │
# │ 20  │ 2                      │ 2                 │
# │ 21  │ 2                      │ 2                 │
# │ 22  │ 2                      │ 2                 │
# │ 23  │ 2                      │ 2                 │
# │ 24  │ 2                      │ 2                 │
# │ 25  │ 2                      │ 2                 │
# │ 26  │ 2                      │ 2                 │
# │ 27  │ 2                      │ 2                 │
# │ 28  │ 2                      │ 2                 │
# │ 29  │ 2                      │ 2                 │
# │ 30  │ 1                      │ 2                 │
# │ 31  │ 1                      │ 2                 │
# │ 32  │ 1                      │ 2                 │
# │ 33  │ 1                      │ 2                 │
# │ 34  │ 1                      │ 2                 │
# │ 35  │ 1                      │ 2                 │
# │ 36  │ 1                      │ 1                 │
# │ 37  │ 1                      │ 1                 │
# │ 38  │ 1                      │ 1                 │
# │ 39  │ 1                      │ 1                 │
# │ 40  │ 1                      │ 1                 │
# │ 41  │ 1                      │ 1                 │
# │ 42  │ 1                      │ 1                 │
# │ 43  │ 1                      │ 1                 │
# │ 44  │ 1                      │ 1                 │
# │ 45  │ 1                      │ 1                 │
# │ 46  │ 1                      │ 1                 │
# │ 47  │ 1                      │ 1                 │
# │ 48  │ 1                      │ 1                 │
# │ 49  │ 1                      │ 1                 │
# │ 50  │ 1                      │ 1                 │
# │ 51  │ 1                      │ 1                 │
# │ 52  │ 1                      │ 1                 │
# │ 53  │ 1                      │ 1                 │
# │ 54  │ 1                      │ 1                 │
# │ 55  │ 1                      │ 1                 │
# │ 56  │ 1                      │ 1                 │
# │ 57  │ 1                      │ 1                 │
# │ 58  │ 1                      │ 1                 │
# │ 59  │ 1                      │ 1                 │
# │ 60  │ 1                      │ 1                 │
# │ 61  │ 1                      │ 1                 │
# │ 62  │ 1                      │ 1                 │
# │ 63  │ 1                      │ 1                 │
# │ 64  │ 1                      │ 1                 │
# │ 65  │ 1                      │ 1                 │
# │ 66  │ 1                      │ 1                 │
# │ 67  │ 1                      │ 1                 │
# │ 68  │ 1                      │ 1                 │
# │ 69  │ 1                      │ 1                 │
# │ 70  │ 1                      │ 1                 │
# │ 71  │ 1                      │ 1                 │
# │ 72  │ 1                      │ 1                 │
# │ 73  │ 1                      │ 1                 │
# │ 74  │ 1                      │ 1                 │
# │ 75  │ 1                      │ 1                 │
# │ 76  │ 1                      │ 1                 │
# │ 77  │ 1                      │ 1                 │
# │ 78  │ 1                      │ 1                 │
# │ 79  │ 1                      │ 1                 │
# │ 80  │ 1                      │ 1                 │
# │ 81  │ 1                      │ 1                 │
# │ 82  │ 1                      │ 1                 │
# │ 83  │ 1                      │ 1                 │
# │ 84  │ 1                      │ 1                 │
# │ 85  │ 1                      │ 1                 │
# │ 86  │ 1                      │ 1                 │
# │ 87  │ 1                      │ 1                 │
