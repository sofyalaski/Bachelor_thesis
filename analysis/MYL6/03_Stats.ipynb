# %%
using Statistics
using CSV
using DataFrames
using Measures
using Gadfly

ENV["LINES"] = 9;
# Out:
# ┌ Info: Loading DataFrames support into Gadfly.jl
# └ @ Gadfly C:\Users\Diego\.julia\packages\Gadfly\09PWZ\src\mapping.jl:228

# %%
# parameters
protein = "MYL6"
# Out:
# "MYL6"

# %%
function path_to_TranscriptAnnotation()
    folders = String[]
    for folder in splitpath(pwd())
        push!(folders, folder)
        if folder == "TranscriptAnnotation"
            break
        end
    end
    joinpath(folders...)
end

results_folder = joinpath(path_to_TranscriptAnnotation(), "benchmark", protein)
table_path = joinpath(results_folder, "thoraxe", "homologous_exon_table.csv")

const table = CSV.read(table_path);

# %% [markdown]
# ## Transcripts per species

# %%
by(table, :Species, :TranscriptIDCluster => length ∘ unique) |> 
    df -> rename!(df, :TranscriptIDCluster_function => :Transcripts) |>
    df -> show(df, allcols=true, allrows=true)
# Out:
# 5×2 DataFrame
# │ Row │ Species           │ Transcripts │
# │     │ String            │ Int64       │
# ├─────┼───────────────────┼─────────────┤
# │ 1   │ bos_taurus        │ 3           │
# │ 2   │ homo_sapiens      │ 11          │
# │ 3   │ mus_musculus      │ 5           │
# │ 4   │ rattus_norvegicus │ 3           │
# │ 5   │ sus_scrofa        │ 2           │

# %% [markdown]
# ## (Sub)exons without (known) homology

# %%
total = sum(startswith(exonid, "0_") for exonid in unique(table[:HomologousExon]))
print("Number of (sub)exons without (known) homology in the gene: ", total)
# Out:
# Number of (sub)exons without (known) homology in the gene: 11

# %%
by(table, :Species) do df
    (ExonsWithoutHomology = sum(startswith(exonid, "0_") for exonid in unique(df[:HomologousExon])), )
end |> df -> show(df, allcols=true, allrows=true)
# Out:
# 5×2 DataFrame
# │ Row │ Species           │ ExonsWithoutHomology │
# │     │ String            │ Int64                │
# ├─────┼───────────────────┼──────────────────────┤
# │ 1   │ bos_taurus        │ 1                    │
# │ 2   │ homo_sapiens      │ 0                    │
# │ 3   │ mus_musculus      │ 5                    │
# │ 4   │ rattus_norvegicus │ 4                    │
# │ 5   │ sus_scrofa        │ 1                    │

# %% [markdown]
# ### Short exons

# %% [markdown]
# Some subexons doesn't have known homologs because they are too short

# %%
by(table, [:TranscriptIDCluster, :ExonIDCluster], :SubexonProteinSequence => join) |>
    df -> by(df, 
        :ExonIDCluster, 
        :SubexonProteinSequence_join => col -> minimum(map(x -> length(replace(x, "*" => "")), col))) |>
    df -> rename!(df, :SubexonProteinSequence_join_function => :ExonLength) |>
    df -> df[df[:ExonLength] .≤ 4, :] |>
    df -> show(df, allcols=true, allrows=true)
# Out:
# 6×2 DataFrame
# │ Row │ │     │ ├─────┼
# │ 1   │ │ 2   │ │ 3   │ │ 4   │ │ 5   │ │ 6   │
#
# │ Row │ ExonIDCluster                                                                                                   │
# │     │ String                                                                                                          │
# ├─────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ 1   │ ENSBTAE00000116609                                                                                              │
# │ 2   │ ENSE00001302119/ENSE00002342522/ENSE00002366274/ENSE00002371093/ENSE00002376363/ENSE00002402518/ENSE00003472971 │
# │ 3   │ ENSMUSE00000913007/ENSMUSE00001408077/ENSMUSE00001409039/ENSMUSE00001409223                                     │
# │ 4   │ ENSRNOE00000525244/ENSRNOE00000535701                                                                           │
# │ 5   │ ENSRNOE00000571732                                                                                              │
# │ 6   │ ENSSSCE00000161822                                                                                              │
#
# │ Row │ ExonLength │
# │     │ Int64      │
# ├─────┼────────────┤
# │ 1   │ 1          │
# │ 2   │ 1          │
# │ 3   │ 1          │
# │ 4   │ 1          │
# │ 5   │ 2          │
# │ 6   │ 1          │

# %% [markdown]
# ## Putative orthologous exons

# %%
total = sum(!startswith(exonid, "0_") for exonid in unique(table[:HomologousExon]))
print("Number of putative orthologous exons in the gene: ", total)
# Out:
# Number of putative orthologous exons in the gene: 19

# %%
by(table, :Species) do df
    (ExonsWithoutHomology = sum(!startswith(exonid, "0_") for exonid in unique(df[:HomologousExon])), )
end |> df -> show(df, allcols=true, allrows=true)
# Out:
# 5×2 DataFrame
# │ Row │ Species           │ ExonsWithoutHomology │
# │     │ String            │ Int64                │
# ├─────┼───────────────────┼──────────────────────┤
# │ 1   │ bos_taurus        │ 14                   │
# │ 2   │ homo_sapiens      │ 17                   │
# │ 3   │ mus_musculus      │ 14                   │
# │ 4   │ rattus_norvegicus │ 13                   │
# │ 5   │ sus_scrofa        │ 13                   │

# %% [markdown]
# ## Exon Lengths

# %% [markdown]
# Distribution of homologous exon lengths

# %%
len(x) = ismissing(x) ? 0 : length(x)

const lengths = by(table, :HomologousExon, :HomologousExonSequence => col -> maximum(len.(col))) |> 
    df -> rename!(df, :HomologousExonSequence_function  => :HomologousExonLength ) |>
    df -> sort!(df, :HomologousExon) 

show(lengths, allrows=true)
# Out:
# 30×2 DataFrame
# │ Row │ HomologousExon │ HomologousExonLength │
# │     │ String         │ Int64                │
# ├─────┼────────────────┼──────────────────────┤
# │ 1   │ 0_1            │ 1                    │
# │ 2   │ 0_10           │ 2                    │
# │ 3   │ 0_11           │ 1                    │
# │ 4   │ 0_2            │ 1                    │
# │ 5   │ 0_3            │ 1                    │
# │ 6   │ 0_4            │ 1                    │
# │ 7   │ 0_5            │ 1                    │
# │ 8   │ 0_6            │ 1                    │
# │ 9   │ 0_7            │ 1                    │
# │ 10  │ 0_8            │ 1                    │
# │ 11  │ 0_9            │ 1                    │
# │ 12  │ 1_0            │ 1                    │
# │ 13  │ 1_1            │ 92                   │
# │ 14  │ 1_2            │ 1                    │
# │ 15  │ 1_3            │ 10                   │
# │ 16  │ 1_4            │ 8                    │
# │ 17  │ 2_0            │ 41                   │
# │ 18  │ 2_1            │ 4                    │
# │ 19  │ 2_2            │ 13                   │
# │ 20  │ 3_0            │ 12                   │
# │ 21  │ 3_1            │ 17                   │
# │ 22  │ 3_2            │ 11                   │
# │ 23  │ 3_3            │ 8                    │
# │ 24  │ 4_0            │ 16                   │
# │ 25  │ 4_1            │ 10                   │
# │ 26  │ 4_2            │ 9                    │
# │ 27  │ 5_0            │ 18                   │
# │ 28  │ 6_0            │ 15                   │
# │ 29  │ 7_0            │ 9                    │
# │ 30  │ 8_0            │ 8                    │

# %%
lengths[:WithHomologous] = [ !startswith(exonid, "0_") for exonid in lengths[:HomologousExon ] ];

# %%
plt = plot(lengths, x="HomologousExonLength", color="WithHomologous", Geom.histogram)
draw(SVG(25cm, 15cm), plt)
# Out:
# SVG(250.0mm, 150.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=17844, maxsize=Inf, ptr=17845, mark=-1), nothing, "img-5ac6aa61", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Property}}(Property{JSIncludePrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{StrokePrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{FontSizePrimitive}=>nothing,Property{SVGAttributePrimitive}=>nothing,Property{StrokeDashPrimitive}=>nothing,Property{SVGClassPrimitive}=>nothing,Property{FontPrimitive}=>nothing,Property{LineWidthPrimitive}=>nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Length{:mm,Float64},Length{:mm,Float64}}[(10.3467mm, 5.0mm), (216.29mm, 5.0mm), (216.29mm, 130.715mm), (10.3467mm, 130.715mm)])=>"img-5ac6aa61-13"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-5ac6aa61-95", false, 95, Set(AbstractString["C:\\Users\\Diego\\.julia\\packages\\Gadfly\\09PWZ\\src\\gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-5ac6aa61-4\")\n   .drag(function() {}, function() {}, function() {});", "fig.select(\"#img-5ac6aa61-6\")\n   .data(\"color_class\", \"color_false\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-7\")\n   .data(\"color_class\", \"color_true\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-9\")\n   .data(\"color_class\", \"color_false\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-10\")\n   .data(\"color_class\", \"color_true\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-14\")\n   .init_gadfly();"], false, :none, (BoundingBox{Tuple{Length{:mm,Float64},Length{:mm,Float64}},Tuple{Length{:mm,Float64},Length{:mm,Float64}}}((10.346666666666664mm, 5.0mm), (205.94333333333333mm, 125.71499999999999mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-0.9903768383870062, 15.246477426775664, 101.98075367677401, -15.49295485355133, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %% [markdown]
# ## Alternative spliced homologous exons

# %% [markdown]
# Exons with a `TranscriptFraction` of `1.0` in a gene are constitutive. The plot can help to identify homologous_exons that change their `TranscriptFraction` in different genes.

# %%
constitutive = by(table, :GeneID) do df
    subdf = unique(df[:, [:HomologousExon, :TranscriptsWithSubexon, :TranscriptsInGene]])
    by(subdf, :HomologousExon) do exondf
        (TranscriptFraction = exondf[1, :TranscriptsWithSubexon] / exondf[1, :TranscriptsInGene],
         TranscriptsWithSubexon = exondf[1, :TranscriptsWithSubexon],
         TranscriptsInGene = exondf[1, :TranscriptsInGene])
    end
end;

# %%
plt = plot(constitutive, x="HomologousExon", y="TranscriptFraction", Geom.point)
draw(SVG(25cm, 15cm), plt)
# Out:
# SVG(250.0mm, 150.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=44305, maxsize=Inf, ptr=44306, mark=-1), nothing, "img-490bdd3f", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Property}}(Property{JSIncludePrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{StrokePrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{FontSizePrimitive}=>nothing,Property{SVGAttributePrimitive}=>nothing,Property{StrokeDashPrimitive}=>nothing,Property{SVGClassPrimitive}=>nothing,Property{FontPrimitive}=>nothing,Property{LineWidthPrimitive}=>nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Length{:mm,Float64},Length{:mm,Float64}}[(18.6317mm, 5.0mm), (245.0mm, 5.0mm), (245.0mm, 130.715mm), (18.6317mm, 130.715mm)])=>"img-490bdd3f-4"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-490bdd3f-296", false, 296, Set(AbstractString["C:\\Users\\Diego\\.julia\\packages\\Gadfly\\09PWZ\\src\\gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-490bdd3f-5\")\n   .init_gadfly();"], false, :none, (BoundingBox{Tuple{Length{:mm,Float64},Length{:mm,Float64}},Tuple{Length{:mm,Float64},Length{:mm,Float64}}}((18.63166666666669mm, 5.0mm), (226.36833333333334mm, 125.715mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(0.5, 1.0164318284517109, 30.0, -1.032863656903422, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
show(constitutive, allrows=true, allcols=true)
# Out:
# 82×5 DataFrame
# │ Row │ GeneID             │ HomologousExon │ TranscriptFraction │
# │     │ String             │ String         │ Float64            │
# ├─────┼────────────────────┼────────────────┼────────────────────┤
# │ 1   │ ENSBTAG00000010799 │ 0_1            │ 0.333333           │
# │ 2   │ ENSBTAG00000010799 │ 1_3            │ 1.0                │
# │ 3   │ ENSBTAG00000010799 │ 3_0            │ 1.0                │
# │ 4   │ ENSBTAG00000010799 │ 3_1            │ 1.0                │
# │ 5   │ ENSBTAG00000010799 │ 3_2            │ 0.666667           │
# │ 6   │ ENSBTAG00000010799 │ 3_3            │ 1.0                │
# │ 7   │ ENSBTAG00000010799 │ 2_0            │ 1.0                │
# │ 8   │ ENSBTAG00000010799 │ 2_1            │ 1.0                │
# │ 9   │ ENSBTAG00000010799 │ 2_2            │ 1.0                │
# │ 10  │ ENSBTAG00000010799 │ 4_0            │ 1.0                │
# │ 11  │ ENSBTAG00000010799 │ 4_1            │ 1.0                │
# │ 12  │ ENSBTAG00000010799 │ 8_0            │ 0.666667           │
# │ 13  │ ENSBTAG00000010799 │ 1_4            │ 0.333333           │
# │ 14  │ ENSBTAG00000010799 │ 1_1            │ 0.333333           │
# │ 15  │ ENSBTAG00000010799 │ 1_2            │ 0.333333           │
# │ 16  │ ENSG00000092841    │ 1_0            │ 0.909091           │
# │ 17  │ ENSG00000092841    │ 1_2            │ 0.363636           │
# │ 18  │ ENSG00000092841    │ 1_3            │ 0.909091           │
# │ 19  │ ENSG00000092841    │ 3_0            │ 0.727273           │
# │ 20  │ ENSG00000092841    │ 3_1            │ 0.636364           │
# │ 21  │ ENSG00000092841    │ 3_2            │ 0.636364           │
# │ 22  │ ENSG00000092841    │ 3_3            │ 0.636364           │
# │ 23  │ ENSG00000092841    │ 2_0            │ 0.909091           │
# │ 24  │ ENSG00000092841    │ 2_1            │ 0.909091           │
# │ 25  │ ENSG00000092841    │ 2_2            │ 1.0                │
# │ 26  │ ENSG00000092841    │ 4_0            │ 1.0                │
# │ 27  │ ENSG00000092841    │ 4_1            │ 1.0                │
# │ 28  │ ENSG00000092841    │ 1_4            │ 0.454545           │
# │ 29  │ ENSG00000092841    │ 8_0            │ 0.272727           │
# │ 30  │ ENSG00000092841    │ 1_1            │ 0.181818           │
# │ 31  │ ENSG00000092841    │ 4_2            │ 0.181818           │
# │ 32  │ ENSG00000092841    │ 5_0            │ 0.0909091          │
# │ 33  │ ENSMUSG00000090841 │ 0_2            │ 1.0                │
# │ 34  │ ENSMUSG00000090841 │ 1_3            │ 1.0                │
# │ 35  │ ENSMUSG00000090841 │ 3_0            │ 0.8                │
# │ 36  │ ENSMUSG00000090841 │ 3_1            │ 1.0                │
# │ 37  │ ENSMUSG00000090841 │ 3_2            │ 1.0                │
# │ 38  │ ENSMUSG00000090841 │ 3_3            │ 1.0                │
# │ 39  │ ENSMUSG00000090841 │ 2_0            │ 1.0                │
# │ 40  │ ENSMUSG00000090841 │ 2_1            │ 1.0                │
# │ 41  │ ENSMUSG00000090841 │ 2_2            │ 1.0                │
# │ 42  │ ENSMUSG00000090841 │ 4_0            │ 1.0                │
# │ 43  │ ENSMUSG00000090841 │ 4_1            │ 1.0                │
# │ 44  │ ENSMUSG00000090841 │ 1_4            │ 0.4                │
# │ 45  │ ENSMUSG00000090841 │ 0_3            │ 1.0                │
# │ 46  │ ENSMUSG00000090841 │ 4_2            │ 0.2                │
# │ 47  │ ENSMUSG00000090841 │ 0_6            │ 1.0                │
# │ 48  │ ENSMUSG00000090841 │ 6_0            │ 0.2                │
# │ 49  │ ENSMUSG00000090841 │ 0_4            │ 1.0                │
# │ 50  │ ENSMUSG00000090841 │ 0_5            │ 1.0                │
# │ 51  │ ENSMUSG00000090841 │ 8_0            │ 0.2                │
# │ 52  │ ENSRNOG00000054140 │ 0_7            │ 1.0                │
# │ 53  │ ENSRNOG00000054140 │ 1_3            │ 1.0                │
# │ 54  │ ENSRNOG00000054140 │ 3_0            │ 1.0                │
# │ 55  │ ENSRNOG00000054140 │ 3_1            │ 1.0                │
# │ 56  │ ENSRNOG00000054140 │ 3_2            │ 1.0                │
# │ 57  │ ENSRNOG00000054140 │ 3_3            │ 1.0                │
# │ 58  │ ENSRNOG00000054140 │ 2_0            │ 1.0                │
# │ 59  │ ENSRNOG00000054140 │ 2_1            │ 0.666667           │
# │ 60  │ ENSRNOG00000054140 │ 2_2            │ 0.666667           │
# │ 61  │ ENSRNOG00000054140 │ 4_0            │ 0.666667           │
# │ 62  │ ENSRNOG00000054140 │ 4_1            │ 0.666667           │
# │ 63  │ ENSRNOG00000054140 │ 4_2            │ 0.333333           │
# │ 64  │ ENSRNOG00000054140 │ 0_8            │ 1.0                │
# │ 65  │ ENSRNOG00000054140 │ 7_0            │ 0.333333           │
# │ 66  │ ENSRNOG00000054140 │ 0_10           │ 0.333333           │
# │ 67  │ ENSRNOG00000054140 │ 0_9            │ 1.0                │
# │ 68  │ ENSRNOG00000054140 │ 1_4            │ 0.333333           │
# │ 69  │ ENSSSCG00000039795 │ 0_11           │ 0.5                │
# │ 70  │ ENSSSCG00000039795 │ 1_3            │ 1.0                │
# │ 71  │ ENSSSCG00000039795 │ 3_0            │ 1.0                │
# │ 72  │ ENSSSCG00000039795 │ 3_1            │ 1.0                │
# │ 73  │ ENSSSCG00000039795 │ 3_2            │ 1.0                │
# │ 74  │ ENSSSCG00000039795 │ 3_3            │ 1.0                │
# │ 75  │ ENSSSCG00000039795 │ 2_0            │ 1.0                │
# │ 76  │ ENSSSCG00000039795 │ 2_1            │ 1.0                │
# │ 77  │ ENSSSCG00000039795 │ 2_2            │ 1.0                │
# │ 78  │ ENSSSCG00000039795 │ 4_0            │ 1.0                │
# │ 79  │ ENSSSCG00000039795 │ 4_1            │ 1.0                │
# │ 80  │ ENSSSCG00000039795 │ 8_0            │ 1.0                │
# │ 81  │ ENSSSCG00000039795 │ 1_1            │ 0.5                │
# │ 82  │ ENSSSCG00000039795 │ 1_2            │ 0.5                │
#
# │ Row │ TranscriptsWithSubexon │ TranscriptsInGene │
# │     │ Int64                  │ Int64             │
# ├─────┼────────────────────────┼───────────────────┤
# │ 1   │ 1                      │ 3                 │
# │ 2   │ 3                      │ 3                 │
# │ 3   │ 3                      │ 3                 │
# │ 4   │ 3                      │ 3                 │
# │ 5   │ 2                      │ 3                 │
# │ 6   │ 3                      │ 3                 │
# │ 7   │ 3                      │ 3                 │
# │ 8   │ 3                      │ 3                 │
# │ 9   │ 3                      │ 3                 │
# │ 10  │ 3                      │ 3                 │
# │ 11  │ 3                      │ 3                 │
# │ 12  │ 2                      │ 3                 │
# │ 13  │ 1                      │ 3                 │
# │ 14  │ 1                      │ 3                 │
# │ 15  │ 1                      │ 3                 │
# │ 16  │ 10                     │ 11                │
# │ 17  │ 4                      │ 11                │
# │ 18  │ 10                     │ 11                │
# │ 19  │ 8                      │ 11                │
# │ 20  │ 7                      │ 11                │
# │ 21  │ 7                      │ 11                │
# │ 22  │ 7                      │ 11                │
# │ 23  │ 10                     │ 11                │
# │ 24  │ 10                     │ 11                │
# │ 25  │ 11                     │ 11                │
# │ 26  │ 11                     │ 11                │
# │ 27  │ 11                     │ 11                │
# │ 28  │ 5                      │ 11                │
# │ 29  │ 3                      │ 11                │
# │ 30  │ 2                      │ 11                │
# │ 31  │ 2                      │ 11                │
# │ 32  │ 1                      │ 11                │
# │ 33  │ 5                      │ 5                 │
# │ 34  │ 5                      │ 5                 │
# │ 35  │ 4                      │ 5                 │
# │ 36  │ 5                      │ 5                 │
# │ 37  │ 5                      │ 5                 │
# │ 38  │ 5                      │ 5                 │
# │ 39  │ 5                      │ 5                 │
# │ 40  │ 5                      │ 5                 │
# │ 41  │ 5                      │ 5                 │
# │ 42  │ 5                      │ 5                 │
# │ 43  │ 5                      │ 5                 │
# │ 44  │ 2                      │ 5                 │
# │ 45  │ 5                      │ 5                 │
# │ 46  │ 1                      │ 5                 │
# │ 47  │ 5                      │ 5                 │
# │ 48  │ 1                      │ 5                 │
# │ 49  │ 5                      │ 5                 │
# │ 50  │ 5                      │ 5                 │
# │ 51  │ 1                      │ 5                 │
# │ 52  │ 3                      │ 3                 │
# │ 53  │ 3                      │ 3                 │
# │ 54  │ 3                      │ 3                 │
# │ 55  │ 3                      │ 3                 │
# │ 56  │ 3                      │ 3                 │
# │ 57  │ 3                      │ 3                 │
# │ 58  │ 3                      │ 3                 │
# │ 59  │ 2                      │ 3                 │
# │ 60  │ 2                      │ 3                 │
# │ 61  │ 2                      │ 3                 │
# │ 62  │ 2                      │ 3                 │
# │ 63  │ 1                      │ 3                 │
# │ 64  │ 3                      │ 3                 │
# │ 65  │ 1                      │ 3                 │
# │ 66  │ 1                      │ 3                 │
# │ 67  │ 3                      │ 3                 │
# │ 68  │ 1                      │ 3                 │
# │ 69  │ 1                      │ 2                 │
# │ 70  │ 2                      │ 2                 │
# │ 71  │ 2                      │ 2                 │
# │ 72  │ 2                      │ 2                 │
# │ 73  │ 2                      │ 2                 │
# │ 74  │ 2                      │ 2                 │
# │ 75  │ 2                      │ 2                 │
# │ 76  │ 2                      │ 2                 │
# │ 77  │ 2                      │ 2                 │
# │ 78  │ 2                      │ 2                 │
# │ 79  │ 2                      │ 2                 │
# │ 80  │ 2                      │ 2                 │
# │ 81  │ 1                      │ 2                 │
# │ 82  │ 1                      │ 2                 │
