# %%
using Statistics
using CSV
using DataFrames
using Measures
using Gadfly

ENV["LINES"] = 9;
# Out:
# ┌ Info: Loading DataFrames support into Gadfly.jl
# └ @ Gadfly C:\Users\Diego\.julia\packages\Gadfly\09PWZ\src\mapping.jl:228

# %%
# parameters
protein = "MYO1D"
# Out:
# "MYO1D"

# %%
function path_to_TranscriptAnnotation()
    folders = String[]
    for folder in splitpath(pwd())
        push!(folders, folder)
        if folder == "TranscriptAnnotation"
            break
        end
    end
    joinpath(folders...)
end

results_folder = joinpath(path_to_TranscriptAnnotation(), "benchmark", protein)
table_path = joinpath(results_folder, "thoraxe", "homologous_exon_table.csv")

const table = CSV.read(table_path);

# %% [markdown]
# ## Transcripts per species

# %%
by(table, :Species, :TranscriptIDCluster => length ∘ unique) |> 
    df -> rename!(df, :TranscriptIDCluster_function => :Transcripts) |>
    df -> show(df, allcols=true, allrows=true)
# Out:
# 10×2 DataFrame
# │ Row │ Species               │ Transcripts │
# │     │ String                │ Int64       │
# ├─────┼───────────────────────┼─────────────┤
# │ 1   │ bos_taurus            │ 2           │
# │ 2   │ danio_rerio           │ 1           │
# │ 3   │ homo_sapiens          │ 3           │
# │ 4   │ gorilla_gorilla       │ 5           │
# │ 5   │ macaca_mulatta        │ 3           │
# │ 6   │ monodelphis_domestica │ 1           │
# │ 7   │ mus_musculus          │ 1           │
# │ 8   │ rattus_norvegicus     │ 1           │
# │ 9   │ sus_scrofa            │ 2           │
# │ 10  │ xenopus_tropicalis    │ 1           │

# %% [markdown]
# ## (Sub)exons without (known) homology

# %%
total = sum(startswith(exonid, "0_") for exonid in unique(table[:HomologousExon]))
print("Number of (sub)exons without (known) homology in the gene: ", total)
# Out:
# Number of (sub)exons without (known) homology in the gene: 3

# %%
by(table, :Species) do df
    (ExonsWithoutHomology = sum(startswith(exonid, "0_") for exonid in unique(df[:HomologousExon])), )
end |> df -> show(df, allcols=true, allrows=true)
# Out:
# 10×2 DataFrame
# │ Row │ Species               │ ExonsWithoutHomology │
# │     │ String                │ Int64                │
# ├─────┼───────────────────────┼──────────────────────┤
# │ 1   │ bos_taurus            │ 0                    │
# │ 2   │ danio_rerio           │ 0                    │
# │ 3   │ homo_sapiens          │ 0                    │
# │ 4   │ gorilla_gorilla       │ 2                    │
# │ 5   │ macaca_mulatta        │ 1                    │
# │ 6   │ monodelphis_domestica │ 0                    │
# │ 7   │ mus_musculus          │ 0                    │
# │ 8   │ rattus_norvegicus     │ 0                    │
# │ 9   │ sus_scrofa            │ 0                    │
# │ 10  │ xenopus_tropicalis    │ 0                    │

# %% [markdown]
# ### Short exons

# %% [markdown]
# Some subexons doesn't have known homologs because they are too short

# %%
by(table, [:TranscriptIDCluster, :ExonIDCluster], :SubexonProteinSequence => join) |>
    df -> by(df, 
        :ExonIDCluster, 
        :SubexonProteinSequence_join => col -> minimum(map(x -> length(replace(x, "*" => "")), col))) |>
    df -> rename!(df, :SubexonProteinSequence_join_function => :ExonLength) |>
    df -> df[df[:ExonLength] .≤ 4, :] |>
    df -> show(df, allcols=true, allrows=true)
# Out:
# 3×2 DataFrame
# │ Row │ ExonIDCluster      │ ExonLength │
# │     │ String             │ Int64      │
# ├─────┼────────────────────┼────────────┤
# │ 1   │ ENSE00002688700    │ 4          │
# │ 2   │ ENSGGOE00000346670 │ 4          │
# │ 3   │ ENSMMUE00000424182 │ 4          │

# %% [markdown]
# ## Putative orthologous exons

# %%
total = sum(!startswith(exonid, "0_") for exonid in unique(table[:HomologousExon]))
print("Number of putative orthologous exons in the gene: ", total)
# Out:
# Number of putative orthologous exons in the gene: 33

# %%
by(table, :Species) do df
    (ExonsWithoutHomology = sum(!startswith(exonid, "0_") for exonid in unique(df[:HomologousExon])), )
end |> df -> show(df, allcols=true, allrows=true)
# Out:
# 10×2 DataFrame
# │ Row │ Species               │ ExonsWithoutHomology │
# │     │ String                │ Int64                │
# ├─────┼───────────────────────┼──────────────────────┤
# │ 1   │ bos_taurus            │ 24                   │
# │ 2   │ danio_rerio           │ 24                   │
# │ 3   │ homo_sapiens          │ 26                   │
# │ 4   │ gorilla_gorilla       │ 28                   │
# │ 5   │ macaca_mulatta        │ 27                   │
# │ 6   │ monodelphis_domestica │ 24                   │
# │ 7   │ mus_musculus          │ 22                   │
# │ 8   │ rattus_norvegicus     │ 24                   │
# │ 9   │ sus_scrofa            │ 25                   │
# │ 10  │ xenopus_tropicalis    │ 24                   │

# %% [markdown]
# ## Exon Lengths

# %% [markdown]
# Distribution of homologous exon lengths

# %%
len(x) = ismissing(x) ? 0 : length(x)

const lengths = by(table, :HomologousExon, :HomologousExonSequence => col -> maximum(len.(col))) |> 
    df -> rename!(df, :HomologousExonSequence_function  => :HomologousExonLength ) |>
    df -> sort!(df, :HomologousExon) 

show(lengths, allrows=true)
# Out:
# 36×2 DataFrame
# │ Row │ HomologousExon │ HomologousExonLength │
# │     │ String         │ Int64                │
# ├─────┼────────────────┼──────────────────────┤
# │ 1   │ 0_1            │ 0                    │
# │ 2   │ 0_2            │ 15                   │
# │ 3   │ 0_3            │ 27                   │
# │ 4   │ 10_0           │ 49                   │
# │ 5   │ 11_0           │ 48                   │
# │ 6   │ 12_0           │ 44                   │
# │ 7   │ 13_0           │ 41                   │
# │ 8   │ 14_0           │ 39                   │
# │ 9   │ 14_1           │ 20                   │
# │ 10  │ 15_0           │ 39                   │
# │ 11  │ 16_0           │ 38                   │
# │ 12  │ 17_0           │ 38                   │
# │ 13  │ 18_0           │ 38                   │
# │ 14  │ 19_0           │ 35                   │
# │ 15  │ 1_0            │ 75                   │
# │ 16  │ 20_0           │ 32                   │
# │ 17  │ 21_0           │ 31                   │
# │ 18  │ 21_1           │ 7                    │
# │ 19  │ 23_0           │ 25                   │
# │ 20  │ 24_0           │ 24                   │
# │ 21  │ 25_0           │ 18                   │
# │ 22  │ 2_0            │ 56                   │
# │ 23  │ 2_1            │ 14                   │
# │ 24  │ 2_2            │ 7                    │
# │ 25  │ 3_0            │ 6                    │
# │ 26  │ 3_1            │ 69                   │
# │ 27  │ 4_0            │ 68                   │
# │ 28  │ 4_1            │ 4                    │
# │ 29  │ 4_2            │ 6                    │
# │ 30  │ 5_0            │ 57                   │
# │ 31  │ 5_1            │ 6                    │
# │ 32  │ 6_0            │ 56                   │
# │ 33  │ 7_0            │ 55                   │
# │ 34  │ 8_0            │ 46                   │
# │ 35  │ 8_1            │ 7                    │
# │ 36  │ 9_0            │ 51                   │

# %%
lengths[:WithHomologous] = [ !startswith(exonid, "0_") for exonid in lengths[:HomologousExon ] ];

# %%
plt = plot(lengths, x="HomologousExonLength", color="WithHomologous", Geom.histogram)
draw(SVG(25cm, 15cm), plt)
# Out:
# SVG(250.0mm, 150.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=21364, maxsize=Inf, ptr=21365, mark=-1), nothing, "img-5ac6aa61", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Property}}(Property{JSIncludePrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{StrokePrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{FontSizePrimitive}=>nothing,Property{SVGAttributePrimitive}=>nothing,Property{StrokeDashPrimitive}=>nothing,Property{SVGClassPrimitive}=>nothing,Property{FontPrimitive}=>nothing,Property{LineWidthPrimitive}=>nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Length{:mm,Float64},Length{:mm,Float64}}[(8.67333mm, 5.0mm), (216.29mm, 5.0mm), (216.29mm, 130.715mm), (8.67333mm, 130.715mm)])=>"img-5ac6aa61-13"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-5ac6aa61-111", false, 111, Set(AbstractString["C:\\Users\\Diego\\.julia\\packages\\Gadfly\\09PWZ\\src\\gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-5ac6aa61-4\")\n   .drag(function() {}, function() {}, function() {});", "fig.select(\"#img-5ac6aa61-6\")\n   .data(\"color_class\", \"color_false\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-7\")\n   .data(\"color_class\", \"color_true\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-9\")\n   .data(\"color_class\", \"color_false\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-10\")\n   .data(\"color_class\", \"color_true\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-14\")\n   .init_gadfly();"], false, :none, (BoundingBox{Tuple{Length{:mm,Float64},Length{:mm,Float64}},Tuple{Length{:mm,Float64},Length{:mm,Float64}}}((8.673333333333346mm, 5.0mm), (207.61666666666667mm, 125.71499999999999mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-0.7857902922157649, 3.049295485355133, 81.57158058443153, -3.0985909707102657, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %% [markdown]
# ## Alternative spliced homologous exons

# %% [markdown]
# Exons with a `TranscriptFraction` of `1.0` in a gene are constitutive. The plot can help to identify homologous_exons that change their `TranscriptFraction` in different genes.

# %%
constitutive = by(table, :GeneID) do df
    subdf = unique(df[:, [:HomologousExon, :TranscriptsWithSubexon, :TranscriptsInGene]])
    by(subdf, :HomologousExon) do exondf
        (TranscriptFraction = exondf[1, :TranscriptsWithSubexon] / exondf[1, :TranscriptsInGene],
         TranscriptsWithSubexon = exondf[1, :TranscriptsWithSubexon],
         TranscriptsInGene = exondf[1, :TranscriptsInGene])
    end
end;

# %%
plt = plot(constitutive, x="HomologousExon", y="TranscriptFraction", Geom.point)
draw(SVG(25cm, 15cm), plt)
# Out:
# SVG(250.0mm, 150.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=111028, maxsize=Inf, ptr=111029, mark=-1), nothing, "img-490bdd3f", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Property}}(Property{JSIncludePrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{StrokePrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{FontSizePrimitive}=>nothing,Property{SVGAttributePrimitive}=>nothing,Property{StrokeDashPrimitive}=>nothing,Property{SVGClassPrimitive}=>nothing,Property{FontPrimitive}=>nothing,Property{LineWidthPrimitive}=>nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Length{:mm,Float64},Length{:mm,Float64}}[(18.6317mm, 5.0mm), (245.0mm, 5.0mm), (245.0mm, 130.715mm), (18.6317mm, 130.715mm)])=>"img-490bdd3f-4"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-490bdd3f-809", false, 809, Set(AbstractString["C:\\Users\\Diego\\.julia\\packages\\Gadfly\\09PWZ\\src\\gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-490bdd3f-5\")\n   .init_gadfly();"], false, :none, (BoundingBox{Tuple{Length{:mm,Float64},Length{:mm,Float64}},Tuple{Length{:mm,Float64},Length{:mm,Float64}}}((18.63166666666669mm, 5.0mm), (226.36833333333334mm, 125.715mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(0.5, 1.0164318284517109, 36.0, -1.032863656903422, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
show(constitutive, allrows=true, allcols=true)
# Out:
# 251×5 DataFrame
# │ Row │ GeneID             │ HomologousExon │ TranscriptFraction │
# │     │ String             │ String         │ Float64            │
# ├─────┼────────────────────┼────────────────┼────────────────────┤
# │ 1   │ ENSBTAG00000015527 │ 18_0           │ 1.0                │
# │ 2   │ ENSBTAG00000015527 │ 2_0            │ 1.0                │
# │ 3   │ ENSBTAG00000015527 │ 2_1            │ 1.0                │
# │ 4   │ ENSBTAG00000015527 │ 21_0           │ 1.0                │
# │ 5   │ ENSBTAG00000015527 │ 7_0            │ 1.0                │
# │ 6   │ ENSBTAG00000015527 │ 25_0           │ 0.5                │
# │ 7   │ ENSBTAG00000015527 │ 20_0           │ 1.0                │
# │ 8   │ ENSBTAG00000015527 │ 14_0           │ 1.0                │
# │ 9   │ ENSBTAG00000015527 │ 4_0            │ 1.0                │
# │ 10  │ ENSBTAG00000015527 │ 10_0           │ 1.0                │
# │ 11  │ ENSBTAG00000015527 │ 17_0           │ 1.0                │
# │ 12  │ ENSBTAG00000015527 │ 5_0            │ 1.0                │
# │ 13  │ ENSBTAG00000015527 │ 24_0           │ 1.0                │
# │ 14  │ ENSBTAG00000015527 │ 23_0           │ 1.0                │
# │ 15  │ ENSBTAG00000015527 │ 12_0           │ 1.0                │
# │ 16  │ ENSBTAG00000015527 │ 6_0            │ 1.0                │
# │ 17  │ ENSBTAG00000015527 │ 3_1            │ 1.0                │
# │ 18  │ ENSBTAG00000015527 │ 1_0            │ 1.0                │
# │ 19  │ ENSBTAG00000015527 │ 11_0           │ 1.0                │
# │ 20  │ ENSBTAG00000015527 │ 19_0           │ 1.0                │
# │ 21  │ ENSBTAG00000015527 │ 16_0           │ 1.0                │
# │ 22  │ ENSBTAG00000015527 │ 8_0            │ 1.0                │
# │ 23  │ ENSBTAG00000015527 │ 8_1            │ 1.0                │
# │ 24  │ ENSBTAG00000015527 │ 9_0            │ 1.0                │
# │ 25  │ ENSDARG00000036863 │ 18_0           │ 1.0                │
# │ 26  │ ENSDARG00000036863 │ 2_0            │ 1.0                │
# │ 27  │ ENSDARG00000036863 │ 2_1            │ 1.0                │
# │ 28  │ ENSDARG00000036863 │ 21_0           │ 1.0                │
# │ 29  │ ENSDARG00000036863 │ 7_0            │ 1.0                │
# │ 30  │ ENSDARG00000036863 │ 25_0           │ 1.0                │
# │ 31  │ ENSDARG00000036863 │ 20_0           │ 1.0                │
# │ 32  │ ENSDARG00000036863 │ 14_0           │ 1.0                │
# │ 33  │ ENSDARG00000036863 │ 4_0            │ 1.0                │
# │ 34  │ ENSDARG00000036863 │ 10_0           │ 1.0                │
# │ 35  │ ENSDARG00000036863 │ 17_0           │ 1.0                │
# │ 36  │ ENSDARG00000036863 │ 5_0            │ 1.0                │
# │ 37  │ ENSDARG00000036863 │ 24_0           │ 1.0                │
# │ 38  │ ENSDARG00000036863 │ 23_0           │ 1.0                │
# │ 39  │ ENSDARG00000036863 │ 12_0           │ 1.0                │
# │ 40  │ ENSDARG00000036863 │ 6_0            │ 1.0                │
# │ 41  │ ENSDARG00000036863 │ 3_1            │ 1.0                │
# │ 42  │ ENSDARG00000036863 │ 1_0            │ 1.0                │
# │ 43  │ ENSDARG00000036863 │ 11_0           │ 1.0                │
# │ 44  │ ENSDARG00000036863 │ 19_0           │ 1.0                │
# │ 45  │ ENSDARG00000036863 │ 16_0           │ 1.0                │
# │ 46  │ ENSDARG00000036863 │ 8_0            │ 1.0                │
# │ 47  │ ENSDARG00000036863 │ 8_1            │ 1.0                │
# │ 48  │ ENSDARG00000036863 │ 9_0            │ 1.0                │
# │ 49  │ ENSG00000176658    │ 18_0           │ 1.0                │
# │ 50  │ ENSG00000176658    │ 2_0            │ 1.0                │
# │ 51  │ ENSG00000176658    │ 2_1            │ 1.0                │
# │ 52  │ ENSG00000176658    │ 21_0           │ 1.0                │
# │ 53  │ ENSG00000176658    │ 7_0            │ 1.0                │
# │ 54  │ ENSG00000176658    │ 25_0           │ 1.0                │
# │ 55  │ ENSG00000176658    │ 20_0           │ 1.0                │
# │ 56  │ ENSG00000176658    │ 14_0           │ 1.0                │
# │ 57  │ ENSG00000176658    │ 4_0            │ 1.0                │
# │ 58  │ ENSG00000176658    │ 10_0           │ 1.0                │
# │ 59  │ ENSG00000176658    │ 17_0           │ 1.0                │
# │ 60  │ ENSG00000176658    │ 5_0            │ 0.666667           │
# │ 61  │ ENSG00000176658    │ 24_0           │ 0.666667           │
# │ 62  │ ENSG00000176658    │ 23_0           │ 0.666667           │
# │ 63  │ ENSG00000176658    │ 12_0           │ 0.666667           │
# │ 64  │ ENSG00000176658    │ 6_0            │ 0.666667           │
# │ 65  │ ENSG00000176658    │ 3_1            │ 0.666667           │
# │ 66  │ ENSG00000176658    │ 1_0            │ 0.666667           │
# │ 67  │ ENSG00000176658    │ 11_0           │ 0.666667           │
# │ 68  │ ENSG00000176658    │ 19_0           │ 0.666667           │
# │ 69  │ ENSG00000176658    │ 16_0           │ 0.666667           │
# │ 70  │ ENSG00000176658    │ 8_0            │ 0.666667           │
# │ 71  │ ENSG00000176658    │ 8_1            │ 0.666667           │
# │ 72  │ ENSG00000176658    │ 9_0            │ 0.333333           │
# │ 73  │ ENSG00000176658    │ 4_2            │ 0.333333           │
# │ 74  │ ENSG00000176658    │ 4_1            │ 0.333333           │
# │ 75  │ ENSGGOG00000000276 │ 2_0            │ 0.8                │
# │ 76  │ ENSGGOG00000000276 │ 2_1            │ 1.0                │
# │ 77  │ ENSGGOG00000000276 │ 21_0           │ 1.0                │
# │ 78  │ ENSGGOG00000000276 │ 7_0            │ 1.0                │
# │ 79  │ ENSGGOG00000000276 │ 25_0           │ 1.0                │
# │ 80  │ ENSGGOG00000000276 │ 20_0           │ 1.0                │
# │ 81  │ ENSGGOG00000000276 │ 14_0           │ 1.0                │
# │ 82  │ ENSGGOG00000000276 │ 4_0            │ 1.0                │
# │ 83  │ ENSGGOG00000000276 │ 10_0           │ 1.0                │
# │ 84  │ ENSGGOG00000000276 │ 17_0           │ 1.0                │
# │ 85  │ ENSGGOG00000000276 │ 5_0            │ 0.8                │
# │ 86  │ ENSGGOG00000000276 │ 24_0           │ 0.8                │
# │ 87  │ ENSGGOG00000000276 │ 23_0           │ 0.8                │
# │ 88  │ ENSGGOG00000000276 │ 12_0           │ 0.8                │
# │ 89  │ ENSGGOG00000000276 │ 6_0            │ 0.8                │
# │ 90  │ ENSGGOG00000000276 │ 3_1            │ 0.8                │
# │ 91  │ ENSGGOG00000000276 │ 1_0            │ 0.8                │
# │ 92  │ ENSGGOG00000000276 │ 11_0           │ 0.8                │
# │ 93  │ ENSGGOG00000000276 │ 19_0           │ 0.8                │
# │ 94  │ ENSGGOG00000000276 │ 16_0           │ 0.8                │
# │ 95  │ ENSGGOG00000000276 │ 8_0            │ 0.8                │
# │ 96  │ ENSGGOG00000000276 │ 8_1            │ 0.8                │
# │ 97  │ ENSGGOG00000000276 │ 4_2            │ 0.2                │
# │ 98  │ ENSGGOG00000000276 │ 3_0            │ 0.2                │
# │ 99  │ ENSGGOG00000000276 │ 0_1            │ 0.2                │
# │ 100 │ ENSGGOG00000000276 │ 15_0           │ 0.2                │
# │ 101 │ ENSGGOG00000000276 │ 9_0            │ 0.2                │
# │ 102 │ ENSGGOG00000000276 │ 21_1           │ 0.2                │
# │ 103 │ ENSGGOG00000000276 │ 0_2            │ 0.2                │
# │ 104 │ ENSGGOG00000000276 │ 4_1            │ 0.2                │
# │ 105 │ ENSMMUG00000014689 │ 18_0           │ 1.0                │
# │ 106 │ ENSMMUG00000014689 │ 2_0            │ 1.0                │
# │ 107 │ ENSMMUG00000014689 │ 2_1            │ 1.0                │
# │ 108 │ ENSMMUG00000014689 │ 21_0           │ 1.0                │
# │ 109 │ ENSMMUG00000014689 │ 7_0            │ 1.0                │
# │ 110 │ ENSMMUG00000014689 │ 25_0           │ 1.0                │
# │ 111 │ ENSMMUG00000014689 │ 20_0           │ 1.0                │
# │ 112 │ ENSMMUG00000014689 │ 14_0           │ 1.0                │
# │ 113 │ ENSMMUG00000014689 │ 4_0            │ 1.0                │
# │ 114 │ ENSMMUG00000014689 │ 10_0           │ 1.0                │
# │ 115 │ ENSMMUG00000014689 │ 17_0           │ 1.0                │
# │ 116 │ ENSMMUG00000014689 │ 5_0            │ 0.666667           │
# │ 117 │ ENSMMUG00000014689 │ 5_1            │ 0.333333           │
# │ 118 │ ENSMMUG00000014689 │ 2_2            │ 0.333333           │
# │ 119 │ ENSMMUG00000014689 │ 23_0           │ 0.666667           │
# │ 120 │ ENSMMUG00000014689 │ 12_0           │ 0.666667           │
# │ 121 │ ENSMMUG00000014689 │ 6_0            │ 0.666667           │
# │ 122 │ ENSMMUG00000014689 │ 3_1            │ 0.666667           │
# │ 123 │ ENSMMUG00000014689 │ 1_0            │ 0.666667           │
# │ 124 │ ENSMMUG00000014689 │ 11_0           │ 0.666667           │
# │ 125 │ ENSMMUG00000014689 │ 19_0           │ 0.666667           │
# │ 126 │ ENSMMUG00000014689 │ 16_0           │ 0.666667           │
# │ 127 │ ENSMMUG00000014689 │ 8_0            │ 0.666667           │
# │ 128 │ ENSMMUG00000014689 │ 0_3            │ 0.333333           │
# │ 129 │ ENSMMUG00000014689 │ 4_1            │ 0.333333           │
# │ 130 │ ENSMMUG00000014689 │ 24_0           │ 0.333333           │
# │ 131 │ ENSMMUG00000014689 │ 8_1            │ 0.333333           │
# │ 132 │ ENSMMUG00000014689 │ 9_0            │ 0.333333           │
# │ 133 │ ENSMODG00000019177 │ 18_0           │ 1.0                │
# │ 134 │ ENSMODG00000019177 │ 2_0            │ 1.0                │
# │ 135 │ ENSMODG00000019177 │ 2_1            │ 1.0                │
# │ 136 │ ENSMODG00000019177 │ 21_0           │ 1.0                │
# │ 137 │ ENSMODG00000019177 │ 7_0            │ 1.0                │
# │ 138 │ ENSMODG00000019177 │ 25_0           │ 1.0                │
# │ 139 │ ENSMODG00000019177 │ 20_0           │ 1.0                │
# │ 140 │ ENSMODG00000019177 │ 14_0           │ 1.0                │
# │ 141 │ ENSMODG00000019177 │ 4_0            │ 1.0                │
# │ 142 │ ENSMODG00000019177 │ 10_0           │ 1.0                │
# │ 143 │ ENSMODG00000019177 │ 17_0           │ 1.0                │
# │ 144 │ ENSMODG00000019177 │ 5_0            │ 1.0                │
# │ 145 │ ENSMODG00000019177 │ 24_0           │ 1.0                │
# │ 146 │ ENSMODG00000019177 │ 23_0           │ 1.0                │
# │ 147 │ ENSMODG00000019177 │ 12_0           │ 1.0                │
# │ 148 │ ENSMODG00000019177 │ 6_0            │ 1.0                │
# │ 149 │ ENSMODG00000019177 │ 3_1            │ 1.0                │
# │ 150 │ ENSMODG00000019177 │ 1_0            │ 1.0                │
# │ 151 │ ENSMODG00000019177 │ 11_0           │ 1.0                │
# │ 152 │ ENSMODG00000019177 │ 19_0           │ 1.0                │
# │ 153 │ ENSMODG00000019177 │ 16_0           │ 1.0                │
# │ 154 │ ENSMODG00000019177 │ 8_0            │ 1.0                │
# │ 155 │ ENSMODG00000019177 │ 8_1            │ 1.0                │
# │ 156 │ ENSMODG00000019177 │ 9_0            │ 1.0                │
# │ 157 │ ENSMUSG00000035441 │ 18_0           │ 1.0                │
# │ 158 │ ENSMUSG00000035441 │ 2_0            │ 1.0                │
# │ 159 │ ENSMUSG00000035441 │ 2_1            │ 1.0                │
# │ 160 │ ENSMUSG00000035441 │ 21_0           │ 1.0                │
# │ 161 │ ENSMUSG00000035441 │ 7_0            │ 1.0                │
# │ 162 │ ENSMUSG00000035441 │ 25_0           │ 1.0                │
# │ 163 │ ENSMUSG00000035441 │ 20_0           │ 1.0                │
# │ 164 │ ENSMUSG00000035441 │ 14_0           │ 1.0                │
# │ 165 │ ENSMUSG00000035441 │ 4_0            │ 1.0                │
# │ 166 │ ENSMUSG00000035441 │ 10_0           │ 1.0                │
# │ 167 │ ENSMUSG00000035441 │ 17_0           │ 1.0                │
# │ 168 │ ENSMUSG00000035441 │ 5_0            │ 1.0                │
# │ 169 │ ENSMUSG00000035441 │ 24_0           │ 1.0                │
# │ 170 │ ENSMUSG00000035441 │ 23_0           │ 1.0                │
# │ 171 │ ENSMUSG00000035441 │ 12_0           │ 1.0                │
# │ 172 │ ENSMUSG00000035441 │ 6_0            │ 1.0                │
# │ 173 │ ENSMUSG00000035441 │ 3_1            │ 1.0                │
# │ 174 │ ENSMUSG00000035441 │ 1_0            │ 1.0                │
# │ 175 │ ENSMUSG00000035441 │ 11_0           │ 1.0                │
# │ 176 │ ENSMUSG00000035441 │ 19_0           │ 1.0                │
# │ 177 │ ENSMUSG00000035441 │ 16_0           │ 1.0                │
# │ 178 │ ENSMUSG00000035441 │ 13_0           │ 1.0                │
# │ 179 │ ENSRNOG00000003276 │ 18_0           │ 1.0                │
# │ 180 │ ENSRNOG00000003276 │ 2_0            │ 1.0                │
# │ 181 │ ENSRNOG00000003276 │ 2_1            │ 1.0                │
# │ 182 │ ENSRNOG00000003276 │ 21_0           │ 1.0                │
# │ 183 │ ENSRNOG00000003276 │ 7_0            │ 1.0                │
# │ 184 │ ENSRNOG00000003276 │ 25_0           │ 1.0                │
# │ 185 │ ENSRNOG00000003276 │ 20_0           │ 1.0                │
# │ 186 │ ENSRNOG00000003276 │ 14_0           │ 1.0                │
# │ 187 │ ENSRNOG00000003276 │ 4_0            │ 1.0                │
# │ 188 │ ENSRNOG00000003276 │ 10_0           │ 1.0                │
# │ 189 │ ENSRNOG00000003276 │ 17_0           │ 1.0                │
# │ 190 │ ENSRNOG00000003276 │ 5_0            │ 1.0                │
# │ 191 │ ENSRNOG00000003276 │ 24_0           │ 1.0                │
# │ 192 │ ENSRNOG00000003276 │ 23_0           │ 1.0                │
# │ 193 │ ENSRNOG00000003276 │ 12_0           │ 1.0                │
# │ 194 │ ENSRNOG00000003276 │ 6_0            │ 1.0                │
# │ 195 │ ENSRNOG00000003276 │ 3_1            │ 1.0                │
# │ 196 │ ENSRNOG00000003276 │ 1_0            │ 1.0                │
# │ 197 │ ENSRNOG00000003276 │ 11_0           │ 1.0                │
# │ 198 │ ENSRNOG00000003276 │ 19_0           │ 1.0                │
# │ 199 │ ENSRNOG00000003276 │ 16_0           │ 1.0                │
# │ 200 │ ENSRNOG00000003276 │ 8_0            │ 1.0                │
# │ 201 │ ENSRNOG00000003276 │ 8_1            │ 1.0                │
# │ 202 │ ENSRNOG00000003276 │ 9_0            │ 1.0                │
# │ 203 │ ENSSSCG00000017728 │ 18_0           │ 1.0                │
# │ 204 │ ENSSSCG00000017728 │ 2_0            │ 1.0                │
# │ 205 │ ENSSSCG00000017728 │ 2_1            │ 1.0                │
# │ 206 │ ENSSSCG00000017728 │ 21_0           │ 1.0                │
# │ 207 │ ENSSSCG00000017728 │ 7_0            │ 1.0                │
# │ 208 │ ENSSSCG00000017728 │ 25_0           │ 1.0                │
# │ 209 │ ENSSSCG00000017728 │ 20_0           │ 1.0                │
# │ 210 │ ENSSSCG00000017728 │ 14_0           │ 1.0                │
# │ 211 │ ENSSSCG00000017728 │ 4_0            │ 1.0                │
# │ 212 │ ENSSSCG00000017728 │ 10_0           │ 1.0                │
# │ 213 │ ENSSSCG00000017728 │ 17_0           │ 1.0                │
# │ 214 │ ENSSSCG00000017728 │ 5_0            │ 1.0                │
# │ 215 │ ENSSSCG00000017728 │ 24_0           │ 1.0                │
# │ 216 │ ENSSSCG00000017728 │ 23_0           │ 1.0                │
# │ 217 │ ENSSSCG00000017728 │ 12_0           │ 1.0                │
# │ 218 │ ENSSSCG00000017728 │ 6_0            │ 1.0                │
# │ 219 │ ENSSSCG00000017728 │ 3_1            │ 1.0                │
# │ 220 │ ENSSSCG00000017728 │ 1_0            │ 1.0                │
# │ 221 │ ENSSSCG00000017728 │ 11_0           │ 1.0                │
# │ 222 │ ENSSSCG00000017728 │ 19_0           │ 1.0                │
# │ 223 │ ENSSSCG00000017728 │ 16_0           │ 1.0                │
# │ 224 │ ENSSSCG00000017728 │ 8_0            │ 1.0                │
# │ 225 │ ENSSSCG00000017728 │ 8_1            │ 1.0                │
# │ 226 │ ENSSSCG00000017728 │ 14_1           │ 0.5                │
# │ 227 │ ENSSSCG00000017728 │ 9_0            │ 0.5                │
# │ 228 │ ENSXETG00000003194 │ 18_0           │ 1.0                │
# │ 229 │ ENSXETG00000003194 │ 2_0            │ 1.0                │
# │ 230 │ ENSXETG00000003194 │ 2_1            │ 1.0                │
# │ 231 │ ENSXETG00000003194 │ 21_0           │ 1.0                │
# │ 232 │ ENSXETG00000003194 │ 7_0            │ 1.0                │
# │ 233 │ ENSXETG00000003194 │ 25_0           │ 1.0                │
# │ 234 │ ENSXETG00000003194 │ 20_0           │ 1.0                │
# │ 235 │ ENSXETG00000003194 │ 14_0           │ 1.0                │
# │ 236 │ ENSXETG00000003194 │ 4_0            │ 1.0                │
# │ 237 │ ENSXETG00000003194 │ 10_0           │ 1.0                │
# │ 238 │ ENSXETG00000003194 │ 17_0           │ 1.0                │
# │ 239 │ ENSXETG00000003194 │ 5_0            │ 1.0                │
# │ 240 │ ENSXETG00000003194 │ 24_0           │ 1.0                │
# │ 241 │ ENSXETG00000003194 │ 23_0           │ 1.0                │
# │ 242 │ ENSXETG00000003194 │ 12_0           │ 1.0                │
# │ 243 │ ENSXETG00000003194 │ 6_0            │ 1.0                │
# │ 244 │ ENSXETG00000003194 │ 3_1            │ 1.0                │
# │ 245 │ ENSXETG00000003194 │ 1_0            │ 1.0                │
# │ 246 │ ENSXETG00000003194 │ 11_0           │ 1.0                │
# │ 247 │ ENSXETG00000003194 │ 19_0           │ 1.0                │
# │ 248 │ ENSXETG00000003194 │ 16_0           │ 1.0                │
# │ 249 │ ENSXETG00000003194 │ 8_0            │ 1.0                │
# │ 250 │ ENSXETG00000003194 │ 8_1            │ 1.0                │
# │ 251 │ ENSXETG00000003194 │ 9_0            │ 1.0                │
#
# │ Row │ TranscriptsWithSubexon │ TranscriptsInGene │
# │     │ Int64                  │ Int64             │
# ├─────┼────────────────────────┼───────────────────┤
# │ 1   │ 2                      │ 2                 │
# │ 2   │ 2                      │ 2                 │
# │ 3   │ 2                      │ 2                 │
# │ 4   │ 2                      │ 2                 │
# │ 5   │ 2                      │ 2                 │
# │ 6   │ 1                      │ 2                 │
# │ 7   │ 2                      │ 2                 │
# │ 8   │ 2                      │ 2                 │
# │ 9   │ 2                      │ 2                 │
# │ 10  │ 2                      │ 2                 │
# │ 11  │ 2                      │ 2                 │
# │ 12  │ 2                      │ 2                 │
# │ 13  │ 2                      │ 2                 │
# │ 14  │ 2                      │ 2                 │
# │ 15  │ 2                      │ 2                 │
# │ 16  │ 2                      │ 2                 │
# │ 17  │ 2                      │ 2                 │
# │ 18  │ 2                      │ 2                 │
# │ 19  │ 2                      │ 2                 │
# │ 20  │ 2                      │ 2                 │
# │ 21  │ 2                      │ 2                 │
# │ 22  │ 2                      │ 2                 │
# │ 23  │ 2                      │ 2                 │
# │ 24  │ 2                      │ 2                 │
# │ 25  │ 1                      │ 1                 │
# │ 26  │ 1                      │ 1                 │
# │ 27  │ 1                      │ 1                 │
# │ 28  │ 1                      │ 1                 │
# │ 29  │ 1                      │ 1                 │
# │ 30  │ 1                      │ 1                 │
# │ 31  │ 1                      │ 1                 │
# │ 32  │ 1                      │ 1                 │
# │ 33  │ 1                      │ 1                 │
# │ 34  │ 1                      │ 1                 │
# │ 35  │ 1                      │ 1                 │
# │ 36  │ 1                      │ 1                 │
# │ 37  │ 1                      │ 1                 │
# │ 38  │ 1                      │ 1                 │
# │ 39  │ 1                      │ 1                 │
# │ 40  │ 1                      │ 1                 │
# │ 41  │ 1                      │ 1                 │
# │ 42  │ 1                      │ 1                 │
# │ 43  │ 1                      │ 1                 │
# │ 44  │ 1                      │ 1                 │
# │ 45  │ 1                      │ 1                 │
# │ 46  │ 1                      │ 1                 │
# │ 47  │ 1                      │ 1                 │
# │ 48  │ 1                      │ 1                 │
# │ 49  │ 3                      │ 3                 │
# │ 50  │ 3                      │ 3                 │
# │ 51  │ 3                      │ 3                 │
# │ 52  │ 3                      │ 3                 │
# │ 53  │ 3                      │ 3                 │
# │ 54  │ 3                      │ 3                 │
# │ 55  │ 3                      │ 3                 │
# │ 56  │ 3                      │ 3                 │
# │ 57  │ 3                      │ 3                 │
# │ 58  │ 3                      │ 3                 │
# │ 59  │ 3                      │ 3                 │
# │ 60  │ 2                      │ 3                 │
# │ 61  │ 2                      │ 3                 │
# │ 62  │ 2                      │ 3                 │
# │ 63  │ 2                      │ 3                 │
# │ 64  │ 2                      │ 3                 │
# │ 65  │ 2                      │ 3                 │
# │ 66  │ 2                      │ 3                 │
# │ 67  │ 2                      │ 3                 │
# │ 68  │ 2                      │ 3                 │
# │ 69  │ 2                      │ 3                 │
# │ 70  │ 2                      │ 3                 │
# │ 71  │ 2                      │ 3                 │
# │ 72  │ 1                      │ 3                 │
# │ 73  │ 1                      │ 3                 │
# │ 74  │ 1                      │ 3                 │
# │ 75  │ 4                      │ 5                 │
# │ 76  │ 5                      │ 5                 │
# │ 77  │ 5                      │ 5                 │
# │ 78  │ 5                      │ 5                 │
# │ 79  │ 5                      │ 5                 │
# │ 80  │ 5                      │ 5                 │
# │ 81  │ 5                      │ 5                 │
# │ 82  │ 5                      │ 5                 │
# │ 83  │ 5                      │ 5                 │
# │ 84  │ 5                      │ 5                 │
# │ 85  │ 4                      │ 5                 │
# │ 86  │ 4                      │ 5                 │
# │ 87  │ 4                      │ 5                 │
# │ 88  │ 4                      │ 5                 │
# │ 89  │ 4                      │ 5                 │
# │ 90  │ 4                      │ 5                 │
# │ 91  │ 4                      │ 5                 │
# │ 92  │ 4                      │ 5                 │
# │ 93  │ 4                      │ 5                 │
# │ 94  │ 4                      │ 5                 │
# │ 95  │ 4                      │ 5                 │
# │ 96  │ 4                      │ 5                 │
# │ 97  │ 1                      │ 5                 │
# │ 98  │ 1                      │ 5                 │
# │ 99  │ 1                      │ 5                 │
# │ 100 │ 1                      │ 5                 │
# │ 101 │ 1                      │ 5                 │
# │ 102 │ 1                      │ 5                 │
# │ 103 │ 1                      │ 5                 │
# │ 104 │ 1                      │ 5                 │
# │ 105 │ 3                      │ 3                 │
# │ 106 │ 3                      │ 3                 │
# │ 107 │ 3                      │ 3                 │
# │ 108 │ 3                      │ 3                 │
# │ 109 │ 3                      │ 3                 │
# │ 110 │ 3                      │ 3                 │
# │ 111 │ 3                      │ 3                 │
# │ 112 │ 3                      │ 3                 │
# │ 113 │ 3                      │ 3                 │
# │ 114 │ 3                      │ 3                 │
# │ 115 │ 3                      │ 3                 │
# │ 116 │ 2                      │ 3                 │
# │ 117 │ 1                      │ 3                 │
# │ 118 │ 1                      │ 3                 │
# │ 119 │ 2                      │ 3                 │
# │ 120 │ 2                      │ 3                 │
# │ 121 │ 2                      │ 3                 │
# │ 122 │ 2                      │ 3                 │
# │ 123 │ 2                      │ 3                 │
# │ 124 │ 2                      │ 3                 │
# │ 125 │ 2                      │ 3                 │
# │ 126 │ 2                      │ 3                 │
# │ 127 │ 2                      │ 3                 │
# │ 128 │ 1                      │ 3                 │
# │ 129 │ 1                      │ 3                 │
# │ 130 │ 1                      │ 3                 │
# │ 131 │ 1                      │ 3                 │
# │ 132 │ 1                      │ 3                 │
# │ 133 │ 1                      │ 1                 │
# │ 134 │ 1                      │ 1                 │
# │ 135 │ 1                      │ 1                 │
# │ 136 │ 1                      │ 1                 │
# │ 137 │ 1                      │ 1                 │
# │ 138 │ 1                      │ 1                 │
# │ 139 │ 1                      │ 1                 │
# │ 140 │ 1                      │ 1                 │
# │ 141 │ 1                      │ 1                 │
# │ 142 │ 1                      │ 1                 │
# │ 143 │ 1                      │ 1                 │
# │ 144 │ 1                      │ 1                 │
# │ 145 │ 1                      │ 1                 │
# │ 146 │ 1                      │ 1                 │
# │ 147 │ 1                      │ 1                 │
# │ 148 │ 1                      │ 1                 │
# │ 149 │ 1                      │ 1                 │
# │ 150 │ 1                      │ 1                 │
# │ 151 │ 1                      │ 1                 │
# │ 152 │ 1                      │ 1                 │
# │ 153 │ 1                      │ 1                 │
# │ 154 │ 1                      │ 1                 │
# │ 155 │ 1                      │ 1                 │
# │ 156 │ 1                      │ 1                 │
# │ 157 │ 1                      │ 1                 │
# │ 158 │ 1                      │ 1                 │
# │ 159 │ 1                      │ 1                 │
# │ 160 │ 1                      │ 1                 │
# │ 161 │ 1                      │ 1                 │
# │ 162 │ 1                      │ 1                 │
# │ 163 │ 1                      │ 1                 │
# │ 164 │ 1                      │ 1                 │
# │ 165 │ 1                      │ 1                 │
# │ 166 │ 1                      │ 1                 │
# │ 167 │ 1                      │ 1                 │
# │ 168 │ 1                      │ 1                 │
# │ 169 │ 1                      │ 1                 │
# │ 170 │ 1                      │ 1                 │
# │ 171 │ 1                      │ 1                 │
# │ 172 │ 1                      │ 1                 │
# │ 173 │ 1                      │ 1                 │
# │ 174 │ 1                      │ 1                 │
# │ 175 │ 1                      │ 1                 │
# │ 176 │ 1                      │ 1                 │
# │ 177 │ 1                      │ 1                 │
# │ 178 │ 1                      │ 1                 │
# │ 179 │ 1                      │ 1                 │
# │ 180 │ 1                      │ 1                 │
# │ 181 │ 1                      │ 1                 │
# │ 182 │ 1                      │ 1                 │
# │ 183 │ 1                      │ 1                 │
# │ 184 │ 1                      │ 1                 │
# │ 185 │ 1                      │ 1                 │
# │ 186 │ 1                      │ 1                 │
# │ 187 │ 1                      │ 1                 │
# │ 188 │ 1                      │ 1                 │
# │ 189 │ 1                      │ 1                 │
# │ 190 │ 1                      │ 1                 │
# │ 191 │ 1                      │ 1                 │
# │ 192 │ 1                      │ 1                 │
# │ 193 │ 1                      │ 1                 │
# │ 194 │ 1                      │ 1                 │
# │ 195 │ 1                      │ 1                 │
# │ 196 │ 1                      │ 1                 │
# │ 197 │ 1                      │ 1                 │
# │ 198 │ 1                      │ 1                 │
# │ 199 │ 1                      │ 1                 │
# │ 200 │ 1                      │ 1                 │
# │ 201 │ 1                      │ 1                 │
# │ 202 │ 1                      │ 1                 │
# │ 203 │ 2                      │ 2                 │
# │ 204 │ 2                      │ 2                 │
# │ 205 │ 2                      │ 2                 │
# │ 206 │ 2                      │ 2                 │
# │ 207 │ 2                      │ 2                 │
# │ 208 │ 2                      │ 2                 │
# │ 209 │ 2                      │ 2                 │
# │ 210 │ 2                      │ 2                 │
# │ 211 │ 2                      │ 2                 │
# │ 212 │ 2                      │ 2                 │
# │ 213 │ 2                      │ 2                 │
# │ 214 │ 2                      │ 2                 │
# │ 215 │ 2                      │ 2                 │
# │ 216 │ 2                      │ 2                 │
# │ 217 │ 2                      │ 2                 │
# │ 218 │ 2                      │ 2                 │
# │ 219 │ 2                      │ 2                 │
# │ 220 │ 2                      │ 2                 │
# │ 221 │ 2                      │ 2                 │
# │ 222 │ 2                      │ 2                 │
# │ 223 │ 2                      │ 2                 │
# │ 224 │ 2                      │ 2                 │
# │ 225 │ 2                      │ 2                 │
# │ 226 │ 1                      │ 2                 │
# │ 227 │ 1                      │ 2                 │
# │ 228 │ 1                      │ 1                 │
# │ 229 │ 1                      │ 1                 │
# │ 230 │ 1                      │ 1                 │
# │ 231 │ 1                      │ 1                 │
# │ 232 │ 1                      │ 1                 │
# │ 233 │ 1                      │ 1                 │
# │ 234 │ 1                      │ 1                 │
# │ 235 │ 1                      │ 1                 │
# │ 236 │ 1                      │ 1                 │
# │ 237 │ 1                      │ 1                 │
# │ 238 │ 1                      │ 1                 │
# │ 239 │ 1                      │ 1                 │
# │ 240 │ 1                      │ 1                 │
# │ 241 │ 1                      │ 1                 │
# │ 242 │ 1                      │ 1                 │
# │ 243 │ 1                      │ 1                 │
# │ 244 │ 1                      │ 1                 │
# │ 245 │ 1                      │ 1                 │
# │ 246 │ 1                      │ 1                 │
# │ 247 │ 1                      │ 1                 │
# │ 248 │ 1                      │ 1                 │
# │ 249 │ 1                      │ 1                 │
# │ 250 │ 1                      │ 1                 │
# │ 251 │ 1                      │ 1                 │
