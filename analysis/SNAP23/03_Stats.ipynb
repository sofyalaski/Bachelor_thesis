# %%
using Statistics
using CSV
using DataFrames
using Measures
using Gadfly

ENV["LINES"] = 9;
# Out:
# ┌ Info: Loading DataFrames support into Gadfly.jl
# └ @ Gadfly C:\Users\Diego\.julia\packages\Gadfly\09PWZ\src\mapping.jl:228

# %%
# parameters
protein = "SNAP23"
# Out:
# "SNAP23"

# %%
function path_to_TranscriptAnnotation()
    folders = String[]
    for folder in splitpath(pwd())
        push!(folders, folder)
        if folder == "TranscriptAnnotation"
            break
        end
    end
    joinpath(folders...)
end

results_folder = joinpath(path_to_TranscriptAnnotation(), "benchmark", protein)
table_path = joinpath(results_folder, "thoraxe", "homologous_exon_table.csv")

const table = CSV.read(table_path);

# %% [markdown]
# ## Transcripts per species

# %%
by(table, :Species, :TranscriptIDCluster => length ∘ unique) |> 
    df -> rename!(df, :TranscriptIDCluster_function => :Transcripts) |>
    df -> show(df, allcols=true, allrows=true)
# Out:
# 10×2 DataFrame
# │ Row │ Species                  │ Transcripts │
# │     │ String                   │ Int64       │
# ├─────┼──────────────────────────┼─────────────┤
# │ 1   │ bos_taurus               │ 1           │
# │ 2   │ homo_sapiens             │ 4           │
# │ 3   │ gorilla_gorilla          │ 7           │
# │ 4   │ macaca_mulatta           │ 5           │
# │ 5   │ monodelphis_domestica    │ 1           │
# │ 6   │ mus_musculus             │ 2           │
# │ 7   │ ornithorhynchus_anatinus │ 2           │
# │ 8   │ rattus_norvegicus        │ 1           │
# │ 9   │ sus_scrofa               │ 2           │
# │ 10  │ xenopus_tropicalis       │ 1           │

# %% [markdown]
# ## (Sub)exons without (known) homology

# %%
total = sum(startswith(exonid, "0_") for exonid in unique(table[:HomologousExon]))
print("Number of (sub)exons without (known) homology in the gene: ", total)
# Out:
# Number of (sub)exons without (known) homology in the gene: 2

# %%
by(table, :Species) do df
    (ExonsWithoutHomology = sum(startswith(exonid, "0_") for exonid in unique(df[:HomologousExon])), )
end |> df -> show(df, allcols=true, allrows=true)
# Out:
# 10×2 DataFrame
# │ Row │ Species                  │ ExonsWithoutHomology │
# │     │ String                   │ Int64                │
# ├─────┼──────────────────────────┼──────────────────────┤
# │ 1   │ bos_taurus               │ 0                    │
# │ 2   │ homo_sapiens             │ 0                    │
# │ 3   │ gorilla_gorilla          │ 0                    │
# │ 4   │ macaca_mulatta           │ 0                    │
# │ 5   │ monodelphis_domestica    │ 0                    │
# │ 6   │ mus_musculus             │ 0                    │
# │ 7   │ ornithorhynchus_anatinus │ 0                    │
# │ 8   │ rattus_norvegicus        │ 2                    │
# │ 9   │ sus_scrofa               │ 0                    │
# │ 10  │ xenopus_tropicalis       │ 0                    │

# %% [markdown]
# ### Short exons

# %% [markdown]
# Some subexons doesn't have known homologs because they are too short

# %%
by(table, [:TranscriptIDCluster, :ExonIDCluster], :SubexonProteinSequence => join) |>
    df -> by(df, 
        :ExonIDCluster, 
        :SubexonProteinSequence_join => col -> minimum(map(x -> length(replace(x, "*" => "")), col))) |>
    df -> rename!(df, :SubexonProteinSequence_join_function => :ExonLength) |>
    df -> df[df[:ExonLength] .≤ 4, :] |>
    df -> show(df, allcols=true, allrows=true)
# Out:
# 2×2 DataFrame
# │ Row │ ExonIDCluster      │ ExonLength │
# │     │ String             │ Int64      │
# ├─────┼────────────────────┼────────────┤
# │ 1   │ ENSRNOE00000492082 │ 3          │
# │ 2   │ ENSRNOE00000566408 │ 3          │

# %% [markdown]
# ## Putative orthologous exons

# %%
total = sum(!startswith(exonid, "0_") for exonid in unique(table[:HomologousExon]))
print("Number of putative orthologous exons in the gene: ", total)
# Out:
# Number of putative orthologous exons in the gene: 21

# %%
by(table, :Species) do df
    (ExonsWithoutHomology = sum(!startswith(exonid, "0_") for exonid in unique(df[:HomologousExon])), )
end |> df -> show(df, allcols=true, allrows=true)
# Out:
# 10×2 DataFrame
# │ Row │ Species                  │ ExonsWithoutHomology │
# │     │ String                   │ Int64                │
# ├─────┼──────────────────────────┼──────────────────────┤
# │ 1   │ bos_taurus               │ 5                    │
# │ 2   │ homo_sapiens             │ 9                    │
# │ 3   │ gorilla_gorilla          │ 13                   │
# │ 4   │ macaca_mulatta           │ 10                   │
# │ 5   │ monodelphis_domestica    │ 7                    │
# │ 6   │ mus_musculus             │ 8                    │
# │ 7   │ ornithorhynchus_anatinus │ 8                    │
# │ 8   │ rattus_norvegicus        │ 11                   │
# │ 9   │ sus_scrofa               │ 8                    │
# │ 10  │ xenopus_tropicalis       │ 7                    │

# %% [markdown]
# ## Exon Lengths

# %% [markdown]
# Distribution of homologous exon lengths

# %%
len(x) = ismissing(x) ? 0 : length(x)

const lengths = by(table, :HomologousExon, :HomologousExonSequence => col -> maximum(len.(col))) |> 
    df -> rename!(df, :HomologousExonSequence_function  => :HomologousExonLength ) |>
    df -> sort!(df, :HomologousExon) 

show(lengths, allrows=true)
# Out:
# 23×2 DataFrame
# │ Row │ HomologousExon │ HomologousExonLength │
# │     │ String         │ Int64                │
# ├─────┼────────────────┼──────────────────────┤
# │ 1   │ 0_1            │ 3                    │
# │ 2   │ 0_2            │ 3                    │
# │ 3   │ 10_0           │ 9                    │
# │ 4   │ 11_0           │ 9                    │
# │ 5   │ 12_0           │ 5                    │
# │ 6   │ 1_0            │ 107                  │
# │ 7   │ 2_0            │ 21                   │
# │ 8   │ 2_1            │ 17                   │
# │ 9   │ 2_2            │ 39                   │
# │ 10  │ 2_3            │ 10                   │
# │ 11  │ 2_4            │ 8                    │
# │ 12  │ 2_5            │ 5                    │
# │ 13  │ 3_0            │ 57                   │
# │ 14  │ 4_0            │ 11                   │
# │ 15  │ 4_1            │ 48                   │
# │ 16  │ 4_2            │ 8                    │
# │ 17  │ 5_0            │ 27                   │
# │ 18  │ 5_1            │ 5                    │
# │ 19  │ 5_2            │ 8                    │
# │ 20  │ 6_0            │ 21                   │
# │ 21  │ 7_0            │ 15                   │
# │ 22  │ 8_0            │ 11                   │
# │ 23  │ 9_0            │ 11                   │

# %%
lengths[:WithHomologous] = [ !startswith(exonid, "0_") for exonid in lengths[:HomologousExon ] ];

# %%
plt = plot(lengths, x="HomologousExonLength", color="WithHomologous", Geom.histogram)
draw(SVG(25cm, 15cm), plt)
# Out:
# SVG(250.0mm, 150.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=11057, maxsize=Inf, ptr=11058, mark=-1), nothing, "img-5ac6aa61", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Property}}(Property{JSIncludePrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{StrokePrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{FontSizePrimitive}=>nothing,Property{SVGAttributePrimitive}=>nothing,Property{StrokeDashPrimitive}=>nothing,Property{SVGClassPrimitive}=>nothing,Property{FontPrimitive}=>nothing,Property{LineWidthPrimitive}=>nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Length{:mm,Float64},Length{:mm,Float64}}[(10.3467mm, 5.0mm), (216.29mm, 5.0mm), (216.29mm, 130.715mm), (10.3467mm, 130.715mm)])=>"img-5ac6aa61-13"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-5ac6aa61-58", false, 58, Set(AbstractString["C:\\Users\\Diego\\.julia\\packages\\Gadfly\\09PWZ\\src\\gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-5ac6aa61-4\")\n   .drag(function() {}, function() {}, function() {});", "fig.select(\"#img-5ac6aa61-6\")\n   .data(\"color_class\", \"color_false\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-7\")\n   .data(\"color_class\", \"color_true\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-9\")\n   .data(\"color_class\", \"color_false\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-10\")\n   .data(\"color_class\", \"color_true\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-14\")\n   .init_gadfly();"], false, :none, (BoundingBox{Tuple{Length{:mm,Float64},Length{:mm,Float64}},Tuple{Length{:mm,Float64},Length{:mm,Float64}}}((10.346666666666664mm, 5.0mm), (205.94333333333333mm, 125.71499999999999mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.4855652575805094, 15.246477426775664, 152.97113051516104, -15.49295485355133, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %% [markdown]
# ## Alternative spliced homologous exons

# %% [markdown]
# Exons with a `TranscriptFraction` of `1.0` in a gene are constitutive. The plot can help to identify homologous_exons that change their `TranscriptFraction` in different genes.

# %%
constitutive = by(table, :GeneID) do df
    subdf = unique(df[:, [:HomologousExon, :TranscriptsWithSubexon, :TranscriptsInGene]])
    by(subdf, :HomologousExon) do exondf
        (TranscriptFraction = exondf[1, :TranscriptsWithSubexon] / exondf[1, :TranscriptsInGene],
         TranscriptsWithSubexon = exondf[1, :TranscriptsWithSubexon],
         TranscriptsInGene = exondf[1, :TranscriptsInGene])
    end
end;

# %%
plt = plot(constitutive, x="HomologousExon", y="TranscriptFraction", Geom.point)
draw(SVG(25cm, 15cm), plt)
# Out:
# SVG(250.0mm, 150.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=45430, maxsize=Inf, ptr=45431, mark=-1), nothing, "img-490bdd3f", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Property}}(Property{JSIncludePrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{StrokePrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{FontSizePrimitive}=>nothing,Property{SVGAttributePrimitive}=>nothing,Property{StrokeDashPrimitive}=>nothing,Property{SVGClassPrimitive}=>nothing,Property{FontPrimitive}=>nothing,Property{LineWidthPrimitive}=>nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Length{:mm,Float64},Length{:mm,Float64}}[(18.6317mm, 5.0mm), (245.0mm, 5.0mm), (245.0mm, 130.715mm), (18.6317mm, 130.715mm)])=>"img-490bdd3f-4"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-490bdd3f-313", false, 313, Set(AbstractString["C:\\Users\\Diego\\.julia\\packages\\Gadfly\\09PWZ\\src\\gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-490bdd3f-5\")\n   .init_gadfly();"], false, :none, (BoundingBox{Tuple{Length{:mm,Float64},Length{:mm,Float64}},Tuple{Length{:mm,Float64},Length{:mm,Float64}}}((18.63166666666669mm, 5.0mm), (226.36833333333334mm, 125.715mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(0.5, 1.0164318284517109, 23.0, -1.032863656903422, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
show(constitutive, allrows=true, allcols=true)
# Out:
# 88×5 DataFrame
# │ Row │ GeneID             │ HomologousExon │ TranscriptFraction │
# │     │ String             │ String         │ Float64            │
# ├─────┼────────────────────┼────────────────┼────────────────────┤
# │ 1   │ ENSBTAG00000050767 │ 11_0           │ 1.0                │
# │ 2   │ ENSBTAG00000050767 │ 2_0            │ 1.0                │
# │ 3   │ ENSBTAG00000050767 │ 2_1            │ 1.0                │
# │ 4   │ ENSBTAG00000050767 │ 2_2            │ 1.0                │
# │ 5   │ ENSBTAG00000050767 │ 1_0            │ 1.0                │
# │ 6   │ ENSG00000092531    │ 5_0            │ 1.0                │
# │ 7   │ ENSG00000092531    │ 2_0            │ 1.0                │
# │ 8   │ ENSG00000092531    │ 2_1            │ 1.0                │
# │ 9   │ ENSG00000092531    │ 2_2            │ 1.0                │
# │ 10  │ ENSG00000092531    │ 3_0            │ 0.25               │
# │ 11  │ ENSG00000092531    │ 4_1            │ 0.5                │
# │ 12  │ ENSG00000092531    │ 6_0            │ 0.5                │
# │ 13  │ ENSG00000092531    │ 1_0            │ 0.25               │
# │ 14  │ ENSG00000092531    │ 5_2            │ 0.25               │
# │ 15  │ ENSGGOG00000015801 │ 5_0            │ 1.0                │
# │ 16  │ ENSGGOG00000015801 │ 2_0            │ 1.0                │
# │ 17  │ ENSGGOG00000015801 │ 2_1            │ 0.714286           │
# │ 18  │ ENSGGOG00000015801 │ 2_2            │ 0.714286           │
# │ 19  │ ENSGGOG00000015801 │ 3_0            │ 0.285714           │
# │ 20  │ ENSGGOG00000015801 │ 4_1            │ 0.428571           │
# │ 21  │ ENSGGOG00000015801 │ 6_0            │ 0.285714           │
# │ 22  │ ENSGGOG00000015801 │ 9_0            │ 0.142857           │
# │ 23  │ ENSGGOG00000015801 │ 5_2            │ 0.142857           │
# │ 24  │ ENSGGOG00000015801 │ 4_2            │ 0.142857           │
# │ 25  │ ENSGGOG00000015801 │ 1_0            │ 0.142857           │
# │ 26  │ ENSGGOG00000015801 │ 7_0            │ 0.142857           │
# │ 27  │ ENSGGOG00000015801 │ 5_1            │ 0.142857           │
# │ 28  │ ENSMMUG00000014043 │ 5_0            │ 1.0                │
# │ 29  │ ENSMMUG00000014043 │ 2_0            │ 1.0                │
# │ 30  │ ENSMMUG00000014043 │ 2_1            │ 0.8                │
# │ 31  │ ENSMMUG00000014043 │ 2_2            │ 0.8                │
# │ 32  │ ENSMMUG00000014043 │ 5_2            │ 0.2                │
# │ 33  │ ENSMMUG00000014043 │ 1_0            │ 0.2                │
# │ 34  │ ENSMMUG00000014043 │ 9_0            │ 0.2                │
# │ 35  │ ENSMMUG00000014043 │ 4_1            │ 0.4                │
# │ 36  │ ENSMMUG00000014043 │ 6_0            │ 0.4                │
# │ 37  │ ENSMMUG00000014043 │ 3_0            │ 0.2                │
# │ 38  │ ENSMODG00000017889 │ 5_0            │ 1.0                │
# │ 39  │ ENSMODG00000017889 │ 2_0            │ 1.0                │
# │ 40  │ ENSMODG00000017889 │ 2_1            │ 1.0                │
# │ 41  │ ENSMODG00000017889 │ 2_2            │ 1.0                │
# │ 42  │ ENSMODG00000017889 │ 3_0            │ 1.0                │
# │ 43  │ ENSMODG00000017889 │ 4_1            │ 1.0                │
# │ 44  │ ENSMODG00000017889 │ 6_0            │ 1.0                │
# │ 45  │ ENSMUSG00000027287 │ 5_0            │ 1.0                │
# │ 46  │ ENSMUSG00000027287 │ 2_0            │ 1.0                │
# │ 47  │ ENSMUSG00000027287 │ 2_1            │ 1.0                │
# │ 48  │ ENSMUSG00000027287 │ 2_2            │ 1.0                │
# │ 49  │ ENSMUSG00000027287 │ 3_0            │ 1.0                │
# │ 50  │ ENSMUSG00000027287 │ 4_1            │ 1.0                │
# │ 51  │ ENSMUSG00000027287 │ 6_0            │ 1.0                │
# │ 52  │ ENSMUSG00000027287 │ 8_0            │ 0.5                │
# │ 53  │ ENSOANG00000010682 │ 5_0            │ 1.0                │
# │ 54  │ ENSOANG00000010682 │ 2_0            │ 1.0                │
# │ 55  │ ENSOANG00000010682 │ 2_1            │ 1.0                │
# │ 56  │ ENSOANG00000010682 │ 2_2            │ 1.0                │
# │ 57  │ ENSOANG00000010682 │ 3_0            │ 1.0                │
# │ 58  │ ENSOANG00000010682 │ 4_1            │ 1.0                │
# │ 59  │ ENSOANG00000010682 │ 6_0            │ 1.0                │
# │ 60  │ ENSOANG00000010682 │ 4_0            │ 0.5                │
# │ 61  │ ENSRNOG00000050552 │ 5_0            │ 1.0                │
# │ 62  │ ENSRNOG00000050552 │ 2_0            │ 1.0                │
# │ 63  │ ENSRNOG00000050552 │ 2_1            │ 1.0                │
# │ 64  │ ENSRNOG00000050552 │ 2_2            │ 1.0                │
# │ 65  │ ENSRNOG00000050552 │ 3_0            │ 1.0                │
# │ 66  │ ENSRNOG00000050552 │ 10_0           │ 1.0                │
# │ 67  │ ENSRNOG00000050552 │ 2_3            │ 1.0                │
# │ 68  │ ENSRNOG00000050552 │ 0_1            │ 1.0                │
# │ 69  │ ENSRNOG00000050552 │ 0_2            │ 1.0                │
# │ 70  │ ENSRNOG00000050552 │ 2_4            │ 1.0                │
# │ 71  │ ENSRNOG00000050552 │ 12_0           │ 1.0                │
# │ 72  │ ENSRNOG00000050552 │ 2_5            │ 1.0                │
# │ 73  │ ENSRNOG00000050552 │ 6_0            │ 1.0                │
# │ 74  │ ENSSSCG00000038735 │ 5_0            │ 1.0                │
# │ 75  │ ENSSSCG00000038735 │ 2_0            │ 1.0                │
# │ 76  │ ENSSSCG00000038735 │ 2_1            │ 1.0                │
# │ 77  │ ENSSSCG00000038735 │ 2_2            │ 1.0                │
# │ 78  │ ENSSSCG00000038735 │ 8_0            │ 0.5                │
# │ 79  │ ENSSSCG00000038735 │ 3_0            │ 1.0                │
# │ 80  │ ENSSSCG00000038735 │ 4_1            │ 1.0                │
# │ 81  │ ENSSSCG00000038735 │ 6_0            │ 1.0                │
# │ 82  │ ENSXETG00000000056 │ 5_0            │ 1.0                │
# │ 83  │ ENSXETG00000000056 │ 2_0            │ 1.0                │
# │ 84  │ ENSXETG00000000056 │ 2_1            │ 1.0                │
# │ 85  │ ENSXETG00000000056 │ 2_2            │ 1.0                │
# │ 86  │ ENSXETG00000000056 │ 3_0            │ 1.0                │
# │ 87  │ ENSXETG00000000056 │ 4_1            │ 1.0                │
# │ 88  │ ENSXETG00000000056 │ 6_0            │ 1.0                │
#
# │ Row │ TranscriptsWithSubexon │ TranscriptsInGene │
# │     │ Int64                  │ Int64             │
# ├─────┼────────────────────────┼───────────────────┤
# │ 1   │ 1                      │ 1                 │
# │ 2   │ 1                      │ 1                 │
# │ 3   │ 1                      │ 1                 │
# │ 4   │ 1                      │ 1                 │
# │ 5   │ 1                      │ 1                 │
# │ 6   │ 4                      │ 4                 │
# │ 7   │ 4                      │ 4                 │
# │ 8   │ 4                      │ 4                 │
# │ 9   │ 4                      │ 4                 │
# │ 10  │ 1                      │ 4                 │
# │ 11  │ 2                      │ 4                 │
# │ 12  │ 2                      │ 4                 │
# │ 13  │ 1                      │ 4                 │
# │ 14  │ 1                      │ 4                 │
# │ 15  │ 7                      │ 7                 │
# │ 16  │ 7                      │ 7                 │
# │ 17  │ 5                      │ 7                 │
# │ 18  │ 5                      │ 7                 │
# │ 19  │ 2                      │ 7                 │
# │ 20  │ 3                      │ 7                 │
# │ 21  │ 2                      │ 7                 │
# │ 22  │ 1                      │ 7                 │
# │ 23  │ 1                      │ 7                 │
# │ 24  │ 1                      │ 7                 │
# │ 25  │ 1                      │ 7                 │
# │ 26  │ 1                      │ 7                 │
# │ 27  │ 1                      │ 7                 │
# │ 28  │ 5                      │ 5                 │
# │ 29  │ 5                      │ 5                 │
# │ 30  │ 4                      │ 5                 │
# │ 31  │ 4                      │ 5                 │
# │ 32  │ 1                      │ 5                 │
# │ 33  │ 1                      │ 5                 │
# │ 34  │ 1                      │ 5                 │
# │ 35  │ 2                      │ 5                 │
# │ 36  │ 2                      │ 5                 │
# │ 37  │ 1                      │ 5                 │
# │ 38  │ 1                      │ 1                 │
# │ 39  │ 1                      │ 1                 │
# │ 40  │ 1                      │ 1                 │
# │ 41  │ 1                      │ 1                 │
# │ 42  │ 1                      │ 1                 │
# │ 43  │ 1                      │ 1                 │
# │ 44  │ 1                      │ 1                 │
# │ 45  │ 2                      │ 2                 │
# │ 46  │ 2                      │ 2                 │
# │ 47  │ 2                      │ 2                 │
# │ 48  │ 2                      │ 2                 │
# │ 49  │ 2                      │ 2                 │
# │ 50  │ 2                      │ 2                 │
# │ 51  │ 2                      │ 2                 │
# │ 52  │ 1                      │ 2                 │
# │ 53  │ 2                      │ 2                 │
# │ 54  │ 2                      │ 2                 │
# │ 55  │ 2                      │ 2                 │
# │ 56  │ 2                      │ 2                 │
# │ 57  │ 2                      │ 2                 │
# │ 58  │ 2                      │ 2                 │
# │ 59  │ 2                      │ 2                 │
# │ 60  │ 1                      │ 2                 │
# │ 61  │ 1                      │ 1                 │
# │ 62  │ 1                      │ 1                 │
# │ 63  │ 1                      │ 1                 │
# │ 64  │ 1                      │ 1                 │
# │ 65  │ 1                      │ 1                 │
# │ 66  │ 1                      │ 1                 │
# │ 67  │ 1                      │ 1                 │
# │ 68  │ 1                      │ 1                 │
# │ 69  │ 1                      │ 1                 │
# │ 70  │ 1                      │ 1                 │
# │ 71  │ 1                      │ 1                 │
# │ 72  │ 1                      │ 1                 │
# │ 73  │ 1                      │ 1                 │
# │ 74  │ 2                      │ 2                 │
# │ 75  │ 2                      │ 2                 │
# │ 76  │ 2                      │ 2                 │
# │ 77  │ 2                      │ 2                 │
# │ 78  │ 1                      │ 2                 │
# │ 79  │ 2                      │ 2                 │
# │ 80  │ 2                      │ 2                 │
# │ 81  │ 2                      │ 2                 │
# │ 82  │ 1                      │ 1                 │
# │ 83  │ 1                      │ 1                 │
# │ 84  │ 1                      │ 1                 │
# │ 85  │ 1                      │ 1                 │
# │ 86  │ 1                      │ 1                 │
# │ 87  │ 1                      │ 1                 │
# │ 88  │ 1                      │ 1                 │
