# %%
using Statistics
using CSV
using DataFrames
using Measures
using Gadfly

ENV["LINES"] = 9;
# Out:
# ┌ Info: Loading DataFrames support into Gadfly.jl
# └ @ Gadfly C:\Users\Diego\.julia\packages\Gadfly\09PWZ\src\mapping.jl:228

# %%
# parameters
protein = "GRIN3A"
# Out:
# "GRIN3A"

# %%
function path_to_TranscriptAnnotation()
    folders = String[]
    for folder in splitpath(pwd())
        push!(folders, folder)
        if folder == "TranscriptAnnotation"
            break
        end
    end
    joinpath(folders...)
end

results_folder = joinpath(path_to_TranscriptAnnotation(), "benchmark", protein)
table_path = joinpath(results_folder, "thoraxe", "homologous_exon_table.csv")

const table = CSV.read(table_path);

# %% [markdown]
# ## Transcripts per species

# %%
by(table, :Species, :TranscriptIDCluster => length ∘ unique) |> 
    df -> rename!(df, :TranscriptIDCluster_function => :Transcripts) |>
    df -> show(df, allcols=true, allrows=true)
# Out:
# 8×2 DataFrame
# │ Row │ Species               │ Transcripts │
# │     │ String                │ Int64       │
# ├─────┼───────────────────────┼─────────────┤
# │ 1   │ bos_taurus            │ 1           │
# │ 2   │ homo_sapiens          │ 1           │
# │ 3   │ gorilla_gorilla       │ 1           │
# │ 4   │ macaca_mulatta        │ 1           │
# │ 5   │ monodelphis_domestica │ 1           │
# │ 6   │ mus_musculus          │ 2           │
# │ 7   │ sus_scrofa            │ 3           │
# │ 8   │ xenopus_tropicalis    │ 1           │

# %% [markdown]
# ## (Sub)exons without (known) homology

# %%
total = sum(startswith(exonid, "0_") for exonid in unique(table[:HomologousExon]))
print("Number of (sub)exons without (known) homology in the gene: ", total)
# Out:
# Number of (sub)exons without (known) homology in the gene: 1

# %%
by(table, :Species) do df
    (ExonsWithoutHomology = sum(startswith(exonid, "0_") for exonid in unique(df[:HomologousExon])), )
end |> df -> show(df, allcols=true, allrows=true)
# Out:
# 8×2 DataFrame
# │ Row │ Species               │ ExonsWithoutHomology │
# │     │ String                │ Int64                │
# ├─────┼───────────────────────┼──────────────────────┤
# │ 1   │ bos_taurus            │ 0                    │
# │ 2   │ homo_sapiens          │ 0                    │
# │ 3   │ gorilla_gorilla       │ 0                    │
# │ 4   │ macaca_mulatta        │ 0                    │
# │ 5   │ monodelphis_domestica │ 0                    │
# │ 6   │ mus_musculus          │ 1                    │
# │ 7   │ sus_scrofa            │ 0                    │
# │ 8   │ xenopus_tropicalis    │ 0                    │

# %% [markdown]
# ### Short exons

# %% [markdown]
# Some subexons doesn't have known homologs because they are too short

# %%
by(table, [:TranscriptIDCluster, :ExonIDCluster], :SubexonProteinSequence => join) |>
    df -> by(df, 
        :ExonIDCluster, 
        :SubexonProteinSequence_join => col -> minimum(map(x -> length(replace(x, "*" => "")), col))) |>
    df -> rename!(df, :SubexonProteinSequence_join_function => :ExonLength) |>
    df -> df[df[:ExonLength] .≤ 4, :] |>
    df -> show(df, allcols=true, allrows=true)
# Out:
# 0×2 DataFrame

# %% [markdown]
# ## Putative orthologous exons

# %%
total = sum(!startswith(exonid, "0_") for exonid in unique(table[:HomologousExon]))
print("Number of putative orthologous exons in the gene: ", total)
# Out:
# Number of putative orthologous exons in the gene: 13

# %%
by(table, :Species) do df
    (ExonsWithoutHomology = sum(!startswith(exonid, "0_") for exonid in unique(df[:HomologousExon])), )
end |> df -> show(df, allcols=true, allrows=true)
# Out:
# 8×2 DataFrame
# │ Row │ Species               │ ExonsWithoutHomology │
# │     │ String                │ Int64                │
# ├─────┼───────────────────────┼──────────────────────┤
# │ 1   │ bos_taurus            │ 11                   │
# │ 2   │ homo_sapiens          │ 11                   │
# │ 3   │ gorilla_gorilla       │ 11                   │
# │ 4   │ macaca_mulatta        │ 11                   │
# │ 5   │ monodelphis_domestica │ 11                   │
# │ 6   │ mus_musculus          │ 11                   │
# │ 7   │ sus_scrofa            │ 11                   │
# │ 8   │ xenopus_tropicalis    │ 13                   │

# %% [markdown]
# ## Exon Lengths

# %% [markdown]
# Distribution of homologous exon lengths

# %%
len(x) = ismissing(x) ? 0 : length(x)

const lengths = by(table, :HomologousExon, :HomologousExonSequence => col -> maximum(len.(col))) |> 
    df -> rename!(df, :HomologousExonSequence_function  => :HomologousExonLength ) |>
    df -> sort!(df, :HomologousExon) 

show(lengths, allrows=true)
# Out:
# 14×2 DataFrame
# │ Row │ HomologousExon │ HomologousExonLength │
# │     │ String         │ Int64                │
# ├─────┼────────────────┼──────────────────────┤
# │ 1   │ 0_1            │ 20                   │
# │ 2   │ 10_0           │ 7                    │
# │ 3   │ 1_0            │ 349                  │
# │ 4   │ 2_0            │ 47                   │
# │ 5   │ 2_1            │ 175                  │
# │ 6   │ 2_2            │ 51                   │
# │ 7   │ 2_3            │ 11                   │
# │ 8   │ 3_0            │ 202                  │
# │ 9   │ 4_0            │ 112                  │
# │ 10  │ 5_0            │ 55                   │
# │ 11  │ 6_0            │ 50                   │
# │ 12  │ 7_0            │ 49                   │
# │ 13  │ 8_0            │ 39                   │
# │ 14  │ 9_0            │ 26                   │

# %%
lengths[:WithHomologous] = [ !startswith(exonid, "0_") for exonid in lengths[:HomologousExon ] ];

# %%
plt = plot(lengths, x="HomologousExonLength", color="WithHomologous", Geom.histogram)
draw(SVG(25cm, 15cm), plt)
# Out:
# SVG(250.0mm, 150.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=9196, maxsize=Inf, ptr=9197, mark=-1), nothing, "img-5ac6aa61", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Property}}(Property{JSIncludePrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{StrokePrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{FontSizePrimitive}=>nothing,Property{SVGAttributePrimitive}=>nothing,Property{StrokeDashPrimitive}=>nothing,Property{SVGClassPrimitive}=>nothing,Property{FontPrimitive}=>nothing,Property{LineWidthPrimitive}=>nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Length{:mm,Float64},Length{:mm,Float64}}[(10.3467mm, 5.0mm), (216.29mm, 5.0mm), (216.29mm, 130.715mm), (10.3467mm, 130.715mm)])=>"img-5ac6aa61-13"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-5ac6aa61-47", false, 47, Set(AbstractString["C:\\Users\\Diego\\.julia\\packages\\Gadfly\\09PWZ\\src\\gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-5ac6aa61-4\")\n   .drag(function() {}, function() {}, function() {});", "fig.select(\"#img-5ac6aa61-6\")\n   .data(\"color_class\", \"color_false\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-7\")\n   .data(\"color_class\", \"color_true\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-9\")\n   .data(\"color_class\", \"color_false\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-10\")\n   .data(\"color_class\", \"color_true\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-14\")\n   .init_gadfly();"], false, :none, (BoundingBox{Tuple{Length{:mm,Float64},Length{:mm,Float64}},Tuple{Length{:mm,Float64},Length{:mm,Float64}}}((10.346666666666664mm, 5.0mm), (205.94333333333333mm, 125.71499999999999mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-3.9615073535480247, 10.16431828451711, 407.92301470709606, -10.32863656903422, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %% [markdown]
# ## Alternative spliced homologous exons

# %% [markdown]
# Exons with a `TranscriptFraction` of `1.0` in a gene are constitutive. The plot can help to identify homologous_exons that change their `TranscriptFraction` in different genes.

# %%
constitutive = by(table, :GeneID) do df
    subdf = unique(df[:, [:HomologousExon, :TranscriptsWithSubexon, :TranscriptsInGene]])
    by(subdf, :HomologousExon) do exondf
        (TranscriptFraction = exondf[1, :TranscriptsWithSubexon] / exondf[1, :TranscriptsInGene],
         TranscriptsWithSubexon = exondf[1, :TranscriptsWithSubexon],
         TranscriptsInGene = exondf[1, :TranscriptsInGene])
    end
end;

# %%
plt = plot(constitutive, x="HomologousExon", y="TranscriptFraction", Geom.point)
draw(SVG(25cm, 15cm), plt)
# Out:
# SVG(250.0mm, 150.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=43752, maxsize=Inf, ptr=43753, mark=-1), nothing, "img-490bdd3f", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Property}}(Property{JSIncludePrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{StrokePrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{FontSizePrimitive}=>nothing,Property{SVGAttributePrimitive}=>nothing,Property{StrokeDashPrimitive}=>nothing,Property{SVGClassPrimitive}=>nothing,Property{FontPrimitive}=>nothing,Property{LineWidthPrimitive}=>nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Length{:mm,Float64},Length{:mm,Float64}}[(18.6317mm, 5.0mm), (245.0mm, 5.0mm), (245.0mm, 130.715mm), (18.6317mm, 130.715mm)])=>"img-490bdd3f-4"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-490bdd3f-313", false, 313, Set(AbstractString["C:\\Users\\Diego\\.julia\\packages\\Gadfly\\09PWZ\\src\\gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-490bdd3f-5\")\n   .init_gadfly();"], false, :none, (BoundingBox{Tuple{Length{:mm,Float64},Length{:mm,Float64}},Tuple{Length{:mm,Float64},Length{:mm,Float64}}}((18.63166666666669mm, 5.0mm), (226.36833333333334mm, 125.715mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(0.5, 1.0082159142258555, 14.0, -0.516431828451711, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
show(constitutive, allrows=true, allcols=true)
# Out:
# 91×5 DataFrame
# │ Row │ GeneID             │ HomologousExon │ TranscriptFraction │
# │     │ String             │ String         │ Float64            │
# ├─────┼────────────────────┼────────────────┼────────────────────┤
# │ 1   │ ENSBTAG00000018445 │ 2_0            │ 1.0                │
# │ 2   │ ENSBTAG00000018445 │ 2_1            │ 1.0                │
# │ 3   │ ENSBTAG00000018445 │ 2_2            │ 1.0                │
# │ 4   │ ENSBTAG00000018445 │ 3_0            │ 1.0                │
# │ 5   │ ENSBTAG00000018445 │ 1_0            │ 1.0                │
# │ 6   │ ENSBTAG00000018445 │ 7_0            │ 1.0                │
# │ 7   │ ENSBTAG00000018445 │ 8_0            │ 1.0                │
# │ 8   │ ENSBTAG00000018445 │ 6_0            │ 1.0                │
# │ 9   │ ENSBTAG00000018445 │ 5_0            │ 1.0                │
# │ 10  │ ENSBTAG00000018445 │ 9_0            │ 1.0                │
# │ 11  │ ENSBTAG00000018445 │ 4_0            │ 1.0                │
# │ 12  │ ENSG00000198785    │ 2_0            │ 1.0                │
# │ 13  │ ENSG00000198785    │ 2_1            │ 1.0                │
# │ 14  │ ENSG00000198785    │ 2_2            │ 1.0                │
# │ 15  │ ENSG00000198785    │ 3_0            │ 1.0                │
# │ 16  │ ENSG00000198785    │ 1_0            │ 1.0                │
# │ 17  │ ENSG00000198785    │ 7_0            │ 1.0                │
# │ 18  │ ENSG00000198785    │ 8_0            │ 1.0                │
# │ 19  │ ENSG00000198785    │ 6_0            │ 1.0                │
# │ 20  │ ENSG00000198785    │ 5_0            │ 1.0                │
# │ 21  │ ENSG00000198785    │ 9_0            │ 1.0                │
# │ 22  │ ENSG00000198785    │ 4_0            │ 1.0                │
# │ 23  │ ENSGGOG00000009473 │ 2_0            │ 1.0                │
# │ 24  │ ENSGGOG00000009473 │ 2_1            │ 1.0                │
# │ 25  │ ENSGGOG00000009473 │ 2_2            │ 1.0                │
# │ 26  │ ENSGGOG00000009473 │ 3_0            │ 1.0                │
# │ 27  │ ENSGGOG00000009473 │ 1_0            │ 1.0                │
# │ 28  │ ENSGGOG00000009473 │ 7_0            │ 1.0                │
# │ 29  │ ENSGGOG00000009473 │ 8_0            │ 1.0                │
# │ 30  │ ENSGGOG00000009473 │ 6_0            │ 1.0                │
# │ 31  │ ENSGGOG00000009473 │ 5_0            │ 1.0                │
# │ 32  │ ENSGGOG00000009473 │ 9_0            │ 1.0                │
# │ 33  │ ENSGGOG00000009473 │ 4_0            │ 1.0                │
# │ 34  │ ENSMMUG00000016675 │ 2_0            │ 1.0                │
# │ 35  │ ENSMMUG00000016675 │ 2_1            │ 1.0                │
# │ 36  │ ENSMMUG00000016675 │ 2_2            │ 1.0                │
# │ 37  │ ENSMMUG00000016675 │ 3_0            │ 1.0                │
# │ 38  │ ENSMMUG00000016675 │ 1_0            │ 1.0                │
# │ 39  │ ENSMMUG00000016675 │ 7_0            │ 1.0                │
# │ 40  │ ENSMMUG00000016675 │ 8_0            │ 1.0                │
# │ 41  │ ENSMMUG00000016675 │ 6_0            │ 1.0                │
# │ 42  │ ENSMMUG00000016675 │ 5_0            │ 1.0                │
# │ 43  │ ENSMMUG00000016675 │ 9_0            │ 1.0                │
# │ 44  │ ENSMMUG00000016675 │ 4_0            │ 1.0                │
# │ 45  │ ENSMODG00000014442 │ 2_0            │ 1.0                │
# │ 46  │ ENSMODG00000014442 │ 2_1            │ 1.0                │
# │ 47  │ ENSMODG00000014442 │ 2_2            │ 1.0                │
# │ 48  │ ENSMODG00000014442 │ 3_0            │ 1.0                │
# │ 49  │ ENSMODG00000014442 │ 1_0            │ 1.0                │
# │ 50  │ ENSMODG00000014442 │ 7_0            │ 1.0                │
# │ 51  │ ENSMODG00000014442 │ 8_0            │ 1.0                │
# │ 52  │ ENSMODG00000014442 │ 6_0            │ 1.0                │
# │ 53  │ ENSMODG00000014442 │ 5_0            │ 1.0                │
# │ 54  │ ENSMODG00000014442 │ 9_0            │ 1.0                │
# │ 55  │ ENSMODG00000014442 │ 4_0            │ 1.0                │
# │ 56  │ ENSMUSG00000039579 │ 2_0            │ 1.0                │
# │ 57  │ ENSMUSG00000039579 │ 2_1            │ 1.0                │
# │ 58  │ ENSMUSG00000039579 │ 2_2            │ 1.0                │
# │ 59  │ ENSMUSG00000039579 │ 3_0            │ 1.0                │
# │ 60  │ ENSMUSG00000039579 │ 1_0            │ 1.0                │
# │ 61  │ ENSMUSG00000039579 │ 7_0            │ 1.0                │
# │ 62  │ ENSMUSG00000039579 │ 8_0            │ 1.0                │
# │ 63  │ ENSMUSG00000039579 │ 6_0            │ 1.0                │
# │ 64  │ ENSMUSG00000039579 │ 5_0            │ 1.0                │
# │ 65  │ ENSMUSG00000039579 │ 9_0            │ 1.0                │
# │ 66  │ ENSMUSG00000039579 │ 4_0            │ 1.0                │
# │ 67  │ ENSMUSG00000039579 │ 0_1            │ 0.5                │
# │ 68  │ ENSSSCG00000005400 │ 2_0            │ 1.0                │
# │ 69  │ ENSSSCG00000005400 │ 2_1            │ 0.666667           │
# │ 70  │ ENSSSCG00000005400 │ 2_2            │ 1.0                │
# │ 71  │ ENSSSCG00000005400 │ 3_0            │ 1.0                │
# │ 72  │ ENSSSCG00000005400 │ 1_0            │ 1.0                │
# │ 73  │ ENSSSCG00000005400 │ 7_0            │ 1.0                │
# │ 74  │ ENSSSCG00000005400 │ 8_0            │ 1.0                │
# │ 75  │ ENSSSCG00000005400 │ 6_0            │ 1.0                │
# │ 76  │ ENSSSCG00000005400 │ 9_0            │ 1.0                │
# │ 77  │ ENSSSCG00000005400 │ 4_0            │ 1.0                │
# │ 78  │ ENSSSCG00000005400 │ 5_0            │ 0.666667           │
# │ 79  │ ENSXETG00000029920 │ 2_0            │ 1.0                │
# │ 80  │ ENSXETG00000029920 │ 2_1            │ 1.0                │
# │ 81  │ ENSXETG00000029920 │ 2_2            │ 1.0                │
# │ 82  │ ENSXETG00000029920 │ 3_0            │ 1.0                │
# │ 83  │ ENSXETG00000029920 │ 1_0            │ 1.0                │
# │ 84  │ ENSXETG00000029920 │ 7_0            │ 1.0                │
# │ 85  │ ENSXETG00000029920 │ 8_0            │ 1.0                │
# │ 86  │ ENSXETG00000029920 │ 6_0            │ 1.0                │
# │ 87  │ ENSXETG00000029920 │ 5_0            │ 1.0                │
# │ 88  │ ENSXETG00000029920 │ 9_0            │ 1.0                │
# │ 89  │ ENSXETG00000029920 │ 2_3            │ 1.0                │
# │ 90  │ ENSXETG00000029920 │ 10_0           │ 1.0                │
# │ 91  │ ENSXETG00000029920 │ 4_0            │ 1.0                │
#
# │ Row │ TranscriptsWithSubexon │ TranscriptsInGene │
# │     │ Int64                  │ Int64             │
# ├─────┼────────────────────────┼───────────────────┤
# │ 1   │ 1                      │ 1                 │
# │ 2   │ 1                      │ 1                 │
# │ 3   │ 1                      │ 1                 │
# │ 4   │ 1                      │ 1                 │
# │ 5   │ 1                      │ 1                 │
# │ 6   │ 1                      │ 1                 │
# │ 7   │ 1                      │ 1                 │
# │ 8   │ 1                      │ 1                 │
# │ 9   │ 1                      │ 1                 │
# │ 10  │ 1                      │ 1                 │
# │ 11  │ 1                      │ 1                 │
# │ 12  │ 1                      │ 1                 │
# │ 13  │ 1                      │ 1                 │
# │ 14  │ 1                      │ 1                 │
# │ 15  │ 1                      │ 1                 │
# │ 16  │ 1                      │ 1                 │
# │ 17  │ 1                      │ 1                 │
# │ 18  │ 1                      │ 1                 │
# │ 19  │ 1                      │ 1                 │
# │ 20  │ 1                      │ 1                 │
# │ 21  │ 1                      │ 1                 │
# │ 22  │ 1                      │ 1                 │
# │ 23  │ 1                      │ 1                 │
# │ 24  │ 1                      │ 1                 │
# │ 25  │ 1                      │ 1                 │
# │ 26  │ 1                      │ 1                 │
# │ 27  │ 1                      │ 1                 │
# │ 28  │ 1                      │ 1                 │
# │ 29  │ 1                      │ 1                 │
# │ 30  │ 1                      │ 1                 │
# │ 31  │ 1                      │ 1                 │
# │ 32  │ 1                      │ 1                 │
# │ 33  │ 1                      │ 1                 │
# │ 34  │ 1                      │ 1                 │
# │ 35  │ 1                      │ 1                 │
# │ 36  │ 1                      │ 1                 │
# │ 37  │ 1                      │ 1                 │
# │ 38  │ 1                      │ 1                 │
# │ 39  │ 1                      │ 1                 │
# │ 40  │ 1                      │ 1                 │
# │ 41  │ 1                      │ 1                 │
# │ 42  │ 1                      │ 1                 │
# │ 43  │ 1                      │ 1                 │
# │ 44  │ 1                      │ 1                 │
# │ 45  │ 1                      │ 1                 │
# │ 46  │ 1                      │ 1                 │
# │ 47  │ 1                      │ 1                 │
# │ 48  │ 1                      │ 1                 │
# │ 49  │ 1                      │ 1                 │
# │ 50  │ 1                      │ 1                 │
# │ 51  │ 1                      │ 1                 │
# │ 52  │ 1                      │ 1                 │
# │ 53  │ 1                      │ 1                 │
# │ 54  │ 1                      │ 1                 │
# │ 55  │ 1                      │ 1                 │
# │ 56  │ 2                      │ 2                 │
# │ 57  │ 2                      │ 2                 │
# │ 58  │ 2                      │ 2                 │
# │ 59  │ 2                      │ 2                 │
# │ 60  │ 2                      │ 2                 │
# │ 61  │ 2                      │ 2                 │
# │ 62  │ 2                      │ 2                 │
# │ 63  │ 2                      │ 2                 │
# │ 64  │ 2                      │ 2                 │
# │ 65  │ 2                      │ 2                 │
# │ 66  │ 2                      │ 2                 │
# │ 67  │ 1                      │ 2                 │
# │ 68  │ 3                      │ 3                 │
# │ 69  │ 2                      │ 3                 │
# │ 70  │ 3                      │ 3                 │
# │ 71  │ 3                      │ 3                 │
# │ 72  │ 3                      │ 3                 │
# │ 73  │ 3                      │ 3                 │
# │ 74  │ 3                      │ 3                 │
# │ 75  │ 3                      │ 3                 │
# │ 76  │ 3                      │ 3                 │
# │ 77  │ 3                      │ 3                 │
# │ 78  │ 2                      │ 3                 │
# │ 79  │ 1                      │ 1                 │
# │ 80  │ 1                      │ 1                 │
# │ 81  │ 1                      │ 1                 │
# │ 82  │ 1                      │ 1                 │
# │ 83  │ 1                      │ 1                 │
# │ 84  │ 1                      │ 1                 │
# │ 85  │ 1                      │ 1                 │
# │ 86  │ 1                      │ 1                 │
# │ 87  │ 1                      │ 1                 │
# │ 88  │ 1                      │ 1                 │
# │ 89  │ 1                      │ 1                 │
# │ 90  │ 1                      │ 1                 │
# │ 91  │ 1                      │ 1                 │
