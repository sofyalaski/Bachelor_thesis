# %%
using Statistics
using CSV
using DataFrames
using Measures
using Gadfly

ENV["LINES"] = 9;
# Out:
# ┌ Info: Loading DataFrames support into Gadfly.jl
# └ @ Gadfly C:\Users\Diego\.julia\packages\Gadfly\09PWZ\src\mapping.jl:228

# %%
# parameters
protein = "TPM4"
# Out:
# "TPM4"

# %%
function path_to_TranscriptAnnotation()
    folders = String[]
    for folder in splitpath(pwd())
        push!(folders, folder)
        if folder == "TranscriptAnnotation"
            break
        end
    end
    joinpath(folders...)
end

results_folder = joinpath(path_to_TranscriptAnnotation(), "benchmark", protein)
table_path = joinpath(results_folder, "thoraxe", "homologous_exon_table.csv")

const table = CSV.read(table_path);

# %% [markdown]
# ## Transcripts per species

# %%
by(table, :Species, :TranscriptIDCluster => length ∘ unique) |> 
    df -> rename!(df, :TranscriptIDCluster_function => :Transcripts) |>
    df -> show(df, allcols=true, allrows=true)
# Out:
# 10×2 DataFrame
# │ Row │ Species                  │ Transcripts │
# │     │ String                   │ Int64       │
# ├─────┼──────────────────────────┼─────────────┤
# │ 1   │ bos_taurus               │ 2           │
# │ 2   │ homo_sapiens             │ 3           │
# │ 3   │ gorilla_gorilla          │ 4           │
# │ 4   │ macaca_mulatta           │ 4           │
# │ 5   │ monodelphis_domestica    │ 1           │
# │ 6   │ mus_musculus             │ 1           │
# │ 7   │ ornithorhynchus_anatinus │ 1           │
# │ 8   │ rattus_norvegicus        │ 1           │
# │ 9   │ sus_scrofa               │ 1           │
# │ 10  │ xenopus_tropicalis       │ 2           │

# %% [markdown]
# ## (Sub)exons without (known) homology

# %%
total = sum(startswith(exonid, "0_") for exonid in unique(table[:HomologousExon]))
print("Number of (sub)exons without (known) homology in the gene: ", total)
# Out:
# Number of (sub)exons without (known) homology in the gene: 0

# %%
by(table, :Species) do df
    (ExonsWithoutHomology = sum(startswith(exonid, "0_") for exonid in unique(df[:HomologousExon])), )
end |> df -> show(df, allcols=true, allrows=true)
# Out:
# 10×2 DataFrame
# │ Row │ Species                  │ ExonsWithoutHomology │
# │     │ String                   │ Int64                │
# ├─────┼──────────────────────────┼──────────────────────┤
# │ 1   │ bos_taurus               │ 0                    │
# │ 2   │ homo_sapiens             │ 0                    │
# │ 3   │ gorilla_gorilla          │ 0                    │
# │ 4   │ macaca_mulatta           │ 0                    │
# │ 5   │ monodelphis_domestica    │ 0                    │
# │ 6   │ mus_musculus             │ 0                    │
# │ 7   │ ornithorhynchus_anatinus │ 0                    │
# │ 8   │ rattus_norvegicus        │ 0                    │
# │ 9   │ sus_scrofa               │ 0                    │
# │ 10  │ xenopus_tropicalis       │ 0                    │

# %% [markdown]
# ### Short exons

# %% [markdown]
# Some subexons doesn't have known homologs because they are too short

# %%
by(table, [:TranscriptIDCluster, :ExonIDCluster], :SubexonProteinSequence => join) |>
    df -> by(df, 
        :ExonIDCluster, 
        :SubexonProteinSequence_join => col -> minimum(map(x -> length(replace(x, "*" => "")), col))) |>
    df -> rename!(df, :SubexonProteinSequence_join_function => :ExonLength) |>
    df -> df[df[:ExonLength] .≤ 4, :] |>
    df -> show(df, allcols=true, allrows=true)
# Out:
# 1×2 DataFrame
# │ Row │ ExonIDCluster   │ ExonLength │
# │     │ String          │ Int64      │
# ├─────┼─────────────────┼────────────┤
# │ 1   │ ENSE00003824587 │ 4          │

# %% [markdown]
# ## Putative orthologous exons

# %%
total = sum(!startswith(exonid, "0_") for exonid in unique(table[:HomologousExon]))
print("Number of putative orthologous exons in the gene: ", total)
# Out:
# Number of putative orthologous exons in the gene: 19

# %%
by(table, :Species) do df
    (ExonsWithoutHomology = sum(!startswith(exonid, "0_") for exonid in unique(df[:HomologousExon])), )
end |> df -> show(df, allcols=true, allrows=true)
# Out:
# 10×2 DataFrame
# │ Row │ Species                  │ ExonsWithoutHomology │
# │     │ String                   │ Int64                │
# ├─────┼──────────────────────────┼──────────────────────┤
# │ 1   │ bos_taurus               │ 11                   │
# │ 2   │ homo_sapiens             │ 12                   │
# │ 3   │ gorilla_gorilla          │ 12                   │
# │ 4   │ macaca_mulatta           │ 12                   │
# │ 5   │ monodelphis_domestica    │ 8                    │
# │ 6   │ mus_musculus             │ 8                    │
# │ 7   │ ornithorhynchus_anatinus │ 7                    │
# │ 8   │ rattus_norvegicus        │ 8                    │
# │ 9   │ sus_scrofa               │ 8                    │
# │ 10  │ xenopus_tropicalis       │ 12                   │

# %% [markdown]
# ## Exon Lengths

# %% [markdown]
# Distribution of homologous exon lengths

# %%
len(x) = ismissing(x) ? 0 : length(x)

const lengths = by(table, :HomologousExon, :HomologousExonSequence => col -> maximum(len.(col))) |> 
    df -> rename!(df, :HomologousExonSequence_function  => :HomologousExonLength ) |>
    df -> sort!(df, :HomologousExon) 

show(lengths, allrows=true)
# Out:
# 19×2 DataFrame
# │ Row │ HomologousExon │ HomologousExonLength │
# │     │ String         │ Int64                │
# ├─────┼────────────────┼──────────────────────┤
# │ 1   │ 11_0           │ 18                   │
# │ 2   │ 1_0            │ 42                   │
# │ 3   │ 1_1            │ 4                    │
# │ 4   │ 1_2            │ 1                    │
# │ 5   │ 1_3            │ 45                   │
# │ 6   │ 1_4            │ 24                   │
# │ 7   │ 2_0            │ 44                   │
# │ 8   │ 2_1            │ 24                   │
# │ 9   │ 3_0            │ 19                   │
# │ 10  │ 3_1            │ 21                   │
# │ 11  │ 4_0            │ 39                   │
# │ 12  │ 5_0            │ 25                   │
# │ 13  │ 5_1            │ 14                   │
# │ 14  │ 5_2            │ 16                   │
# │ 15  │ 5_3            │ 26                   │
# │ 16  │ 6_0            │ 38                   │
# │ 17  │ 7_0            │ 26                   │
# │ 18  │ 8_0            │ 26                   │
# │ 19  │ 9_0            │ 24                   │

# %%
lengths[:WithHomologous] = [ !startswith(exonid, "0_") for exonid in lengths[:HomologousExon ] ];

# %%
plt = plot(lengths, x="HomologousExonLength", color="WithHomologous", Geom.histogram)
draw(SVG(25cm, 15cm), plt)
# Out:
# SVG(250.0mm, 150.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=9205, maxsize=Inf, ptr=9206, mark=-1), nothing, "img-5ac6aa61", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Property}}(Property{JSIncludePrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{StrokePrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{FontSizePrimitive}=>nothing,Property{SVGAttributePrimitive}=>nothing,Property{StrokeDashPrimitive}=>nothing,Property{SVGClassPrimitive}=>nothing,Property{FontPrimitive}=>nothing,Property{LineWidthPrimitive}=>nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Length{:mm,Float64},Length{:mm,Float64}}[(8.67333mm, 5.0mm), (216.29mm, 5.0mm), (216.29mm, 130.715mm), (8.67333mm, 130.715mm)])=>"img-5ac6aa61-12"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-5ac6aa61-48", false, 48, Set(AbstractString["C:\\Users\\Diego\\.julia\\packages\\Gadfly\\09PWZ\\src\\gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-5ac6aa61-4\")\n   .drag(function() {}, function() {}, function() {});", "fig.select(\"#img-5ac6aa61-5\")\n   .data(\"color_class\", \"color_true\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-13\")\n   .init_gadfly();"], false, :none, (BoundingBox{Tuple{Length{:mm,Float64},Length{:mm,Float64}},Tuple{Length{:mm,Float64},Length{:mm,Float64}}}((8.673333333333346mm, 5.0mm), (207.61666666666667mm, 125.715mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-0.4911189326348531, 4.0657273138068435, 50.98223786526971, -4.131454627613688, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %% [markdown]
# ## Alternative spliced homologous exons

# %% [markdown]
# Exons with a `TranscriptFraction` of `1.0` in a gene are constitutive. The plot can help to identify homologous_exons that change their `TranscriptFraction` in different genes.

# %%
constitutive = by(table, :GeneID) do df
    subdf = unique(df[:, [:HomologousExon, :TranscriptsWithSubexon, :TranscriptsInGene]])
    by(subdf, :HomologousExon) do exondf
        (TranscriptFraction = exondf[1, :TranscriptsWithSubexon] / exondf[1, :TranscriptsInGene],
         TranscriptsWithSubexon = exondf[1, :TranscriptsWithSubexon],
         TranscriptsInGene = exondf[1, :TranscriptsInGene])
    end
end;

# %%
plt = plot(constitutive, x="HomologousExon", y="TranscriptFraction", Geom.point)
draw(SVG(25cm, 15cm), plt)
# Out:
# SVG(250.0mm, 150.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=48036, maxsize=Inf, ptr=48037, mark=-1), nothing, "img-490bdd3f", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Property}}(Property{JSIncludePrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{StrokePrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{FontSizePrimitive}=>nothing,Property{SVGAttributePrimitive}=>nothing,Property{StrokeDashPrimitive}=>nothing,Property{SVGClassPrimitive}=>nothing,Property{FontPrimitive}=>nothing,Property{LineWidthPrimitive}=>nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Length{:mm,Float64},Length{:mm,Float64}}[(18.6317mm, 5.0mm), (245.0mm, 5.0mm), (245.0mm, 130.715mm), (18.6317mm, 130.715mm)])=>"img-490bdd3f-4"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-490bdd3f-339", false, 339, Set(AbstractString["C:\\Users\\Diego\\.julia\\packages\\Gadfly\\09PWZ\\src\\gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-490bdd3f-5\")\n   .init_gadfly();"], false, :none, (BoundingBox{Tuple{Length{:mm,Float64},Length{:mm,Float64}},Tuple{Length{:mm,Float64},Length{:mm,Float64}}}((18.63166666666669mm, 5.0mm), (226.36833333333334mm, 125.715mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(0.5, 1.0164318284517109, 19.0, -1.032863656903422, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
show(constitutive, allrows=true, allcols=true)
# Out:
# 98×5 DataFrame
# │ Row │ GeneID             │ HomologousExon │ TranscriptFraction │
# │     │ String             │ String         │ Float64            │
# ├─────┼────────────────────┼────────────────┼────────────────────┤
# │ 1   │ ENSBTAG00000004553 │ 2_0            │ 0.5                │
# │ 2   │ ENSBTAG00000004553 │ 1_3            │ 1.0                │
# │ 3   │ ENSBTAG00000004553 │ 4_0            │ 1.0                │
# │ 4   │ ENSBTAG00000004553 │ 1_4            │ 1.0                │
# │ 5   │ ENSBTAG00000004553 │ 5_0            │ 1.0                │
# │ 6   │ ENSBTAG00000004553 │ 3_1            │ 1.0                │
# │ 7   │ ENSBTAG00000004553 │ 2_1            │ 1.0                │
# │ 8   │ ENSBTAG00000004553 │ 5_3            │ 0.5                │
# │ 9   │ ENSBTAG00000004553 │ 6_0            │ 0.5                │
# │ 10  │ ENSBTAG00000004553 │ 1_0            │ 0.5                │
# │ 11  │ ENSBTAG00000004553 │ 8_0            │ 0.5                │
# │ 12  │ ENSG00000167460    │ 2_0            │ 0.333333           │
# │ 13  │ ENSG00000167460    │ 1_3            │ 1.0                │
# │ 14  │ ENSG00000167460    │ 4_0            │ 1.0                │
# │ 15  │ ENSG00000167460    │ 1_4            │ 1.0                │
# │ 16  │ ENSG00000167460    │ 5_0            │ 1.0                │
# │ 17  │ ENSG00000167460    │ 3_1            │ 1.0                │
# │ 18  │ ENSG00000167460    │ 2_1            │ 1.0                │
# │ 19  │ ENSG00000167460    │ 5_3            │ 1.0                │
# │ 20  │ ENSG00000167460    │ 1_1            │ 0.333333           │
# │ 21  │ ENSG00000167460    │ 11_0           │ 0.333333           │
# │ 22  │ ENSG00000167460    │ 6_0            │ 0.333333           │
# │ 23  │ ENSG00000167460    │ 1_0            │ 0.333333           │
# │ 24  │ ENSGGOG00000014510 │ 2_0            │ 0.5                │
# │ 25  │ ENSGGOG00000014510 │ 1_3            │ 1.0                │
# │ 26  │ ENSGGOG00000014510 │ 4_0            │ 1.0                │
# │ 27  │ ENSGGOG00000014510 │ 1_4            │ 1.0                │
# │ 28  │ ENSGGOG00000014510 │ 5_0            │ 1.0                │
# │ 29  │ ENSGGOG00000014510 │ 3_1            │ 0.75               │
# │ 30  │ ENSGGOG00000014510 │ 5_2            │ 0.25               │
# │ 31  │ ENSGGOG00000014510 │ 6_0            │ 0.5                │
# │ 32  │ ENSGGOG00000014510 │ 1_0            │ 0.5                │
# │ 33  │ ENSGGOG00000014510 │ 5_1            │ 0.25               │
# │ 34  │ ENSGGOG00000014510 │ 2_1            │ 0.75               │
# │ 35  │ ENSGGOG00000014510 │ 5_3            │ 0.75               │
# │ 36  │ ENSMMUG00000015783 │ 6_0            │ 0.75               │
# │ 37  │ ENSMMUG00000015783 │ 1_0            │ 0.75               │
# │ 38  │ ENSMMUG00000015783 │ 1_3            │ 1.0                │
# │ 39  │ ENSMMUG00000015783 │ 4_0            │ 1.0                │
# │ 40  │ ENSMMUG00000015783 │ 1_4            │ 1.0                │
# │ 41  │ ENSMMUG00000015783 │ 3_0            │ 0.25               │
# │ 42  │ ENSMMUG00000015783 │ 3_1            │ 1.0                │
# │ 43  │ ENSMMUG00000015783 │ 2_1            │ 1.0                │
# │ 44  │ ENSMMUG00000015783 │ 5_3            │ 0.75               │
# │ 45  │ ENSMMUG00000015783 │ 5_0            │ 0.75               │
# │ 46  │ ENSMMUG00000015783 │ 2_0            │ 0.25               │
# │ 47  │ ENSMMUG00000015783 │ 7_0            │ 0.25               │
# │ 48  │ ENSMODG00000014882 │ 2_0            │ 1.0                │
# │ 49  │ ENSMODG00000014882 │ 1_3            │ 1.0                │
# │ 50  │ ENSMODG00000014882 │ 4_0            │ 1.0                │
# │ 51  │ ENSMODG00000014882 │ 1_4            │ 1.0                │
# │ 52  │ ENSMODG00000014882 │ 5_0            │ 1.0                │
# │ 53  │ ENSMODG00000014882 │ 3_1            │ 1.0                │
# │ 54  │ ENSMODG00000014882 │ 2_1            │ 1.0                │
# │ 55  │ ENSMODG00000014882 │ 5_3            │ 1.0                │
# │ 56  │ ENSMUSG00000031799 │ 2_0            │ 1.0                │
# │ 57  │ ENSMUSG00000031799 │ 1_3            │ 1.0                │
# │ 58  │ ENSMUSG00000031799 │ 4_0            │ 1.0                │
# │ 59  │ ENSMUSG00000031799 │ 1_4            │ 1.0                │
# │ 60  │ ENSMUSG00000031799 │ 5_0            │ 1.0                │
# │ 61  │ ENSMUSG00000031799 │ 3_1            │ 1.0                │
# │ 62  │ ENSMUSG00000031799 │ 9_0            │ 1.0                │
# │ 63  │ ENSMUSG00000031799 │ 5_3            │ 1.0                │
# │ 64  │ ENSOANG00000005367 │ 1_3            │ 1.0                │
# │ 65  │ ENSOANG00000005367 │ 4_0            │ 1.0                │
# │ 66  │ ENSOANG00000005367 │ 1_4            │ 1.0                │
# │ 67  │ ENSOANG00000005367 │ 5_0            │ 1.0                │
# │ 68  │ ENSOANG00000005367 │ 3_1            │ 1.0                │
# │ 69  │ ENSOANG00000005367 │ 2_1            │ 1.0                │
# │ 70  │ ENSOANG00000005367 │ 8_0            │ 1.0                │
# │ 71  │ ENSRNOG00000015496 │ 2_0            │ 1.0                │
# │ 72  │ ENSRNOG00000015496 │ 1_3            │ 1.0                │
# │ 73  │ ENSRNOG00000015496 │ 4_0            │ 1.0                │
# │ 74  │ ENSRNOG00000015496 │ 1_4            │ 1.0                │
# │ 75  │ ENSRNOG00000015496 │ 5_0            │ 1.0                │
# │ 76  │ ENSRNOG00000015496 │ 3_1            │ 1.0                │
# │ 77  │ ENSRNOG00000015496 │ 9_0            │ 1.0                │
# │ 78  │ ENSRNOG00000015496 │ 5_3            │ 1.0                │
# │ 79  │ ENSSSCG00000013849 │ 2_0            │ 1.0                │
# │ 80  │ ENSSSCG00000013849 │ 1_3            │ 1.0                │
# │ 81  │ ENSSSCG00000013849 │ 4_0            │ 1.0                │
# │ 82  │ ENSSSCG00000013849 │ 1_4            │ 1.0                │
# │ 83  │ ENSSSCG00000013849 │ 5_0            │ 1.0                │
# │ 84  │ ENSSSCG00000013849 │ 3_1            │ 1.0                │
# │ 85  │ ENSSSCG00000013849 │ 2_1            │ 1.0                │
# │ 86  │ ENSSSCG00000013849 │ 5_3            │ 1.0                │
# │ 87  │ ENSXETG00000008736 │ 6_0            │ 0.5                │
# │ 88  │ ENSXETG00000008736 │ 1_0            │ 0.5                │
# │ 89  │ ENSXETG00000008736 │ 1_2            │ 0.5                │
# │ 90  │ ENSXETG00000008736 │ 1_3            │ 1.0                │
# │ 91  │ ENSXETG00000008736 │ 4_0            │ 1.0                │
# │ 92  │ ENSXETG00000008736 │ 1_4            │ 1.0                │
# │ 93  │ ENSXETG00000008736 │ 5_0            │ 1.0                │
# │ 94  │ ENSXETG00000008736 │ 3_1            │ 1.0                │
# │ 95  │ ENSXETG00000008736 │ 9_0            │ 1.0                │
# │ 96  │ ENSXETG00000008736 │ 8_0            │ 0.5                │
# │ 97  │ ENSXETG00000008736 │ 2_0            │ 0.5                │
# │ 98  │ ENSXETG00000008736 │ 7_0            │ 0.5                │
#
# │ Row │ TranscriptsWithSubexon │ TranscriptsInGene │
# │     │ Int64                  │ Int64             │
# ├─────┼────────────────────────┼───────────────────┤
# │ 1   │ 1                      │ 2                 │
# │ 2   │ 2                      │ 2                 │
# │ 3   │ 2                      │ 2                 │
# │ 4   │ 2                      │ 2                 │
# │ 5   │ 2                      │ 2                 │
# │ 6   │ 2                      │ 2                 │
# │ 7   │ 2                      │ 2                 │
# │ 8   │ 1                      │ 2                 │
# │ 9   │ 1                      │ 2                 │
# │ 10  │ 1                      │ 2                 │
# │ 11  │ 1                      │ 2                 │
# │ 12  │ 1                      │ 3                 │
# │ 13  │ 3                      │ 3                 │
# │ 14  │ 3                      │ 3                 │
# │ 15  │ 3                      │ 3                 │
# │ 16  │ 3                      │ 3                 │
# │ 17  │ 3                      │ 3                 │
# │ 18  │ 3                      │ 3                 │
# │ 19  │ 3                      │ 3                 │
# │ 20  │ 1                      │ 3                 │
# │ 21  │ 1                      │ 3                 │
# │ 22  │ 1                      │ 3                 │
# │ 23  │ 1                      │ 3                 │
# │ 24  │ 2                      │ 4                 │
# │ 25  │ 4                      │ 4                 │
# │ 26  │ 4                      │ 4                 │
# │ 27  │ 4                      │ 4                 │
# │ 28  │ 4                      │ 4                 │
# │ 29  │ 3                      │ 4                 │
# │ 30  │ 1                      │ 4                 │
# │ 31  │ 2                      │ 4                 │
# │ 32  │ 2                      │ 4                 │
# │ 33  │ 1                      │ 4                 │
# │ 34  │ 3                      │ 4                 │
# │ 35  │ 3                      │ 4                 │
# │ 36  │ 3                      │ 4                 │
# │ 37  │ 3                      │ 4                 │
# │ 38  │ 4                      │ 4                 │
# │ 39  │ 4                      │ 4                 │
# │ 40  │ 4                      │ 4                 │
# │ 41  │ 1                      │ 4                 │
# │ 42  │ 4                      │ 4                 │
# │ 43  │ 4                      │ 4                 │
# │ 44  │ 3                      │ 4                 │
# │ 45  │ 3                      │ 4                 │
# │ 46  │ 1                      │ 4                 │
# │ 47  │ 1                      │ 4                 │
# │ 48  │ 1                      │ 1                 │
# │ 49  │ 1                      │ 1                 │
# │ 50  │ 1                      │ 1                 │
# │ 51  │ 1                      │ 1                 │
# │ 52  │ 1                      │ 1                 │
# │ 53  │ 1                      │ 1                 │
# │ 54  │ 1                      │ 1                 │
# │ 55  │ 1                      │ 1                 │
# │ 56  │ 1                      │ 1                 │
# │ 57  │ 1                      │ 1                 │
# │ 58  │ 1                      │ 1                 │
# │ 59  │ 1                      │ 1                 │
# │ 60  │ 1                      │ 1                 │
# │ 61  │ 1                      │ 1                 │
# │ 62  │ 1                      │ 1                 │
# │ 63  │ 1                      │ 1                 │
# │ 64  │ 1                      │ 1                 │
# │ 65  │ 1                      │ 1                 │
# │ 66  │ 1                      │ 1                 │
# │ 67  │ 1                      │ 1                 │
# │ 68  │ 1                      │ 1                 │
# │ 69  │ 1                      │ 1                 │
# │ 70  │ 1                      │ 1                 │
# │ 71  │ 1                      │ 1                 │
# │ 72  │ 1                      │ 1                 │
# │ 73  │ 1                      │ 1                 │
# │ 74  │ 1                      │ 1                 │
# │ 75  │ 1                      │ 1                 │
# │ 76  │ 1                      │ 1                 │
# │ 77  │ 1                      │ 1                 │
# │ 78  │ 1                      │ 1                 │
# │ 79  │ 1                      │ 1                 │
# │ 80  │ 1                      │ 1                 │
# │ 81  │ 1                      │ 1                 │
# │ 82  │ 1                      │ 1                 │
# │ 83  │ 1                      │ 1                 │
# │ 84  │ 1                      │ 1                 │
# │ 85  │ 1                      │ 1                 │
# │ 86  │ 1                      │ 1                 │
# │ 87  │ 1                      │ 2                 │
# │ 88  │ 1                      │ 2                 │
# │ 89  │ 1                      │ 2                 │
# │ 90  │ 2                      │ 2                 │
# │ 91  │ 2                      │ 2                 │
# │ 92  │ 2                      │ 2                 │
# │ 93  │ 2                      │ 2                 │
# │ 94  │ 2                      │ 2                 │
# │ 95  │ 2                      │ 2                 │
# │ 96  │ 1                      │ 2                 │
# │ 97  │ 1                      │ 2                 │
# │ 98  │ 1                      │ 2                 │
