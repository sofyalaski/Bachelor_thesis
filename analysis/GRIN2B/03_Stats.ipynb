# %%
using Statistics
using CSV
using DataFrames
using Measures
using Gadfly

ENV["LINES"] = 9;
# Out:
# ┌ Info: Loading DataFrames support into Gadfly.jl
# └ @ Gadfly C:\Users\Diego\.julia\packages\Gadfly\09PWZ\src\mapping.jl:228

# %%
# parameters
protein = "GRIN2B"
# Out:
# "GRIN2B"

# %%
function path_to_TranscriptAnnotation()
    folders = String[]
    for folder in splitpath(pwd())
        push!(folders, folder)
        if folder == "TranscriptAnnotation"
            break
        end
    end
    joinpath(folders...)
end

results_folder = joinpath(path_to_TranscriptAnnotation(), "benchmark", protein)
table_path = joinpath(results_folder, "thoraxe", "homologous_exon_table.csv")

const table = CSV.read(table_path);

# %% [markdown]
# ## Transcripts per species

# %%
by(table, :Species, :TranscriptIDCluster => length ∘ unique) |> 
    df -> rename!(df, :TranscriptIDCluster_function => :Transcripts) |>
    df -> show(df, allcols=true, allrows=true)
# Out:
# 8×2 DataFrame
# │ Row │ Species            │ Transcripts │
# │     │ String             │ Int64       │
# ├─────┼────────────────────┼─────────────┤
# │ 1   │ bos_taurus         │ 1           │
# │ 2   │ homo_sapiens       │ 1           │
# │ 3   │ gorilla_gorilla    │ 1           │
# │ 4   │ macaca_mulatta     │ 1           │
# │ 5   │ mus_musculus       │ 1           │
# │ 6   │ rattus_norvegicus  │ 1           │
# │ 7   │ sus_scrofa         │ 1           │
# │ 8   │ xenopus_tropicalis │ 1           │

# %% [markdown]
# ## (Sub)exons without (known) homology

# %%
total = sum(startswith(exonid, "0_") for exonid in unique(table[:HomologousExon]))
print("Number of (sub)exons without (known) homology in the gene: ", total)
# Out:
# Number of (sub)exons without (known) homology in the gene: 1

# %%
by(table, :Species) do df
    (ExonsWithoutHomology = sum(startswith(exonid, "0_") for exonid in unique(df[:HomologousExon])), )
end |> df -> show(df, allcols=true, allrows=true)
# Out:
# 8×2 DataFrame
# │ Row │ Species            │ ExonsWithoutHomology │
# │     │ String             │ Int64                │
# ├─────┼────────────────────┼──────────────────────┤
# │ 1   │ bos_taurus         │ 0                    │
# │ 2   │ homo_sapiens       │ 0                    │
# │ 3   │ gorilla_gorilla    │ 0                    │
# │ 4   │ macaca_mulatta     │ 0                    │
# │ 5   │ mus_musculus       │ 1                    │
# │ 6   │ rattus_norvegicus  │ 0                    │
# │ 7   │ sus_scrofa         │ 0                    │
# │ 8   │ xenopus_tropicalis │ 0                    │

# %% [markdown]
# ### Short exons

# %% [markdown]
# Some subexons doesn't have known homologs because they are too short

# %%
by(table, [:TranscriptIDCluster, :ExonIDCluster], :SubexonProteinSequence => join) |>
    df -> by(df, 
        :ExonIDCluster, 
        :SubexonProteinSequence_join => col -> minimum(map(x -> length(replace(x, "*" => "")), col))) |>
    df -> rename!(df, :SubexonProteinSequence_join_function => :ExonLength) |>
    df -> df[df[:ExonLength] .≤ 4, :] |>
    df -> show(df, allcols=true, allrows=true)
# Out:
# 1×2 DataFrame
# │ Row │ ExonIDCluster      │ ExonLength │
# │     │ String             │ Int64      │
# ├─────┼────────────────────┼────────────┤
# │ 1   │ ENSMUSE00000835365 │ 0          │

# %% [markdown]
# ## Putative orthologous exons

# %%
total = sum(!startswith(exonid, "0_") for exonid in unique(table[:HomologousExon]))
print("Number of putative orthologous exons in the gene: ", total)
# Out:
# Number of putative orthologous exons in the gene: 17

# %%
by(table, :Species) do df
    (ExonsWithoutHomology = sum(!startswith(exonid, "0_") for exonid in unique(df[:HomologousExon])), )
end |> df -> show(df, allcols=true, allrows=true)
# Out:
# 8×2 DataFrame
# │ Row │ Species            │ ExonsWithoutHomology │
# │     │ String             │ Int64                │
# ├─────┼────────────────────┼──────────────────────┤
# │ 1   │ bos_taurus         │ 12                   │
# │ 2   │ homo_sapiens       │ 12                   │
# │ 3   │ gorilla_gorilla    │ 12                   │
# │ 4   │ macaca_mulatta     │ 12                   │
# │ 5   │ mus_musculus       │ 2                    │
# │ 6   │ rattus_norvegicus  │ 12                   │
# │ 7   │ sus_scrofa         │ 12                   │
# │ 8   │ xenopus_tropicalis │ 15                   │

# %% [markdown]
# ## Exon Lengths

# %% [markdown]
# Distribution of homologous exon lengths

# %%
len(x) = ismissing(x) ? 0 : length(x)

const lengths = by(table, :HomologousExon, :HomologousExonSequence => col -> maximum(len.(col))) |> 
    df -> rename!(df, :HomologousExonSequence_function  => :HomologousExonLength ) |>
    df -> sort!(df, :HomologousExon) 

show(lengths, allrows=true)
# Out:
# 18×2 DataFrame
# │ Row │ HomologousExon │ HomologousExonLength │
# │     │ String         │ Int64                │
# ├─────┼────────────────┼──────────────────────┤
# │ 1   │ 0_1            │ 0                    │
# │ 2   │ 10_0           │ 52                   │
# │ 3   │ 11_0           │ 42                   │
# │ 4   │ 12_0           │ 41                   │
# │ 5   │ 13_0           │ 38                   │
# │ 6   │ 14_0           │ 11                   │
# │ 7   │ 1_0            │ 6                    │
# │ 8   │ 1_1            │ 631                  │
# │ 9   │ 2_0            │ 201                  │
# │ 10  │ 2_1            │ 10                   │
# │ 11  │ 3_0            │ 137                  │
# │ 12  │ 4_0            │ 80                   │
# │ 13  │ 5_0            │ 79                   │
# │ 14  │ 6_0            │ 70                   │
# │ 15  │ 7_0            │ 12                   │
# │ 16  │ 7_1            │ 63                   │
# │ 17  │ 8_0            │ 57                   │
# │ 18  │ 9_0            │ 54                   │

# %%
lengths[:WithHomologous] = [ !startswith(exonid, "0_") for exonid in lengths[:HomologousExon ] ];

# %%
plt = plot(lengths, x="HomologousExonLength", color="WithHomologous", Geom.histogram)
draw(SVG(25cm, 15cm), plt)
# Out:
# SVG(250.0mm, 150.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=12936, maxsize=Inf, ptr=12937, mark=-1), nothing, "img-5ac6aa61", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Property}}(Property{JSIncludePrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{StrokePrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{FontSizePrimitive}=>nothing,Property{SVGAttributePrimitive}=>nothing,Property{StrokeDashPrimitive}=>nothing,Property{SVGClassPrimitive}=>nothing,Property{FontPrimitive}=>nothing,Property{LineWidthPrimitive}=>nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Length{:mm,Float64},Length{:mm,Float64}}[(8.67333mm, 5.0mm), (216.29mm, 5.0mm), (216.29mm, 130.715mm), (8.67333mm, 130.715mm)])=>"img-5ac6aa61-17"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-5ac6aa61-71", false, 71, Set(AbstractString["C:\\Users\\Diego\\.julia\\packages\\Gadfly\\09PWZ\\src\\gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-5ac6aa61-4\")\n   .drag(function() {}, function() {}, function() {});", "fig.select(\"#img-5ac6aa61-5\")\n   .data(\"color_class\", \"color_true\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-10\")\n   .data(\"color_class\", \"color_false\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-18\")\n   .init_gadfly();"], false, :none, (BoundingBox{Tuple{Length{:mm,Float64},Length{:mm,Float64}},Tuple{Length{:mm,Float64},Length{:mm,Float64}}}((8.673333333333346mm, 5.0mm), (207.61666666666667mm, 125.715mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-7.85790292215765, 8.131454627613687, 815.7158058443154, -8.262909255227376, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %% [markdown]
# ## Alternative spliced homologous exons

# %% [markdown]
# Exons with a `TranscriptFraction` of `1.0` in a gene are constitutive. The plot can help to identify homologous_exons that change their `TranscriptFraction` in different genes.

# %%
constitutive = by(table, :GeneID) do df
    subdf = unique(df[:, [:HomologousExon, :TranscriptsWithSubexon, :TranscriptsInGene]])
    by(subdf, :HomologousExon) do exondf
        (TranscriptFraction = exondf[1, :TranscriptsWithSubexon] / exondf[1, :TranscriptsInGene],
         TranscriptsWithSubexon = exondf[1, :TranscriptsWithSubexon],
         TranscriptsInGene = exondf[1, :TranscriptsInGene])
    end
end;

# %%
plt = plot(constitutive, x="HomologousExon", y="TranscriptFraction", Geom.point)
draw(SVG(25cm, 15cm), plt)
# Out:
# SVG(250.0mm, 150.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=43281, maxsize=Inf, ptr=43282, mark=-1), nothing, "img-490bdd3f", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Property}}(Property{JSIncludePrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{StrokePrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{FontSizePrimitive}=>nothing,Property{SVGAttributePrimitive}=>nothing,Property{StrokeDashPrimitive}=>nothing,Property{SVGClassPrimitive}=>nothing,Property{FontPrimitive}=>nothing,Property{LineWidthPrimitive}=>nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Length{:mm,Float64},Length{:mm,Float64}}[(16.285mm, 5.0mm), (245.0mm, 5.0mm), (245.0mm, 130.715mm), (16.285mm, 130.715mm)])=>"img-490bdd3f-4"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-490bdd3f-304", false, 304, Set(AbstractString["C:\\Users\\Diego\\.julia\\packages\\Gadfly\\09PWZ\\src\\gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-490bdd3f-5\")\n   .init_gadfly();"], false, :none, (BoundingBox{Tuple{Length{:mm,Float64},Length{:mm,Float64}},Tuple{Length{:mm,Float64},Length{:mm,Float64}}}((16.285000000000025mm, 5.0mm), (228.71500000000003mm, 125.715mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(0.5, 2.0328636569034217, 18.0, -2.065727313806844, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
show(constitutive, allrows=true, allcols=true)
# Out:
# 90×5 DataFrame
# │ Row │ GeneID             │ HomologousExon │ TranscriptFraction │
# │     │ String             │ String         │ Float64            │
# ├─────┼────────────────────┼────────────────┼────────────────────┤
# │ 1   │ ENSBTAG00000000219 │ 3_0            │ 1.0                │
# │ 2   │ ENSBTAG00000000219 │ 2_0            │ 1.0                │
# │ 3   │ ENSBTAG00000000219 │ 13_0           │ 1.0                │
# │ 4   │ ENSBTAG00000000219 │ 6_0            │ 1.0                │
# │ 5   │ ENSBTAG00000000219 │ 8_0            │ 1.0                │
# │ 6   │ ENSBTAG00000000219 │ 10_0           │ 1.0                │
# │ 7   │ ENSBTAG00000000219 │ 11_0           │ 1.0                │
# │ 8   │ ENSBTAG00000000219 │ 4_0            │ 1.0                │
# │ 9   │ ENSBTAG00000000219 │ 9_0            │ 1.0                │
# │ 10  │ ENSBTAG00000000219 │ 7_1            │ 1.0                │
# │ 11  │ ENSBTAG00000000219 │ 5_0            │ 1.0                │
# │ 12  │ ENSBTAG00000000219 │ 1_1            │ 1.0                │
# │ 13  │ ENSG00000273079    │ 3_0            │ 1.0                │
# │ 14  │ ENSG00000273079    │ 2_0            │ 1.0                │
# │ 15  │ ENSG00000273079    │ 13_0           │ 1.0                │
# │ 16  │ ENSG00000273079    │ 6_0            │ 1.0                │
# │ 17  │ ENSG00000273079    │ 8_0            │ 1.0                │
# │ 18  │ ENSG00000273079    │ 10_0           │ 1.0                │
# │ 19  │ ENSG00000273079    │ 11_0           │ 1.0                │
# │ 20  │ ENSG00000273079    │ 4_0            │ 1.0                │
# │ 21  │ ENSG00000273079    │ 9_0            │ 1.0                │
# │ 22  │ ENSG00000273079    │ 7_1            │ 1.0                │
# │ 23  │ ENSG00000273079    │ 5_0            │ 1.0                │
# │ 24  │ ENSG00000273079    │ 1_1            │ 1.0                │
# │ 25  │ ENSGGOG00000009965 │ 3_0            │ 1.0                │
# │ 26  │ ENSGGOG00000009965 │ 2_0            │ 1.0                │
# │ 27  │ ENSGGOG00000009965 │ 13_0           │ 1.0                │
# │ 28  │ ENSGGOG00000009965 │ 6_0            │ 1.0                │
# │ 29  │ ENSGGOG00000009965 │ 8_0            │ 1.0                │
# │ 30  │ ENSGGOG00000009965 │ 10_0           │ 1.0                │
# │ 31  │ ENSGGOG00000009965 │ 11_0           │ 1.0                │
# │ 32  │ ENSGGOG00000009965 │ 4_0            │ 1.0                │
# │ 33  │ ENSGGOG00000009965 │ 9_0            │ 1.0                │
# │ 34  │ ENSGGOG00000009965 │ 7_1            │ 1.0                │
# │ 35  │ ENSGGOG00000009965 │ 5_0            │ 1.0                │
# │ 36  │ ENSGGOG00000009965 │ 1_1            │ 1.0                │
# │ 37  │ ENSMMUG00000019112 │ 3_0            │ 1.0                │
# │ 38  │ ENSMMUG00000019112 │ 2_0            │ 1.0                │
# │ 39  │ ENSMMUG00000019112 │ 13_0           │ 1.0                │
# │ 40  │ ENSMMUG00000019112 │ 6_0            │ 1.0                │
# │ 41  │ ENSMMUG00000019112 │ 8_0            │ 1.0                │
# │ 42  │ ENSMMUG00000019112 │ 10_0           │ 1.0                │
# │ 43  │ ENSMMUG00000019112 │ 11_0           │ 1.0                │
# │ 44  │ ENSMMUG00000019112 │ 4_0            │ 1.0                │
# │ 45  │ ENSMMUG00000019112 │ 9_0            │ 1.0                │
# │ 46  │ ENSMMUG00000019112 │ 7_1            │ 1.0                │
# │ 47  │ ENSMMUG00000019112 │ 5_0            │ 1.0                │
# │ 48  │ ENSMMUG00000019112 │ 1_1            │ 1.0                │
# │ 49  │ ENSMUSG00000030209 │ 3_0            │ 1.0                │
# │ 50  │ ENSMUSG00000030209 │ 2_0            │ 1.0                │
# │ 51  │ ENSMUSG00000030209 │ 0_1            │ 1.0                │
# │ 52  │ ENSRNOG00000008766 │ 3_0            │ 1.0                │
# │ 53  │ ENSRNOG00000008766 │ 2_0            │ 1.0                │
# │ 54  │ ENSRNOG00000008766 │ 13_0           │ 1.0                │
# │ 55  │ ENSRNOG00000008766 │ 6_0            │ 1.0                │
# │ 56  │ ENSRNOG00000008766 │ 8_0            │ 1.0                │
# │ 57  │ ENSRNOG00000008766 │ 10_0           │ 1.0                │
# │ 58  │ ENSRNOG00000008766 │ 11_0           │ 1.0                │
# │ 59  │ ENSRNOG00000008766 │ 4_0            │ 1.0                │
# │ 60  │ ENSRNOG00000008766 │ 9_0            │ 1.0                │
# │ 61  │ ENSRNOG00000008766 │ 7_1            │ 1.0                │
# │ 62  │ ENSRNOG00000008766 │ 5_0            │ 1.0                │
# │ 63  │ ENSRNOG00000008766 │ 1_1            │ 1.0                │
# │ 64  │ ENSSSCG00000000614 │ 3_0            │ 1.0                │
# │ 65  │ ENSSSCG00000000614 │ 2_0            │ 1.0                │
# │ 66  │ ENSSSCG00000000614 │ 13_0           │ 1.0                │
# │ 67  │ ENSSSCG00000000614 │ 6_0            │ 1.0                │
# │ 68  │ ENSSSCG00000000614 │ 8_0            │ 1.0                │
# │ 69  │ ENSSSCG00000000614 │ 10_0           │ 1.0                │
# │ 70  │ ENSSSCG00000000614 │ 11_0           │ 1.0                │
# │ 71  │ ENSSSCG00000000614 │ 4_0            │ 1.0                │
# │ 72  │ ENSSSCG00000000614 │ 9_0            │ 1.0                │
# │ 73  │ ENSSSCG00000000614 │ 7_1            │ 1.0                │
# │ 74  │ ENSSSCG00000000614 │ 5_0            │ 1.0                │
# │ 75  │ ENSSSCG00000000614 │ 1_1            │ 1.0                │
# │ 76  │ ENSXETG00000030602 │ 2_0            │ 1.0                │
# │ 77  │ ENSXETG00000030602 │ 13_0           │ 1.0                │
# │ 78  │ ENSXETG00000030602 │ 6_0            │ 1.0                │
# │ 79  │ ENSXETG00000030602 │ 8_0            │ 1.0                │
# │ 80  │ ENSXETG00000030602 │ 10_0           │ 1.0                │
# │ 81  │ ENSXETG00000030602 │ 14_0           │ 1.0                │
# │ 82  │ ENSXETG00000030602 │ 12_0           │ 1.0                │
# │ 83  │ ENSXETG00000030602 │ 7_0            │ 1.0                │
# │ 84  │ ENSXETG00000030602 │ 1_0            │ 1.0                │
# │ 85  │ ENSXETG00000030602 │ 2_1            │ 1.0                │
# │ 86  │ ENSXETG00000030602 │ 4_0            │ 1.0                │
# │ 87  │ ENSXETG00000030602 │ 9_0            │ 1.0                │
# │ 88  │ ENSXETG00000030602 │ 7_1            │ 1.0                │
# │ 89  │ ENSXETG00000030602 │ 5_0            │ 1.0                │
# │ 90  │ ENSXETG00000030602 │ 1_1            │ 1.0                │
#
# │ Row │ TranscriptsWithSubexon │ TranscriptsInGene │
# │     │ Int64                  │ Int64             │
# ├─────┼────────────────────────┼───────────────────┤
# │ 1   │ 1                      │ 1                 │
# │ 2   │ 1                      │ 1                 │
# │ 3   │ 1                      │ 1                 │
# │ 4   │ 1                      │ 1                 │
# │ 5   │ 1                      │ 1                 │
# │ 6   │ 1                      │ 1                 │
# │ 7   │ 1                      │ 1                 │
# │ 8   │ 1                      │ 1                 │
# │ 9   │ 1                      │ 1                 │
# │ 10  │ 1                      │ 1                 │
# │ 11  │ 1                      │ 1                 │
# │ 12  │ 1                      │ 1                 │
# │ 13  │ 1                      │ 1                 │
# │ 14  │ 1                      │ 1                 │
# │ 15  │ 1                      │ 1                 │
# │ 16  │ 1                      │ 1                 │
# │ 17  │ 1                      │ 1                 │
# │ 18  │ 1                      │ 1                 │
# │ 19  │ 1                      │ 1                 │
# │ 20  │ 1                      │ 1                 │
# │ 21  │ 1                      │ 1                 │
# │ 22  │ 1                      │ 1                 │
# │ 23  │ 1                      │ 1                 │
# │ 24  │ 1                      │ 1                 │
# │ 25  │ 1                      │ 1                 │
# │ 26  │ 1                      │ 1                 │
# │ 27  │ 1                      │ 1                 │
# │ 28  │ 1                      │ 1                 │
# │ 29  │ 1                      │ 1                 │
# │ 30  │ 1                      │ 1                 │
# │ 31  │ 1                      │ 1                 │
# │ 32  │ 1                      │ 1                 │
# │ 33  │ 1                      │ 1                 │
# │ 34  │ 1                      │ 1                 │
# │ 35  │ 1                      │ 1                 │
# │ 36  │ 1                      │ 1                 │
# │ 37  │ 1                      │ 1                 │
# │ 38  │ 1                      │ 1                 │
# │ 39  │ 1                      │ 1                 │
# │ 40  │ 1                      │ 1                 │
# │ 41  │ 1                      │ 1                 │
# │ 42  │ 1                      │ 1                 │
# │ 43  │ 1                      │ 1                 │
# │ 44  │ 1                      │ 1                 │
# │ 45  │ 1                      │ 1                 │
# │ 46  │ 1                      │ 1                 │
# │ 47  │ 1                      │ 1                 │
# │ 48  │ 1                      │ 1                 │
# │ 49  │ 1                      │ 1                 │
# │ 50  │ 1                      │ 1                 │
# │ 51  │ 1                      │ 1                 │
# │ 52  │ 1                      │ 1                 │
# │ 53  │ 1                      │ 1                 │
# │ 54  │ 1                      │ 1                 │
# │ 55  │ 1                      │ 1                 │
# │ 56  │ 1                      │ 1                 │
# │ 57  │ 1                      │ 1                 │
# │ 58  │ 1                      │ 1                 │
# │ 59  │ 1                      │ 1                 │
# │ 60  │ 1                      │ 1                 │
# │ 61  │ 1                      │ 1                 │
# │ 62  │ 1                      │ 1                 │
# │ 63  │ 1                      │ 1                 │
# │ 64  │ 1                      │ 1                 │
# │ 65  │ 1                      │ 1                 │
# │ 66  │ 1                      │ 1                 │
# │ 67  │ 1                      │ 1                 │
# │ 68  │ 1                      │ 1                 │
# │ 69  │ 1                      │ 1                 │
# │ 70  │ 1                      │ 1                 │
# │ 71  │ 1                      │ 1                 │
# │ 72  │ 1                      │ 1                 │
# │ 73  │ 1                      │ 1                 │
# │ 74  │ 1                      │ 1                 │
# │ 75  │ 1                      │ 1                 │
# │ 76  │ 1                      │ 1                 │
# │ 77  │ 1                      │ 1                 │
# │ 78  │ 1                      │ 1                 │
# │ 79  │ 1                      │ 1                 │
# │ 80  │ 1                      │ 1                 │
# │ 81  │ 1                      │ 1                 │
# │ 82  │ 1                      │ 1                 │
# │ 83  │ 1                      │ 1                 │
# │ 84  │ 1                      │ 1                 │
# │ 85  │ 1                      │ 1                 │
# │ 86  │ 1                      │ 1                 │
# │ 87  │ 1                      │ 1                 │
# │ 88  │ 1                      │ 1                 │
# │ 89  │ 1                      │ 1                 │
# │ 90  │ 1                      │ 1                 │
