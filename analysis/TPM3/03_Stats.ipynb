# %%
using Statistics
using CSV
using DataFrames
using Measures
using Gadfly

ENV["LINES"] = 9;
# Out:
# ┌ Info: Loading DataFrames support into Gadfly.jl
# └ @ Gadfly C:\Users\Diego\.julia\packages\Gadfly\09PWZ\src\mapping.jl:228

# %%
# parameters
protein = "TPM3"
# Out:
# "TPM3"

# %%
function path_to_TranscriptAnnotation()
    folders = String[]
    for folder in splitpath(pwd())
        push!(folders, folder)
        if folder == "TranscriptAnnotation"
            break
        end
    end
    joinpath(folders...)
end

results_folder = joinpath(path_to_TranscriptAnnotation(), "benchmark", protein)
table_path = joinpath(results_folder, "thoraxe", "homologous_exon_table.csv")

const table = CSV.read(table_path);

# %% [markdown]
# ## Transcripts per species

# %%
by(table, :Species, :TranscriptIDCluster => length ∘ unique) |> 
    df -> rename!(df, :TranscriptIDCluster_function => :Transcripts) |>
    df -> show(df, allcols=true, allrows=true)
# Out:
# 7×2 DataFrame
# │ Row │ Species               │ Transcripts │
# │     │ String                │ Int64       │
# ├─────┼───────────────────────┼─────────────┤
# │ 1   │ bos_taurus            │ 3           │
# │ 2   │ danio_rerio           │ 5           │
# │ 3   │ homo_sapiens          │ 9           │
# │ 4   │ macaca_mulatta        │ 6           │
# │ 5   │ monodelphis_domestica │ 1           │
# │ 6   │ rattus_norvegicus     │ 3           │
# │ 7   │ sus_scrofa            │ 4           │

# %% [markdown]
# ## (Sub)exons without (known) homology

# %%
total = sum(startswith(exonid, "0_") for exonid in unique(table[:HomologousExon]))
print("Number of (sub)exons without (known) homology in the gene: ", total)
# Out:
# Number of (sub)exons without (known) homology in the gene: 11

# %%
by(table, :Species) do df
    (ExonsWithoutHomology = sum(startswith(exonid, "0_") for exonid in unique(df[:HomologousExon])), )
end |> df -> show(df, allcols=true, allrows=true)
# Out:
# 7×2 DataFrame
# │ Row │ Species               │ ExonsWithoutHomology │
# │     │ String                │ Int64                │
# ├─────┼───────────────────────┼──────────────────────┤
# │ 1   │ bos_taurus            │ 1                    │
# │ 2   │ danio_rerio           │ 1                    │
# │ 3   │ homo_sapiens          │ 3                    │
# │ 4   │ macaca_mulatta        │ 2                    │
# │ 5   │ monodelphis_domestica │ 1                    │
# │ 6   │ rattus_norvegicus     │ 1                    │
# │ 7   │ sus_scrofa            │ 2                    │

# %% [markdown]
# ### Short exons

# %% [markdown]
# Some subexons doesn't have known homologs because they are too short

# %%
by(table, [:TranscriptIDCluster, :ExonIDCluster], :SubexonProteinSequence => join) |>
    df -> by(df, 
        :ExonIDCluster, 
        :SubexonProteinSequence_join => col -> minimum(map(x -> length(replace(x, "*" => "")), col))) |>
    df -> rename!(df, :SubexonProteinSequence_join_function => :ExonLength) |>
    df -> df[df[:ExonLength] .≤ 4, :] |>
    df -> show(df, allcols=true, allrows=true)
# Out:
# 9×2 DataFrame
# │ Row │ ExonIDCluster                         │ ExonLength │
# │     │ String                                │ Int64      │
# ├─────┼───────────────────────────────────────┼────────────┤
# │ 1   │ ENSBTAE00000106662                    │ 0          │
# │ 2   │ ENSDARE00000776632                    │ 0          │
# │ 3   │ ENSE00001447355                       │ 0          │
# │ 4   │ ENSE00002019162/ENSE00003846728       │ 0          │
# │ 5   │ ENSMMUE00000104638/ENSMMUE00000220161 │ 0          │
# │ 6   │ ENSMODE00000257411                    │ 0          │
# │ 7   │ ENSRNOE00000467026                    │ 0          │
# │ 8   │ ENSSSCE00000056195                    │ 0          │
# │ 9   │ ENSSSCE00000335583                    │ 0          │

# %% [markdown]
# ## Putative orthologous exons

# %%
total = sum(!startswith(exonid, "0_") for exonid in unique(table[:HomologousExon]))
print("Number of putative orthologous exons in the gene: ", total)
# Out:
# Number of putative orthologous exons in the gene: 21

# %%
by(table, :Species) do df
    (ExonsWithoutHomology = sum(!startswith(exonid, "0_") for exonid in unique(df[:HomologousExon])), )
end |> df -> show(df, allcols=true, allrows=true)
# Out:
# 7×2 DataFrame
# │ Row │ Species               │ ExonsWithoutHomology │
# │     │ String                │ Int64                │
# ├─────┼───────────────────────┼──────────────────────┤
# │ 1   │ bos_taurus            │ 15                   │
# │ 2   │ danio_rerio           │ 14                   │
# │ 3   │ homo_sapiens          │ 16                   │
# │ 4   │ macaca_mulatta        │ 17                   │
# │ 5   │ monodelphis_domestica │ 11                   │
# │ 6   │ rattus_norvegicus     │ 15                   │
# │ 7   │ sus_scrofa            │ 15                   │

# %% [markdown]
# ## Exon Lengths

# %% [markdown]
# Distribution of homologous exon lengths

# %%
len(x) = ismissing(x) ? 0 : length(x)

const lengths = by(table, :HomologousExon, :HomologousExonSequence => col -> maximum(len.(col))) |> 
    df -> rename!(df, :HomologousExonSequence_function  => :HomologousExonLength ) |>
    df -> sort!(df, :HomologousExon) 

show(lengths, allrows=true)
# Out:
# 32×2 DataFrame
# │ Row │ HomologousExon │ HomologousExonLength │
# │     │ String         │ Int64                │
# ├─────┼────────────────┼──────────────────────┤
# │ 1   │ 0_1            │ 0                    │
# │ 2   │ 0_10           │ 0                    │
# │ 3   │ 0_11           │ 0                    │
# │ 4   │ 0_2            │ 0                    │
# │ 5   │ 0_3            │ 0                    │
# │ 6   │ 0_4            │ 0                    │
# │ 7   │ 0_5            │ 0                    │
# │ 8   │ 0_6            │ 0                    │
# │ 9   │ 0_7            │ 0                    │
# │ 10  │ 0_8            │ 0                    │
# │ 11  │ 0_9            │ 0                    │
# │ 12  │ 10_0           │ 21                   │
# │ 13  │ 11_0           │ 16                   │
# │ 14  │ 12_0           │ 12                   │
# │ 15  │ 1_0            │ 42                   │
# │ 16  │ 1_1            │ 45                   │
# │ 17  │ 1_2            │ 6                    │
# │ 18  │ 2_0            │ 1                    │
# │ 19  │ 2_1            │ 38                   │
# │ 20  │ 2_2            │ 44                   │
# │ 21  │ 2_3            │ 24                   │
# │ 22  │ 3_0            │ 1                    │
# │ 23  │ 3_1            │ 38                   │
# │ 24  │ 4_0            │ 39                   │
# │ 25  │ 5_0            │ 1                    │
# │ 26  │ 5_1            │ 25                   │
# │ 27  │ 6_0            │ 26                   │
# │ 28  │ 6_1            │ 25                   │
# │ 29  │ 7_0            │ 25                   │
# │ 30  │ 7_1            │ 25                   │
# │ 31  │ 8_0            │ 25                   │
# │ 32  │ 9_0            │ 24                   │

# %%
lengths[:WithHomologous] = [ !startswith(exonid, "0_") for exonid in lengths[:HomologousExon ] ];

# %%
plt = plot(lengths, x="HomologousExonLength", color="WithHomologous", Geom.histogram)
draw(SVG(25cm, 15cm), plt)
# Out:
# SVG(250.0mm, 150.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=15819, maxsize=Inf, ptr=15820, mark=-1), nothing, "img-5ac6aa61", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Property}}(Property{JSIncludePrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{StrokePrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{FontSizePrimitive}=>nothing,Property{SVGAttributePrimitive}=>nothing,Property{StrokeDashPrimitive}=>nothing,Property{SVGClassPrimitive}=>nothing,Property{FontPrimitive}=>nothing,Property{LineWidthPrimitive}=>nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Length{:mm,Float64},Length{:mm,Float64}}[(10.3467mm, 5.0mm), (216.29mm, 5.0mm), (216.29mm, 130.715mm), (10.3467mm, 130.715mm)])=>"img-5ac6aa61-13"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-5ac6aa61-82", false, 82, Set(AbstractString["C:\\Users\\Diego\\.julia\\packages\\Gadfly\\09PWZ\\src\\gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-5ac6aa61-4\")\n   .drag(function() {}, function() {}, function() {});", "fig.select(\"#img-5ac6aa61-6\")\n   .data(\"color_class\", \"color_false\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-7\")\n   .data(\"color_class\", \"color_true\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-9\")\n   .data(\"color_class\", \"color_false\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-10\")\n   .data(\"color_class\", \"color_true\")\n.click(Gadfly.colorkey_swatch_click)\n;", "fig.select(\"#img-5ac6aa61-14\")\n   .init_gadfly();"], false, :none, (BoundingBox{Tuple{Length{:mm,Float64},Length{:mm,Float64}},Tuple{Length{:mm,Float64},Length{:mm,Float64}}}((10.346666666666664mm, 5.0mm), (205.94333333333333mm, 125.71499999999999mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(-0.4951884191935031, 15.246477426775664, 50.99037683838701, -15.49295485355133, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %% [markdown]
# ## Alternative spliced homologous exons

# %% [markdown]
# Exons with a `TranscriptFraction` of `1.0` in a gene are constitutive. The plot can help to identify homologous_exons that change their `TranscriptFraction` in different genes.

# %%
constitutive = by(table, :GeneID) do df
    subdf = unique(df[:, [:HomologousExon, :TranscriptsWithSubexon, :TranscriptsInGene]])
    by(subdf, :HomologousExon) do exondf
        (TranscriptFraction = exondf[1, :TranscriptsWithSubexon] / exondf[1, :TranscriptsInGene],
         TranscriptsWithSubexon = exondf[1, :TranscriptsWithSubexon],
         TranscriptsInGene = exondf[1, :TranscriptsInGene])
    end
end;

# %%
plt = plot(constitutive, x="HomologousExon", y="TranscriptFraction", Geom.point)
draw(SVG(25cm, 15cm), plt)
# Out:
# SVG(250.0mm, 150.0mm, IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=58325, maxsize=Inf, ptr=58326, mark=-1), nothing, "img-490bdd3f", 0, Compose.SVGPropertyFrame[], Dict{Type,Union{Nothing, Property}}(Property{JSIncludePrimitive}=>nothing,Property{FillPrimitive}=>nothing,Property{StrokePrimitive}=>nothing,Property{JSCallPrimitive}=>nothing,Property{FontSizePrimitive}=>nothing,Property{SVGAttributePrimitive}=>nothing,Property{StrokeDashPrimitive}=>nothing,Property{SVGClassPrimitive}=>nothing,Property{FontPrimitive}=>nothing,Property{LineWidthPrimitive}=>nothing…), OrderedCollections.OrderedDict{Compose.ClipPrimitive,String}(ClipPrimitive{Tuple{Length{:mm,Float64},Length{:mm,Float64}}}(Tuple{Length{:mm,Float64},Length{:mm,Float64}}[(18.6317mm, 5.0mm), (245.0mm, 5.0mm), (245.0mm, 130.715mm), (18.6317mm, 130.715mm)])=>"img-490bdd3f-4"), Tuple{Compose.FormPrimitive,String}[], Set(AbstractString[]), true, false, nothing, true, "img-490bdd3f-400", false, 400, Set(AbstractString["C:\\Users\\Diego\\.julia\\packages\\Gadfly\\09PWZ\\src\\gadfly.js"]), Set(Tuple{AbstractString,AbstractString}[("Snap.svg", "Snap"), ("Gadfly", "Gadfly")]), AbstractString["fig.select(\"#img-490bdd3f-5\")\n   .init_gadfly();"], false, :none, (BoundingBox{Tuple{Length{:mm,Float64},Length{:mm,Float64}},Tuple{Length{:mm,Float64},Length{:mm,Float64}}}((18.63166666666669mm, 5.0mm), (226.36833333333334mm, 125.715mm)), Compose.UnitBox{Float64,Float64,Float64,Float64}(0.5, 1.0164318284517109, 32.0, -1.032863656903422, 0.0mm, 0.0mm, 0.0mm, 0.0mm), Compose.IdentityTransform()))

# %%
show(constitutive, allrows=true, allcols=true)
# Out:
# 114×5 DataFrame
# │ Row │ GeneID             │ HomologousExon │ TranscriptFraction │
# │     │ String             │ String         │ Float64            │
# ├─────┼────────────────────┼────────────────┼────────────────────┤
# │ 1   │ ENSBTAG00000033217 │ 2_1            │ 0.666667           │
# │ 2   │ ENSBTAG00000033217 │ 1_0            │ 0.666667           │
# │ 3   │ ENSBTAG00000033217 │ 1_1            │ 0.666667           │
# │ 4   │ ENSBTAG00000033217 │ 3_0            │ 0.666667           │
# │ 5   │ ENSBTAG00000033217 │ 3_1            │ 0.666667           │
# │ 6   │ ENSBTAG00000033217 │ 2_3            │ 0.666667           │
# │ 7   │ ENSBTAG00000033217 │ 7_1            │ 0.333333           │
# │ 8   │ ENSBTAG00000033217 │ 10_0           │ 0.666667           │
# │ 9   │ ENSBTAG00000033217 │ 9_0            │ 0.666667           │
# │ 10  │ ENSBTAG00000033217 │ 6_0            │ 0.333333           │
# │ 11  │ ENSBTAG00000033217 │ 0_1            │ 0.333333           │
# │ 12  │ ENSBTAG00000033217 │ 2_2            │ 0.333333           │
# │ 13  │ ENSBTAG00000033217 │ 7_0            │ 0.333333           │
# │ 14  │ ENSBTAG00000033217 │ 5_0            │ 0.333333           │
# │ 15  │ ENSBTAG00000033217 │ 5_1            │ 0.333333           │
# │ 16  │ ENSBTAG00000033217 │ 11_0           │ 0.333333           │
# │ 17  │ ENSDARG00000005162 │ 2_2            │ 0.4                │
# │ 18  │ ENSDARG00000005162 │ 1_1            │ 1.0                │
# │ 19  │ ENSDARG00000005162 │ 3_0            │ 1.0                │
# │ 20  │ ENSDARG00000005162 │ 3_1            │ 1.0                │
# │ 21  │ ENSDARG00000005162 │ 2_3            │ 1.0                │
# │ 22  │ ENSDARG00000005162 │ 7_0            │ 0.4                │
# │ 23  │ ENSDARG00000005162 │ 10_0           │ 1.0                │
# │ 24  │ ENSDARG00000005162 │ 9_0            │ 1.0                │
# │ 25  │ ENSDARG00000005162 │ 5_0            │ 0.8                │
# │ 26  │ ENSDARG00000005162 │ 5_1            │ 0.8                │
# │ 27  │ ENSDARG00000005162 │ 4_0            │ 0.6                │
# │ 28  │ ENSDARG00000005162 │ 1_0            │ 0.6                │
# │ 29  │ ENSDARG00000005162 │ 7_1            │ 0.6                │
# │ 30  │ ENSDARG00000005162 │ 6_0            │ 0.2                │
# │ 31  │ ENSDARG00000005162 │ 0_2            │ 0.2                │
# │ 32  │ ENSG00000143549    │ 3_1            │ 1.0                │
# │ 33  │ ENSG00000143549    │ 2_3            │ 1.0                │
# │ 34  │ ENSG00000143549    │ 7_1            │ 0.444444           │
# │ 35  │ ENSG00000143549    │ 10_0           │ 0.888889           │
# │ 36  │ ENSG00000143549    │ 9_0            │ 1.0                │
# │ 37  │ ENSG00000143549    │ 5_0            │ 0.444444           │
# │ 38  │ ENSG00000143549    │ 5_1            │ 0.444444           │
# │ 39  │ ENSG00000143549    │ 2_2            │ 0.666667           │
# │ 40  │ ENSG00000143549    │ 1_1            │ 0.888889           │
# │ 41  │ ENSG00000143549    │ 3_0            │ 0.888889           │
# │ 42  │ ENSG00000143549    │ 6_1            │ 0.222222           │
# │ 43  │ ENSG00000143549    │ 7_0            │ 0.555556           │
# │ 44  │ ENSG00000143549    │ 6_0            │ 0.333333           │
# │ 45  │ ENSG00000143549    │ 0_3            │ 0.111111           │
# │ 46  │ ENSG00000143549    │ 2_0            │ 0.222222           │
# │ 47  │ ENSG00000143549    │ 2_1            │ 0.222222           │
# │ 48  │ ENSG00000143549    │ 1_0            │ 0.222222           │
# │ 49  │ ENSG00000143549    │ 0_4            │ 0.222222           │
# │ 50  │ ENSG00000143549    │ 0_5            │ 0.222222           │
# │ 51  │ ENSMMUG00000010805 │ 2_0            │ 0.166667           │
# │ 52  │ ENSMMUG00000010805 │ 2_1            │ 0.333333           │
# │ 53  │ ENSMMUG00000010805 │ 1_0            │ 0.333333           │
# │ 54  │ ENSMMUG00000010805 │ 1_1            │ 1.0                │
# │ 55  │ ENSMMUG00000010805 │ 3_0            │ 1.0                │
# │ 56  │ ENSMMUG00000010805 │ 3_1            │ 1.0                │
# │ 57  │ ENSMMUG00000010805 │ 2_3            │ 1.0                │
# │ 58  │ ENSMMUG00000010805 │ 7_1            │ 0.333333           │
# │ 59  │ ENSMMUG00000010805 │ 10_0           │ 0.833333           │
# │ 60  │ ENSMMUG00000010805 │ 9_0            │ 1.0                │
# │ 61  │ ENSMMUG00000010805 │ 6_0            │ 0.333333           │
# │ 62  │ ENSMMUG00000010805 │ 0_6            │ 0.333333           │
# │ 63  │ ENSMMUG00000010805 │ 2_2            │ 0.666667           │
# │ 64  │ ENSMMUG00000010805 │ 6_1            │ 0.166667           │
# │ 65  │ ENSMMUG00000010805 │ 7_0            │ 0.666667           │
# │ 66  │ ENSMMUG00000010805 │ 12_0           │ 0.166667           │
# │ 67  │ ENSMMUG00000010805 │ 0_7            │ 0.333333           │
# │ 68  │ ENSMMUG00000010805 │ 5_0            │ 0.333333           │
# │ 69  │ ENSMMUG00000010805 │ 5_1            │ 0.333333           │
# │ 70  │ ENSMODG00000017253 │ 2_0            │ 1.0                │
# │ 71  │ ENSMODG00000017253 │ 2_1            │ 1.0                │
# │ 72  │ ENSMODG00000017253 │ 1_0            │ 1.0                │
# │ 73  │ ENSMODG00000017253 │ 1_1            │ 1.0                │
# │ 74  │ ENSMODG00000017253 │ 3_0            │ 1.0                │
# │ 75  │ ENSMODG00000017253 │ 3_1            │ 1.0                │
# │ 76  │ ENSMODG00000017253 │ 2_3            │ 1.0                │
# │ 77  │ ENSMODG00000017253 │ 7_1            │ 1.0                │
# │ 78  │ ENSMODG00000017253 │ 10_0           │ 1.0                │
# │ 79  │ ENSMODG00000017253 │ 9_0            │ 1.0                │
# │ 80  │ ENSMODG00000017253 │ 6_0            │ 1.0                │
# │ 81  │ ENSMODG00000017253 │ 0_8            │ 1.0                │
# │ 82  │ ENSRNOG00000017441 │ 2_2            │ 0.666667           │
# │ 83  │ ENSRNOG00000017441 │ 1_1            │ 1.0                │
# │ 84  │ ENSRNOG00000017441 │ 3_0            │ 1.0                │
# │ 85  │ ENSRNOG00000017441 │ 3_1            │ 1.0                │
# │ 86  │ ENSRNOG00000017441 │ 2_3            │ 1.0                │
# │ 87  │ ENSRNOG00000017441 │ 7_0            │ 0.333333           │
# │ 88  │ ENSRNOG00000017441 │ 10_0           │ 1.0                │
# │ 89  │ ENSRNOG00000017441 │ 9_0            │ 1.0                │
# │ 90  │ ENSRNOG00000017441 │ 5_0            │ 0.333333           │
# │ 91  │ ENSRNOG00000017441 │ 5_1            │ 0.333333           │
# │ 92  │ ENSRNOG00000017441 │ 7_1            │ 0.666667           │
# │ 93  │ ENSRNOG00000017441 │ 8_0            │ 0.333333           │
# │ 94  │ ENSRNOG00000017441 │ 4_0            │ 0.333333           │
# │ 95  │ ENSRNOG00000017441 │ 1_0            │ 0.333333           │
# │ 96  │ ENSRNOG00000017441 │ 6_0            │ 0.333333           │
# │ 97  │ ENSRNOG00000017441 │ 0_9            │ 0.333333           │
# │ 98  │ ENSSSCG00000006556 │ 2_2            │ 0.5                │
# │ 99  │ ENSSSCG00000006556 │ 1_1            │ 1.0                │
# │ 100 │ ENSSSCG00000006556 │ 3_0            │ 1.0                │
# │ 101 │ ENSSSCG00000006556 │ 3_1            │ 1.0                │
# │ 102 │ ENSSSCG00000006556 │ 2_3            │ 1.0                │
# │ 103 │ ENSSSCG00000006556 │ 7_1            │ 0.75               │
# │ 104 │ ENSSSCG00000006556 │ 10_0           │ 1.0                │
# │ 105 │ ENSSSCG00000006556 │ 9_0            │ 1.0                │
# │ 106 │ ENSSSCG00000006556 │ 6_0            │ 0.75               │
# │ 107 │ ENSSSCG00000006556 │ 1_2            │ 0.25               │
# │ 108 │ ENSSSCG00000006556 │ 7_0            │ 0.25               │
# │ 109 │ ENSSSCG00000006556 │ 0_10           │ 0.25               │
# │ 110 │ ENSSSCG00000006556 │ 2_1            │ 0.5                │
# │ 111 │ ENSSSCG00000006556 │ 1_0            │ 0.5                │
# │ 112 │ ENSSSCG00000006556 │ 0_11           │ 0.25               │
# │ 113 │ ENSSSCG00000006556 │ 5_0            │ 0.25               │
# │ 114 │ ENSSSCG00000006556 │ 5_1            │ 0.25               │
#
# │ Row │ TranscriptsWithSubexon │ TranscriptsInGene │
# │     │ Int64                  │ Int64             │
# ├─────┼────────────────────────┼───────────────────┤
# │ 1   │ 2                      │ 3                 │
# │ 2   │ 2                      │ 3                 │
# │ 3   │ 2                      │ 3                 │
# │ 4   │ 2                      │ 3                 │
# │ 5   │ 2                      │ 3                 │
# │ 6   │ 2                      │ 3                 │
# │ 7   │ 1                      │ 3                 │
# │ 8   │ 2                      │ 3                 │
# │ 9   │ 2                      │ 3                 │
# │ 10  │ 1                      │ 3                 │
# │ 11  │ 1                      │ 3                 │
# │ 12  │ 1                      │ 3                 │
# │ 13  │ 1                      │ 3                 │
# │ 14  │ 1                      │ 3                 │
# │ 15  │ 1                      │ 3                 │
# │ 16  │ 1                      │ 3                 │
# │ 17  │ 2                      │ 5                 │
# │ 18  │ 5                      │ 5                 │
# │ 19  │ 5                      │ 5                 │
# │ 20  │ 5                      │ 5                 │
# │ 21  │ 5                      │ 5                 │
# │ 22  │ 2                      │ 5                 │
# │ 23  │ 5                      │ 5                 │
# │ 24  │ 5                      │ 5                 │
# │ 25  │ 4                      │ 5                 │
# │ 26  │ 4                      │ 5                 │
# │ 27  │ 3                      │ 5                 │
# │ 28  │ 3                      │ 5                 │
# │ 29  │ 3                      │ 5                 │
# │ 30  │ 1                      │ 5                 │
# │ 31  │ 1                      │ 5                 │
# │ 32  │ 9                      │ 9                 │
# │ 33  │ 9                      │ 9                 │
# │ 34  │ 4                      │ 9                 │
# │ 35  │ 8                      │ 9                 │
# │ 36  │ 9                      │ 9                 │
# │ 37  │ 4                      │ 9                 │
# │ 38  │ 4                      │ 9                 │
# │ 39  │ 6                      │ 9                 │
# │ 40  │ 8                      │ 9                 │
# │ 41  │ 8                      │ 9                 │
# │ 42  │ 2                      │ 9                 │
# │ 43  │ 5                      │ 9                 │
# │ 44  │ 3                      │ 9                 │
# │ 45  │ 1                      │ 9                 │
# │ 46  │ 2                      │ 9                 │
# │ 47  │ 2                      │ 9                 │
# │ 48  │ 2                      │ 9                 │
# │ 49  │ 2                      │ 9                 │
# │ 50  │ 2                      │ 9                 │
# │ 51  │ 1                      │ 6                 │
# │ 52  │ 2                      │ 6                 │
# │ 53  │ 2                      │ 6                 │
# │ 54  │ 6                      │ 6                 │
# │ 55  │ 6                      │ 6                 │
# │ 56  │ 6                      │ 6                 │
# │ 57  │ 6                      │ 6                 │
# │ 58  │ 2                      │ 6                 │
# │ 59  │ 5                      │ 6                 │
# │ 60  │ 6                      │ 6                 │
# │ 61  │ 2                      │ 6                 │
# │ 62  │ 2                      │ 6                 │
# │ 63  │ 4                      │ 6                 │
# │ 64  │ 1                      │ 6                 │
# │ 65  │ 4                      │ 6                 │
# │ 66  │ 1                      │ 6                 │
# │ 67  │ 2                      │ 6                 │
# │ 68  │ 2                      │ 6                 │
# │ 69  │ 2                      │ 6                 │
# │ 70  │ 1                      │ 1                 │
# │ 71  │ 1                      │ 1                 │
# │ 72  │ 1                      │ 1                 │
# │ 73  │ 1                      │ 1                 │
# │ 74  │ 1                      │ 1                 │
# │ 75  │ 1                      │ 1                 │
# │ 76  │ 1                      │ 1                 │
# │ 77  │ 1                      │ 1                 │
# │ 78  │ 1                      │ 1                 │
# │ 79  │ 1                      │ 1                 │
# │ 80  │ 1                      │ 1                 │
# │ 81  │ 1                      │ 1                 │
# │ 82  │ 2                      │ 3                 │
# │ 83  │ 3                      │ 3                 │
# │ 84  │ 3                      │ 3                 │
# │ 85  │ 3                      │ 3                 │
# │ 86  │ 3                      │ 3                 │
# │ 87  │ 1                      │ 3                 │
# │ 88  │ 3                      │ 3                 │
# │ 89  │ 3                      │ 3                 │
# │ 90  │ 1                      │ 3                 │
# │ 91  │ 1                      │ 3                 │
# │ 92  │ 2                      │ 3                 │
# │ 93  │ 1                      │ 3                 │
# │ 94  │ 1                      │ 3                 │
# │ 95  │ 1                      │ 3                 │
# │ 96  │ 1                      │ 3                 │
# │ 97  │ 1                      │ 3                 │
# │ 98  │ 2                      │ 4                 │
# │ 99  │ 4                      │ 4                 │
# │ 100 │ 4                      │ 4                 │
# │ 101 │ 4                      │ 4                 │
# │ 102 │ 4                      │ 4                 │
# │ 103 │ 3                      │ 4                 │
# │ 104 │ 4                      │ 4                 │
# │ 105 │ 4                      │ 4                 │
# │ 106 │ 3                      │ 4                 │
# │ 107 │ 1                      │ 4                 │
# │ 108 │ 1                      │ 4                 │
# │ 109 │ 1                      │ 4                 │
# │ 110 │ 2                      │ 4                 │
# │ 111 │ 2                      │ 4                 │
# │ 112 │ 1                      │ 4                 │
# │ 113 │ 1                      │ 4                 │
# │ 114 │ 1                      │ 4                 │
